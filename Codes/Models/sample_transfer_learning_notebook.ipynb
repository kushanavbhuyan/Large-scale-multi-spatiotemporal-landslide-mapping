# %% [markdown]
# # **Landslide Footprint Detection over Time with Transfer Learning**
# **Model: Multi-scale Attention U-Net**
#
# **Code Author: Kushanav Bhuyan**

# %% [markdown]
# ## Libraries

# %%
# Import the required Libraries

print("Importing packages.......")

import os
import numpy as np
from osgeo import gdal
import tensorflow.keras
import tensorflow as tf

# physical_devices = tf.config.list_physical_devices('GPU')
# tf.config.experimental.set_memory_growth(physical_devices[0], True)

# from tensorflow.compat.v1 import ConfigProto
# from tensorflow.compat.v1 import InteractiveSession

# config = ConfigProto()
# config.gpu_options.allow_growth = True
# session = InteractiveSession(config=config

# %matplotlib inline
# %pylab inline

pylab.rcParams['figure.figsize'] = (15, 10)
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from skimage import exposure
from sklearn.model_selection import train_test_split
import pandas as pd

from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler
from tensorflow.keras import regularizers
from tensorflow.keras import backend as keras
from tensorflow.python.keras import backend as K
sess = K.get_session()
from tensorflow.compat.v1.keras.backend import set_session
from tensorflow.keras.layers import LeakyReLU

import pickle
import matplotlib.pyplot as plt 
import sys

# print("Installing packages.......")

# !pip install keras-tqdm
# from keras_tqdm import TQDMCallback, TQDMNotebookCallback

# !pip install ipython-autotime
# %load_ext autotime
import imgaug.augmenters as iaa

print("Importing helper functions !!")

from utils import *
from losses import *
from attention_Unets import *

print("Libraries imported....")
print("Helpers imported....")
# Out:
# Importing packages.......
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib
# 2022-10-05 16:36:47.460197: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# Importing helper functions !!
# Segmentation Models: using `keras` framework.
# Libraries imported....
# Helpers imported....

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
print('---------------')
# Out:
# Num GPUs Available:  1
# ---------------

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
print('---------------')
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 4394480167679425944
# xla_global_id: -1
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 24548367360
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 11720685676756455845
# physical_device_desc: "device: 0, name: Xavier, pci bus id: 0000:00:00.0, compute capability: 7.2"
# xla_global_id: 416903419
# ]
# ---------------

# %% [markdown]
# ## Loading the data

# %% [markdown]
# ### Define file directories

# %%
# Set file directory of the location where the data is stored
Data_folder= "Data/"

# %% [markdown]
# ### Prepare required dataset
# Make a list of the satellite images

# %%
def readdata(directory, folder_name):
      
    data_path = os.path.join(directory, folder_name)
    data_list = {}

    for f in sorted(os.listdir(data_path)):
        fdir = os.path.join(data_path, f)
        _, ext = os.path.splitext(f)
        if ext.lower() == ".tif":
            imgtype = f[-20:-4] # Number of characters of the image file. Example, "Image_1.tif" = 11 characters
            image_data=gdal.Open(fdir)
            bands = [image_data.GetRasterBand(i+1).ReadAsArray() for i in range(image_data.RasterCount)]
            data_list[imgtype] = np.stack(bands, axis=2) 

    return data_list

# %%
image_list = readdata(directory=Data_folder, folder_name="Satellite images")
label_list = readdata(directory=Data_folder, folder_name="Label images")

# %%
#Check If Everything Works (CIEW)
print("Number of satellite images: " + str(len(image_list)))
print("Shape of the image: "+ str(image_list["image_2019_T18"].shape))

print("Number of label images: " + str(len(label_list)))
print("Shape of the image: "+ str(label_list["image_2019_T18"].shape))
# Out:
# Number of satellite images: 18
# Shape of the image: (3200, 1600, 5)
# Number of label images: 18
# Shape of the image: (3200, 1600, 1)

# %% [markdown]
# ### Visualise the images

# %%
# Visualise both satellite and label images together
# IMPORTANT NOTE: Use an 8-bit unsigned integer label image otherwise any other data type won't be visualised. 

sample_image="image_2018_T14"
sample_label="image_2018_T14"

def visualise_data(data,data2):
    f, axarr = plt.subplots(1,2)   
    data = data.astype(float)
    for i in range(data.shape[2]):
        p2, p98 = np.percentile(data[:, :, i], (2, 98))
        data[:, :, i] = exposure.rescale_intensity(data[:, :, i],
                                                      in_range=(p2, p98))
    axarr[0].imshow(data[:,:,3])
    axarr[0].set_title("Satellite image")

    a=axarr[1]
    values = np.unique(data2.ravel())
    im = axarr[1].imshow(data2[:,:,0].astype("uint8"))
    a.set_title("Labelled image")
    colors = [im.cmap(im.norm(value)) for value in values] 
    data2 = ["Background", "Landslide footprints"]
    patches = [mpatches.Patch(color=colors[i], label=j) for i, j in zip(range(len(values)), data2)]
    plt.legend(handles=patches, bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0. )

visualise_data(image_list[sample_image],label_list[sample_label])

# %% [markdown]
# ## Design patches, encode into categorical data, remove zero patches, and data augmentations

# %% [markdown]
# ### Generate Patches and encode

# %%
def gridwise_sample(imgarray, patchsize):

    """Extract sample patches of size patchsize x patchsize from an image (imgarray) in a gridwise manner.
    """
    nrows, ncols, nbands = imgarray.shape
    patchsamples = np.zeros(shape=(0, patchsize, patchsize, nbands),
                            dtype=imgarray.dtype)
    for i in range(int(nrows/patchsize)):
        for j in range(int(ncols/patchsize)):
            tocat = imgarray[i*patchsize:(i+1)*patchsize,
                             j*patchsize:(j+1)*patchsize, :]
            tocat = np.expand_dims(tocat, axis=0)
            patchsamples = np.concatenate((patchsamples, tocat),
                                          axis=0)
    return patchsamples

# %%
# FOR GENERATING TRAINING SITES

PATCHSIZE = 128 
NBANDS = image_list["image_2019_T18"].shape[-1]

Xtrain = np.zeros(shape=(0, PATCHSIZE, PATCHSIZE, NBANDS), dtype=np.float32)
Ytrain = np.zeros(shape=(0, PATCHSIZE, PATCHSIZE, 1), dtype=np.float32)

# Sample each training tile systematically in a gridwise manner
train_areas = ["image_2019_T14", "image_2019_T18"] # Transfer learn and fine-tune on the associated images here

for area in train_areas:
    X_toadd = gridwise_sample(image_list[area], PATCHSIZE)
    Y_toadd = gridwise_sample(label_list[area], PATCHSIZE)
    Xtrain = np.concatenate((Xtrain, X_toadd), axis=0)
    Ytrain = np.concatenate((Ytrain, Y_toadd), axis=0)

print(np.unique(Ytrain))
# Encode all landslide and background labels into their respective classes "0" and "1" (Categorical)
Ytrain[Ytrain==0] = 0
# Ytrain[Ytrain==-1] = 0
Ytrain[Ytrain==255] = 1
print(np.unique(Ytrain))

print("There are %i number of training patches" % (Xtrain.shape[0]))
# Out:
# [  0. 255.]
# [0. 1.]
# There are 600 number of training patches

# %%
#CIEW for training patches
bd_px=len(Ytrain[Ytrain==1])/(len(Ytrain[Ytrain==1])+len(Ytrain[Ytrain==0]))
bg_px=len(Ytrain[Ytrain==0])/(len(Ytrain[Ytrain==1])+len(Ytrain[Ytrain==0]))

print("Pixel percentage of landslides = " + str(bd_px* 100)+ " %") 
print("Pixel percentage of background = " + str(bg_px* 100)+ " %")
# Out:
# Pixel percentage of landslides = 5.390391031901041 %
# Pixel percentage of background = 94.60960896809895 %

# %%
Xtrain, Xtest, Ytrain, Ytest = train_test_split(Xtrain, Ytrain, test_size=0.50, random_state=42)

# %%
#CIEW for test patches
bd_px=len(Ytest[Ytest==1])/(len(Ytest[Ytest==1])+len(Ytest[Ytest==0]))
bg_px=len(Ytest[Ytest==0])/(len(Ytest[Ytest==1])+len(Ytest[Ytest==0]))

print("Pixel percentage of landslides = " + str(bd_px* 100) + " %") 
print("Pixel percentage of background = " + str(bg_px* 100)+ " %")
# Out:
# Pixel percentage of landslides = 5.513231682054924 %
# Pixel percentage of background = 94.48676831794508 %

# %% [markdown]
# ### Remove Zero Patches

# %%
def remove_zeros(images_array,masks_array):
    
    all_zeros = []
    for i in range(masks_array.shape[0]):
        if masks_array[i].max() == 0:
            all_zeros.append(i)
    print("There are: {} arrays with just 0 values, and {} arrays with non zero values ".format(len(all_zeros), (
                images_array.shape[0] - len(all_zeros))))
    images = []
    masks = []
    for i in range(images_array.shape[0]):
        if i not in all_zeros:
            images.append(images_array[i])
            masks.append(masks_array[i])

    # Convert to array
    images = np.array(images, dtype="float64")
    masks = np.array(masks, dtype="float32")
    print("Image shape: {}, Mask shape: {}".format(images.shape, masks.shape))
    return images, masks

# %%
X_train, Y_train = remove_zeros(Xtrain, Ytrain)

print("----"*15)

X_test, Y_test = remove_zeros(Xtest, Ytest)

print("----"*15)

print("There are %i number of training patches" % (X_train.shape[0]))
print("There are %i number of testing patches" % (X_test.shape[0]))
# Out:
# There are: 97 arrays with just 0 values, and 305 arrays with non zero values
# Image shape: (305, 128, 128, 5), Mask shape: (305, 128, 128, 1)
# ------------------------------------------------------------
# There are: 53 arrays with just 0 values, and 145 arrays with non zero values
# Image shape: (145, 128, 128, 5), Mask shape: (145, 128, 128, 1)
# ------------------------------------------------------------
# There are 305 number of training patches
# There are 145 number of testing patches

# %%
#CIEW for training patches
bd_px=len(Y_train[Y_train==1])/(len(Y_train[Y_train==1])+len(Y_train[Y_train==0]))
bg_px=len(Y_train[Y_train==0])/(len(Y_train[Y_train==1])+len(Y_train[Y_train==0]))

print("Pixel percentage of landslides = " + str(bd_px* 100)+ " %") 
print("Pixel percentage of background = " + str(bg_px* 100)+ " %")
# Out:
# Pixel percentage of landslides = 7.024966380635246 %
# Pixel percentage of background = 92.97503361936475 %

# %%
#CIEW for testing patches
bd_px=len(Y_test[Y_test==1])/(len(Y_test[Y_test==1])+len(Y_test[Y_test==0]))
bg_px=len(Y_test[Y_test==0])/(len(Y_test[Y_test==1])+len(Y_test[Y_test==0]))

print("Pixel percentage of landslides = " + str(bd_px* 100)+ " %") 
print("Pixel percentage of background = " + str(bg_px* 100)+ " %")
# Out:
# Pixel percentage of landslides = 7.528412917564656 %
# Pixel percentage of background = 92.47158708243535 %

# %% [markdown]
# ### Data augmentations

# %%
print(f'Shape of the image collection before augmentation: {X_train.shape}')
print(f'Shape of the label collection before augmentation: {Y_train.shape}')

# Geometric
seq = iaa.Sequential([
    iaa.Fliplr(1)
])
seq1 = iaa.Sequential([
    iaa.Flipud(1)
])

seq2 = iaa.Sequential([
    iaa.ShearX((-20, 20))
])

seq3 = iaa.Sequential([
    iaa.ShearY((-20, 20))
])

seq4 = iaa.Sequential([
    iaa.Rotate((-45, 45))
])

# Horizontal Flip
X_aug, Y_aug = seq(images=X_train, heatmaps=Y_train)
# Vertical Flip
X_aug1, Y_aug1 = seq1(images=X_train, heatmaps=Y_train)
# Shear X
X_aug2, Y_aug2 = seq2(images=X_train, heatmaps=Y_train)
# Shear Y
X_aug3, Y_aug3 = seq3(images=X_train, heatmaps=Y_train)
# Rotate +-45
X_aug4, Y_aug4 = seq4(images=X_train, heatmaps=Y_train)

# X_train = np.concatenate((X_train, X_aug1, X_aug2, X_aug3,  X_aug4), axis=0)
# Y_train = np.concatenate((Y_train, Y_aug1, Y_aug2, Y_aug3,  Y_aug4), axis=0)

# Radiometric
seq5 = iaa.Sequential([
    iaa.GaussianBlur(sigma=(0.0, 3.0))
])

seq6 = iaa.Sequential([
    iaa.Sharpen(alpha=(0.0, 1.0), lightness=(0.75, 2.0))
])

# seq7 = iaa.Sequential([
#     iaa.AdditiveGaussianNoise(scale=(0, 0.2*255))
# ])

# Blur
X_aug5, Y_aug5 = seq5(images=X_train, heatmaps=Y_train)
# Sharp
X_aug6, Y_aug6 = seq6(images=X_train, heatmaps=Y_train)
# # Noise
# X_aug7, Y_aug7 = seq7(images=X_train.astype(np.uint8), heatmaps=Y_train)

X_train = np.concatenate((X_train, X_aug1, X_aug2, X_aug3,  X_aug4, X_aug5 ,X_aug6), axis=0)
Y_train = np.concatenate((Y_train, Y_aug1, Y_aug2, Y_aug3,  Y_aug4, Y_aug5 ,Y_aug6), axis=0)

print("--"*20)
print(f'Shape of the image collection after augmentation: {X_train.shape}')
print(f'Shape of the label collection after augmentation: {Y_train.shape}')
# Out:
# Shape of the image collection before augmentation: (305, 128, 128, 5)
# Shape of the label collection before augmentation: (305, 128, 128, 1)
# ----------------------------------------
# Shape of the image collection after augmentation: (2135, 128, 128, 5)
# Shape of the label collection after augmentation: (2135, 128, 128, 1)

# %%
print("There are %i number of training patches" % (X_train.shape[0]))

#CIEW for training patches
bd_px=len(Y_train[Y_train==1])/(len(Y_train[Y_train==1])+len(Y_train[Y_train==0]))
bg_px=len(Y_train[Y_train==0])/(len(Y_train[Y_train==1])+len(Y_train[Y_train==0]))

print("----"*15)

print("Pixel percentage of landslides = " + str(bd_px* 100)+ " %") 
print("Pixel percentage of background = " + str(bg_px* 100)+ " %")
# Out:
# There are 2135 number of training patches
# ------------------------------------------------------------
# Pixel percentage of landslides = 6.253001940528493 %
# Pixel percentage of background = 93.74699805947151 %

# %% [markdown]
# ## Define loss functions and metrics for various accuracies

# %%
# Losses

# Tversky
def tversky(y_true, y_pred):
    
    y_true_pos = K.flatten(y_true)
    y_pred_pos = K.flatten(y_pred)
    true_pos = K.sum(y_true_pos * y_pred_pos)
    false_neg = K.sum(y_true_pos * (1-y_pred_pos))
    false_pos = K.sum((1-y_true_pos)*y_pred_pos)
    alpha = 0.7
    return (true_pos + K.epsilon())/(true_pos + alpha*false_neg + (1-alpha)*false_pos + K.epsilon())

def tversky_loss(y_true, y_pred, alpha=0.3, beta=0.7):
  
    """
    Function to calculate the Tversky loss for imbalanced data
    :param prediction: the logits
    :param ground_truth: the segmentation ground_truth
    :param alpha: weight of false negatives
    :param beta: weight of false positives
    :param weight_map:
    :return: the loss
    """
    '''
    EPSILON = 0.00001 (default)
    '''
    y_true_pos = K.flatten(y_true)
    y_pred_pos = K.flatten(y_pred)
    # TP
    true_pos = K.sum(y_true_pos * y_pred_pos)
    # FN
    false_neg = K.sum(y_true_pos * (1-y_pred_pos))
    # FP
    false_pos = K.sum((1-y_true_pos) * y_pred_pos)
    return 1 - (true_pos + K.epsilon())/(true_pos + alpha * false_neg + beta * false_pos + K.epsilon())

# Focal Tversky

def focal_tversky(y_true,y_pred):
    
    pt_1 = tversky(y_true, y_pred)
    gamma = 0.75
    return K.pow((1-pt_1), gamma)

# %%
def accuracy(y_true, y_pred, threshold=0.5):
    """compute accuracy"""
    #y_t = y_true[...,0]
    #y_t = y_t[...,np.newaxis]
    y_pred = K.round(y_pred +0.5 - threshold)
    return K.equal(K.round(y_true), K.round(y_pred))

# K.round() returns the Element-wise rounding to the closest integer!!!
# So the threshold to determine a true positive is set here!!!!!
# K.sum() returns a single integer output unlike the K.round() which returns an element-wise matrix

def recall_m(y_true, y_pred):
    #y_t = y_true[...,0]
    #y_t = y_t[...,np.newaxis]
    tp = true_positives(y_true, y_pred)
    fn = false_negatives(y_true, y_pred)
    recall = K.sum(tp) / (K.sum(tp) + K.sum(fn)+ K.epsilon())
    return recall

def precision_m(y_true, y_pred):
    #y_t = y_true[...,0]
    #y_t = y_t[...,np.newaxis]
    tp = true_positives(y_true, y_pred)
    fp = false_positives(y_true, y_pred)
    precision = K.sum(tp) / (K.sum(tp) + K.sum(fp)+ K.epsilon())
    return precision

def f1_m(y_true, y_pred):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# Collect all the metrics
metrics = [accuracy, precision_m, recall_m, f1_m]

# %% [markdown]
# ## Training the model

# %%
pretrained_weights = "Checkpoints/weights.196-0.06.hdf5" # Define the path to which you have a trained model ready.

# Number of epochs
NUMBER_EPOCHS = 70

# List of hyperparameters
lr = [1e-4]
batch_size_list = [16]
filters = [32]

# Dictionary of results
results = {
           "filters": [],
           "learning_rate": [],
           "batch_size": [],
           "loss": [],
           "accuracy": [],
           "precision": [],
           "recall": [],
           "f1": []
           }

# Multi-scales for training and testing
gt1 = Y_train[:,::8,::8,:]
gt2 = Y_train[:,::4,::4,:]
gt3 = Y_train[:,::2,::2,:]
gt4 = Y_train
gt_train = [gt1,gt2,gt3,gt4]

# gv1 = Yval[:,::8,::8,:]
# gv2 = Yval[:,::4,::4,:]
# gv3 = Yval[:,::2,::2,:]
# gv4 = Yval
# gv_val = [gv1,gv2,gv3,gv4]

gte1 = Y_test[:,::8,::8,:]
gte2 = Y_test[:,::4,::4,:]
gte3 = Y_test[:,::2,::2,:]
gte4 = Y_test
gt_test = [gte1,gte2,gte3,gte4]


for learning_rate in lr:

    for batch_size in batch_size_list:

        for no_filters in filters:

            # Define the model architecture
            def ms_attUNet(lr,filtersFirstLayer, input_size = (PATCHSIZE, PATCHSIZE, NBANDS)):
    
                img_input = Input(shape=input_size, name='input_scale1')
                scale_img_2 = AveragePooling2D(pool_size=(2, 2), name='input_scale2')(img_input)
                scale_img_3 = AveragePooling2D(pool_size=(2, 2), name='input_scale3')(scale_img_2)
                scale_img_4 = AveragePooling2D(pool_size=(2, 2), name='input_scale4')(scale_img_3)

                conv1 = UnetConv2D(img_input, filtersFirstLayer, is_batchnorm=True, name='conv1')
                pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

                input2 = Conv2D(filtersFirstLayer*2, (3, 3), padding='same', activation='relu', name='conv_scale2')(scale_img_2)
                input2 = concatenate([input2, pool1], axis=3)
                conv2 = UnetConv2D(input2, filtersFirstLayer*2, is_batchnorm=True, name='conv2')
                pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

                input3 = Conv2D(filtersFirstLayer*4, (3, 3), padding='same', activation='relu', name='conv_scale3')(scale_img_3)
                input3 = concatenate([input3, pool2], axis=3)
                conv3 = UnetConv2D(input3, filtersFirstLayer*4, is_batchnorm=True, name='conv3')
                pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

                input4 = Conv2D(filtersFirstLayer*8, (3, 3), padding='same', activation='relu', name='conv_scale4')(scale_img_4)
                input4 = concatenate([input4, pool3], axis=3)
                conv4 = UnetConv2D(input4, filtersFirstLayer*2, is_batchnorm=True, name='conv4')
                pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)

                center = UnetConv2D(pool4, filtersFirstLayer*16, is_batchnorm=True, name='center')

                g1 = UnetGatingSignal(center, is_batchnorm=True, name='g1')
                attn1 = AttnGatingBlock(conv4, g1, filtersFirstLayer*4, '_1')
                up1 = concatenate([Conv2DTranspose(filtersFirstLayer, (3,3), strides=(2,2), padding='same', activation='relu', kernel_initializer=kinit)(center), attn1], name='up1')

                g2 = UnetGatingSignal(up1, is_batchnorm=True, name='g2')
                attn2 = AttnGatingBlock(conv3, g2, filtersFirstLayer*2, '_2')
                up2 = concatenate([Conv2DTranspose(filtersFirstLayer*2, (3,3), strides=(2,2), padding='same', activation='relu', kernel_initializer=kinit)(up1), attn2], name='up2')

                g3 = UnetGatingSignal(up1, is_batchnorm=True, name='g3')
                attn3 = AttnGatingBlock(conv2, g3, filtersFirstLayer, '_3')
                up3 = concatenate([Conv2DTranspose(filtersFirstLayer, (3,3), strides=(2,2), padding='same', activation='relu', kernel_initializer=kinit)(up2), attn3], name='up3')

                up4 = concatenate([Conv2DTranspose(filtersFirstLayer, (3,3), strides=(2,2), padding='same', activation='relu', kernel_initializer=kinit)(up3), conv1], name='up4')

                conv6 = UnetConv2D(up1, filtersFirstLayer*8, is_batchnorm=True, name='conv6')
                conv7 = UnetConv2D(up2, filtersFirstLayer*4, is_batchnorm=True, name='conv7')
                conv8 = UnetConv2D(up3, filtersFirstLayer*2, is_batchnorm=True, name='conv8')
                conv9 = UnetConv2D(up4, filtersFirstLayer, is_batchnorm=True, name='conv9')

                out6 = Conv2D(1, (1, 1), activation='sigmoid', name='pred1')(conv6)
                out7 = Conv2D(1, (1, 1), activation='sigmoid', name='pred2')(conv7)
                out8 = Conv2D(1, (1, 1), activation='sigmoid', name='pred3')(conv8)
                out9 = Conv2D(1, (1, 1), activation='sigmoid', name='final')(conv9)

                model = Model(inputs=[img_input], outputs=[out6, out7, out8, out9])

                loss = {'pred1':focal_tversky,
                        'pred2':focal_tversky,
                        'pred3':focal_tversky,
                        'final':losses.tversky_loss}

                loss_weights = {'pred1':1,
                                'pred2':1,
                                'pred3':1,
                                'final':1}
                    
                #model.compile(optimizer=Adam(lr = lr), loss=loss, loss_weights=loss_weights,
                 #             metrics=metrics)
                model.summary()

                return model
            
            # Load the model
            model = ms_attUNet(lr=learning_rate, filtersFirstLayer=no_filters, input_size=(PATCHSIZE, PATCHSIZE, NBANDS))
            
            # Load the pre-trained model weights
            model.load_weights(pretrained_weights)
            
            # Set the layers that you want to freeze. Training will be performed on the remaining layers.
            for layer in model.layers:
                if layer.name == 'pool4': # 'pool4' is the last layer of the encoder. We train only the bridge and decoder block. 
                    break
                layer.trainable = False
                
            model.compile(optimizer=Adam(lr = lr), loss=loss, loss_weights=loss_weights,
                              metrics=metrics)
                              
            print("---------------------------------------------------------------------------------------------------------------------")

            print("Initialising in 3..........2..........1......................................")

            print(f'Training on {X_train.shape[0]} images with learning rate {learning_rate}, batch size {batch_size}, and number of filters {no_filters}')

            # Checkpoint for saving the weights 
            checkpoint_path = os.path.join('Checkpoints/','weights.{epoch:02d}-{val_final_loss:.2f}.hdf5')

            # Create a callback that saves the model's weights at every epoch
            callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                            save_weights_only=True, save_best_only=True, monitor="val_final_loss", mode = "min",
                                                            verbose=1)

            # Create a callback to reduce the learning rate using the ReduceLROnPlateau function
            reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor="val_final_loss", factor=0.33, patience=15, mode="min")
            
            early_stop = tf.keras.callbacks.EarlyStopping(monitor = 'val_final_loss', # what is the metric to measure
                              patience = 40, # how many epochs to continue running the model after seeing an increase in val_loss
                              restore_best_weights = True) # update the mod
            
            # Compile the checkpoints and other settings as a callback
            callback_list = [callback, reduce_lr, early_stop]

            history = model.fit(X_train, gt_train,
                        epochs=NUMBER_EPOCHS,
                        batch_size=batch_size,
                        validation_split = 0.3,
                        # validation_data=(Xval, gv_val),
                        callbacks=callback_list,
                        verbose=2) 

            ########      EVALUATION      ###########
            tf.keras.backend.clear_session()
            evaluate = model.evaluate(X_test, gt_test, verbose=2)

            ########      Saving results      ###########
            results["filters"].append(no_filters)
            results["learning_rate"].append(learning_rate)
            results["batch_size"].append(batch_size)
            results["loss"].append(evaluate[16])
            results["accuracy"].append(evaluate[17])
            results["precision"].append(evaluate[18])
            results["recall"].append(evaluate[19])
            results["f1"].append(evaluate[20])

            # Convert results to a pandas dataframe
            results_df = pd.DataFrame(results)

            # Export as a CSV
            save_path_results = f'Results in CSV'
            if not os.path.exists(save_path_results):
                os.makedirs(save_path_results)

            results_df.to_csv(f'{save_path_results}/learning_rate_{learning_rate}_batch_size_{batch_size}_filters_{no_filters}.csv', index=False)

            tf.compat.v1.reset_default_graph()

            print(f"The metrics for the test set with learning rate {learning_rate},  filters {no_filters}, and batch size {batch_size} is {evaluate}")
            print("__________________________________________________________________________________________________________________________________________________________________________")
# Out:
# /usr/local/lib/python3.8/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_scale1 (InputLayer)      [(None, 128, 128, 5  0           []
#                                 )]
#
#  conv1_1 (Conv2D)               (None, 128, 128, 32  1472        ['input_scale1[0][0]']
#                                 )
#
#  conv1_1_bn (BatchNormalization  (None, 128, 128, 32  128        ['conv1_1[0][0]']
#  )                              )
#
#  conv1_1_act (Activation)       (None, 128, 128, 32  0           ['conv1_1_bn[0][0]']
#                                 )
#
#  conv1_2 (Conv2D)               (None, 128, 128, 32  9248        ['conv1_1_act[0][0]']
#                                 )
#
#  conv1_2_bn (BatchNormalization  (None, 128, 128, 32  128        ['conv1_2[0][0]']
#  )                              )
#
#  input_scale2 (AveragePooling2D  (None, 64, 64, 5)   0           ['input_scale1[0][0]']
#  )
#
#  conv1_2_act (Activation)       (None, 128, 128, 32  0           ['conv1_2_bn[0][0]']
#                                 )
#
#  conv_scale2 (Conv2D)           (None, 64, 64, 64)   2944        ['input_scale2[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 64, 64, 32)   0           ['conv1_2_act[0][0]']
#
#  concatenate (Concatenate)      (None, 64, 64, 96)   0           ['conv_scale2[0][0]',
#                                                                   'max_pooling2d[0][0]']
#
#  conv2_1 (Conv2D)               (None, 64, 64, 64)   55360       ['concatenate[0][0]']
#
#  conv2_1_bn (BatchNormalization  (None, 64, 64, 64)  256         ['conv2_1[0][0]']
#  )
#
#  conv2_1_act (Activation)       (None, 64, 64, 64)   0           ['conv2_1_bn[0][0]']
#
#  conv2_2 (Conv2D)               (None, 64, 64, 64)   36928       ['conv2_1_act[0][0]']
#
#  conv2_2_bn (BatchNormalization  (None, 64, 64, 64)  256         ['conv2_2[0][0]']
#  )
#
#  input_scale3 (AveragePooling2D  (None, 32, 32, 5)   0           ['input_scale2[0][0]']
#  )
#
#  conv2_2_act (Activation)       (None, 64, 64, 64)   0           ['conv2_2_bn[0][0]']
#
#  conv_scale3 (Conv2D)           (None, 32, 32, 128)  5888        ['input_scale3[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 32, 32, 64)  0           ['conv2_2_act[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 32, 32, 192)  0           ['conv_scale3[0][0]',
#                                                                   'max_pooling2d_1[0][0]']
#
#  conv3_1 (Conv2D)               (None, 32, 32, 128)  221312      ['concatenate_1[0][0]']
#
#  conv3_1_bn (BatchNormalization  (None, 32, 32, 128)  512        ['conv3_1[0][0]']
#  )
#
#  conv3_1_act (Activation)       (None, 32, 32, 128)  0           ['conv3_1_bn[0][0]']
#
#  conv3_2 (Conv2D)               (None, 32, 32, 128)  147584      ['conv3_1_act[0][0]']
#
#  conv3_2_bn (BatchNormalization  (None, 32, 32, 128)  512        ['conv3_2[0][0]']
#  )
#
#  input_scale4 (AveragePooling2D  (None, 16, 16, 5)   0           ['input_scale3[0][0]']
#  )
#
#  conv3_2_act (Activation)       (None, 32, 32, 128)  0           ['conv3_2_bn[0][0]']
#
#  conv_scale4 (Conv2D)           (None, 16, 16, 256)  11776       ['input_scale4[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 16, 16, 128)  0          ['conv3_2_act[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 16, 16, 384)  0           ['conv_scale4[0][0]',
#                                                                   'max_pooling2d_2[0][0]']
#
#  conv4_1 (Conv2D)               (None, 16, 16, 64)   221248      ['concatenate_2[0][0]']
#
#  conv4_1_bn (BatchNormalization  (None, 16, 16, 64)  256         ['conv4_1[0][0]']
#  )
#
#  conv4_1_act (Activation)       (None, 16, 16, 64)   0           ['conv4_1_bn[0][0]']
#
#  conv4_2 (Conv2D)               (None, 16, 16, 64)   36928       ['conv4_1_act[0][0]']
#
#  conv4_2_bn (BatchNormalization  (None, 16, 16, 64)  256         ['conv4_2[0][0]']
#  )
#
#  conv4_2_act (Activation)       (None, 16, 16, 64)   0           ['conv4_2_bn[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 8, 8, 64)    0           ['conv4_2_act[0][0]']
#
#  center_1 (Conv2D)              (None, 8, 8, 512)    295424      ['max_pooling2d_3[0][0]']
#
#  center_1_bn (BatchNormalizatio  (None, 8, 8, 512)   2048        ['center_1[0][0]']
#  n)
#
#  center_1_act (Activation)      (None, 8, 8, 512)    0           ['center_1_bn[0][0]']
#
#  center_2 (Conv2D)              (None, 8, 8, 512)    2359808     ['center_1_act[0][0]']
#
#  center_2_bn (BatchNormalizatio  (None, 8, 8, 512)   2048        ['center_2[0][0]']
#  n)
#
#  center_2_act (Activation)      (None, 8, 8, 512)    0           ['center_2_bn[0][0]']
#
#  g1_conv (Conv2D)               (None, 8, 8, 512)    262656      ['center_2_act[0][0]']
#
#  g1_bn (BatchNormalization)     (None, 8, 8, 512)    2048        ['g1_conv[0][0]']
#
#  g1_act (Activation)            (None, 8, 8, 512)    0           ['g1_bn[0][0]']
#
#  conv2d (Conv2D)                (None, 8, 8, 128)    65664       ['g1_act[0][0]']
#
#  g_up_1 (Conv2DTranspose)       (None, 8, 8, 128)    147584      ['conv2d[0][0]']
#
#  xl_1 (Conv2D)                  (None, 8, 8, 128)    32896       ['conv4_2_act[0][0]']
#
#  add (Add)                      (None, 8, 8, 128)    0           ['g_up_1[0][0]',
#                                                                   'xl_1[0][0]']
#
#  activation (Activation)        (None, 8, 8, 128)    0           ['add[0][0]']
#
#  psi_1 (Conv2D)                 (None, 8, 8, 1)      129         ['activation[0][0]']
#
#  activation_1 (Activation)      (None, 8, 8, 1)      0           ['psi_1[0][0]']
#
#  up_sampling2d (UpSampling2D)   (None, 16, 16, 1)    0           ['activation_1[0][0]']
#
#  psi_up_1 (Lambda)              (None, 16, 16, 64)   0           ['up_sampling2d[0][0]']
#
#  q_attn_1 (Multiply)            (None, 16, 16, 64)   0           ['psi_up_1[0][0]',
#                                                                   'conv4_2_act[0][0]']
#
#  q_attn_conv_1 (Conv2D)         (None, 16, 16, 64)   4160        ['q_attn_1[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 16, 16, 32)  147488      ['center_2_act[0][0]']
#  ose)
#
#  q_attn_bn_1 (BatchNormalizatio  (None, 16, 16, 64)  256         ['q_attn_conv_1[0][0]']
#  n)
#
#  up1 (Concatenate)              (None, 16, 16, 96)   0           ['conv2d_transpose[0][0]',
#                                                                   'q_attn_bn_1[0][0]']
#
#  g2_conv (Conv2D)               (None, 16, 16, 96)   9312        ['up1[0][0]']
#
#  g2_bn (BatchNormalization)     (None, 16, 16, 96)   384         ['g2_conv[0][0]']
#
#  g2_act (Activation)            (None, 16, 16, 96)   0           ['g2_bn[0][0]']
#
#  g3_conv (Conv2D)               (None, 16, 16, 96)   9312        ['up1[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 16, 16, 64)   6208        ['g2_act[0][0]']
#
#  g3_bn (BatchNormalization)     (None, 16, 16, 96)   384         ['g3_conv[0][0]']
#
#  g_up_2 (Conv2DTranspose)       (None, 16, 16, 64)   36928       ['conv2d_1[0][0]']
#
#  xl_2 (Conv2D)                  (None, 16, 16, 64)   32832       ['conv3_2_act[0][0]']
#
#  g3_act (Activation)            (None, 16, 16, 96)   0           ['g3_bn[0][0]']
#
#  add_1 (Add)                    (None, 16, 16, 64)   0           ['g_up_2[0][0]',
#                                                                   'xl_2[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 16, 16, 32)   3104        ['g3_act[0][0]']
#
#  activation_2 (Activation)      (None, 16, 16, 64)   0           ['add_1[0][0]']
#
#  g_up_3 (Conv2DTranspose)       (None, 32, 32, 32)   9248        ['conv2d_2[0][0]']
#
#  xl_3 (Conv2D)                  (None, 32, 32, 32)   8224        ['conv2_2_act[0][0]']
#
#  psi_2 (Conv2D)                 (None, 16, 16, 1)    65          ['activation_2[0][0]']
#
#  add_2 (Add)                    (None, 32, 32, 32)   0           ['g_up_3[0][0]',
#                                                                   'xl_3[0][0]']
#
#  activation_3 (Activation)      (None, 16, 16, 1)    0           ['psi_2[0][0]']
#
#  activation_4 (Activation)      (None, 32, 32, 32)   0           ['add_2[0][0]']
#
#  up_sampling2d_1 (UpSampling2D)  (None, 32, 32, 1)   0           ['activation_3[0][0]']
#
#  psi_3 (Conv2D)                 (None, 32, 32, 1)    33          ['activation_4[0][0]']
#
#  psi_up_2 (Lambda)              (None, 32, 32, 128)  0           ['up_sampling2d_1[0][0]']
#
#  activation_5 (Activation)      (None, 32, 32, 1)    0           ['psi_3[0][0]']
#
#  q_attn_2 (Multiply)            (None, 32, 32, 128)  0           ['psi_up_2[0][0]',
#                                                                   'conv3_2_act[0][0]']
#
#  up_sampling2d_2 (UpSampling2D)  (None, 64, 64, 1)   0           ['activation_5[0][0]']
#
#  q_attn_conv_2 (Conv2D)         (None, 32, 32, 128)  16512       ['q_attn_2[0][0]']
#
#  psi_up_3 (Lambda)              (None, 64, 64, 64)   0           ['up_sampling2d_2[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 32, 32, 64)  55360       ['up1[0][0]']
#  spose)
#
#  q_attn_bn_2 (BatchNormalizatio  (None, 32, 32, 128)  512        ['q_attn_conv_2[0][0]']
#  n)
#
#  q_attn_3 (Multiply)            (None, 64, 64, 64)   0           ['psi_up_3[0][0]',
#                                                                   'conv2_2_act[0][0]']
#
#  up2 (Concatenate)              (None, 32, 32, 192)  0           ['conv2d_transpose_1[0][0]',
#                                                                   'q_attn_bn_2[0][0]']
#
#  q_attn_conv_3 (Conv2D)         (None, 64, 64, 64)   4160        ['q_attn_3[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 64, 64, 32)  55328       ['up2[0][0]']
#  spose)
#
#  q_attn_bn_3 (BatchNormalizatio  (None, 64, 64, 64)  256         ['q_attn_conv_3[0][0]']
#  n)
#
#  up3 (Concatenate)              (None, 64, 64, 96)   0           ['conv2d_transpose_2[0][0]',
#                                                                   'q_attn_bn_3[0][0]']
#
#  conv2d_transpose_3 (Conv2DTran  (None, 128, 128, 32  27680      ['up3[0][0]']
#  spose)                         )
#
#  up4 (Concatenate)              (None, 128, 128, 64  0           ['conv2d_transpose_3[0][0]',
#                                 )                                 'conv1_2_act[0][0]']
#
#  conv6_1 (Conv2D)               (None, 16, 16, 256)  221440      ['up1[0][0]']
#
#  conv7_1 (Conv2D)               (None, 32, 32, 128)  221312      ['up2[0][0]']
#
#  conv8_1 (Conv2D)               (None, 64, 64, 64)   55360       ['up3[0][0]']
#
#  conv9_1 (Conv2D)               (None, 128, 128, 32  18464       ['up4[0][0]']
#                                 )
#
#  conv6_1_bn (BatchNormalization  (None, 16, 16, 256)  1024       ['conv6_1[0][0]']
#  )
#
#  conv7_1_bn (BatchNormalization  (None, 32, 32, 128)  512        ['conv7_1[0][0]']
#  )
#
#  conv8_1_bn (BatchNormalization  (None, 64, 64, 64)  256         ['conv8_1[0][0]']
#  )
#
#  conv9_1_bn (BatchNormalization  (None, 128, 128, 32  128        ['conv9_1[0][0]']
#  )                              )
#
#  conv6_1_act (Activation)       (None, 16, 16, 256)  0           ['conv6_1_bn[0][0]']
#
#  conv7_1_act (Activation)       (None, 32, 32, 128)  0           ['conv7_1_bn[0][0]']
#
#  conv8_1_act (Activation)       (None, 64, 64, 64)   0           ['conv8_1_bn[0][0]']
#
#  conv9_1_act (Activation)       (None, 128, 128, 32  0           ['conv9_1_bn[0][0]']
#                                 )
#
#  conv6_2 (Conv2D)               (None, 16, 16, 256)  590080      ['conv6_1_act[0][0]']
#
#  conv7_2 (Conv2D)               (None, 32, 32, 128)  147584      ['conv7_1_act[0][0]']
#
#  conv8_2 (Conv2D)               (None, 64, 64, 64)   36928       ['conv8_1_act[0][0]']
#
#  conv9_2 (Conv2D)               (None, 128, 128, 32  9248        ['conv9_1_act[0][0]']
#                                 )
#
#  conv6_2_bn (BatchNormalization  (None, 16, 16, 256)  1024       ['conv6_2[0][0]']
#  )
#
#  conv7_2_bn (BatchNormalization  (None, 32, 32, 128)  512        ['conv7_2[0][0]']
#  )
#
#  conv8_2_bn (BatchNormalization  (None, 64, 64, 64)  256         ['conv8_2[0][0]']
#  )
#
#  conv9_2_bn (BatchNormalization  (None, 128, 128, 32  128        ['conv9_2[0][0]']
#  )                              )
#
#  conv6_2_act (Activation)       (None, 16, 16, 256)  0           ['conv6_2_bn[0][0]']
#
#  conv7_2_act (Activation)       (None, 32, 32, 128)  0           ['conv7_2_bn[0][0]']
#
#  conv8_2_act (Activation)       (None, 64, 64, 64)   0           ['conv8_2_bn[0][0]']
#
#  conv9_2_act (Activation)       (None, 128, 128, 32  0           ['conv9_2_bn[0][0]']
#                                 )
#
#  pred1 (Conv2D)                 (None, 16, 16, 1)    257         ['conv6_2_act[0][0]']
#
#  pred2 (Conv2D)                 (None, 32, 32, 1)    129         ['conv7_2_act[0][0]']
#
#  pred3 (Conv2D)                 (None, 64, 64, 1)    65          ['conv8_2_act[0][0]']
#
#  final (Conv2D)                 (None, 128, 128, 1)  33          ['conv9_2_act[0][0]']
#
# ==================================================================================================
# Total params: 5,655,783
# Trainable params: 5,648,743
# Non-trainable params: 7,040
# __________________________________________________________________________________________________
# ---------------------------------------------------------------------------------------------------------------------
# Initialising in 3..........2..........1......................................
# Training on 2135 images with learning rate 0.0001, batch size 16, and number of filters 32
# 2022-03-07 11:44:23.533170: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 629473280 exceeds 10% of free system memory.
# 2022-03-07 11:44:23.873115: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 629473280 exceeds 10% of free system memory.
# Epoch 1/70
# 2022-03-07 11:44:38.442619: W tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 10.2.300, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# Epoch 00001: val_final_loss improved from inf to 0.65683, saving model to Checkpoints/weights.01-0.66.hdf5
# 121/121 - 65s - loss: 2.5927 - pred1_loss: 0.6470 - pred2_loss: 0.6323 - pred3_loss: 0.6430 - final_loss: 0.6703 - pred1_accuracy: 0.8259 - pred1_precision_m: 0.2577 - pred1_recall_m: 0.7562 - pred1_f1_m: 0.3766 - pred2_accuracy: 0.8304 - pred2_precision_m: 0.2759 - pred2_recall_m: 0.8370 - pred2_f1_m: 0.4071 - pred3_accuracy: 0.8427 - pred3_precision_m: 0.2850 - pred3_recall_m: 0.8443 - pred3_f1_m: 0.4197 - final_accuracy: 0.7090 - final_precision_m: 0.2041 - final_recall_m: 0.9343 - final_f1_m: 0.3268 - val_loss: 2.6559 - val_pred1_loss: 0.6497 - val_pred2_loss: 0.6420 - val_pred3_loss: 0.7074 - val_final_loss: 0.6568 - val_pred1_accuracy: 0.8654 - val_pred1_precision_m: 0.3349 - val_pred1_recall_m: 0.7380 - val_pred1_f1_m: 0.4550 - val_pred2_accuracy: 0.8639 - val_pred2_precision_m: 0.3422 - val_pred2_recall_m: 0.8332 - val_pred2_f1_m: 0.4801 - val_pred3_accuracy: 0.8626 - val_pred3_precision_m: 0.3389 - val_pred3_recall_m: 0.8439 - val_pred3_f1_m: 0.4793 - val_final_accuracy: 0.7902 - val_final_precision_m: 0.2548 - val_final_recall_m: 0.9037 - val_final_f1_m: 0.3945 - lr: 1.0000e-04 - 65s/epoch - 540ms/step
# Epoch 2/70
#
# Epoch 00002: val_final_loss improved from 0.65683 to 0.59278, saving model to Checkpoints/weights.02-0.59.hdf5
# 121/121 - 35s - loss: 2.2409 - pred1_loss: 0.5555 - pred2_loss: 0.5391 - pred3_loss: 0.5513 - final_loss: 0.5949 - pred1_accuracy: 0.8915 - pred1_precision_m: 0.3543 - pred1_recall_m: 0.7676 - pred1_f1_m: 0.4783 - pred2_accuracy: 0.8991 - pred2_precision_m: 0.3798 - pred2_recall_m: 0.8185 - pred2_f1_m: 0.5126 - pred3_accuracy: 0.8969 - pred3_precision_m: 0.3768 - pred3_recall_m: 0.8417 - pred3_f1_m: 0.5149 - final_accuracy: 0.8441 - final_precision_m: 0.2899 - final_recall_m: 0.9179 - final_f1_m: 0.4357 - val_loss: 2.3674 - val_pred1_loss: 0.6003 - val_pred2_loss: 0.5652 - val_pred3_loss: 0.6092 - val_final_loss: 0.5928 - val_pred1_accuracy: 0.8317 - val_pred1_precision_m: 0.2905 - val_pred1_recall_m: 0.8459 - val_pred1_f1_m: 0.4300 - val_pred2_accuracy: 0.8869 - val_pred2_precision_m: 0.3870 - val_pred2_recall_m: 0.8241 - val_pred2_f1_m: 0.5220 - val_pred3_accuracy: 0.8876 - val_pred3_precision_m: 0.3885 - val_pred3_recall_m: 0.8240 - val_pred3_f1_m: 0.5227 - val_final_accuracy: 0.8440 - val_final_precision_m: 0.3213 - val_final_recall_m: 0.9039 - val_final_f1_m: 0.4688 - lr: 1.0000e-04 - 35s/epoch - 292ms/step
# Epoch 3/70
#
# Epoch 00003: val_final_loss improved from 0.59278 to 0.58612, saving model to Checkpoints/weights.03-0.59.hdf5
# 121/121 - 35s - loss: 2.1283 - pred1_loss: 0.5328 - pred2_loss: 0.5084 - pred3_loss: 0.5216 - final_loss: 0.5656 - pred1_accuracy: 0.9042 - pred1_precision_m: 0.3876 - pred1_recall_m: 0.7622 - pred1_f1_m: 0.5060 - pred2_accuracy: 0.9132 - pred2_precision_m: 0.4188 - pred2_recall_m: 0.8001 - pred2_f1_m: 0.5424 - pred3_accuracy: 0.9128 - pred3_precision_m: 0.4189 - pred3_recall_m: 0.8225 - pred3_f1_m: 0.5483 - final_accuracy: 0.8734 - final_precision_m: 0.3334 - final_recall_m: 0.9053 - final_f1_m: 0.4813 - val_loss: 2.2671 - val_pred1_loss: 0.5707 - val_pred2_loss: 0.5500 - val_pred3_loss: 0.5603 - val_final_loss: 0.5861 - val_pred1_accuracy: 0.8249 - val_pred1_precision_m: 0.2922 - val_pred1_recall_m: 0.8965 - val_pred1_f1_m: 0.4376 - val_pred2_accuracy: 0.8459 - val_pred2_precision_m: 0.3237 - val_pred2_recall_m: 0.9105 - val_pred2_f1_m: 0.4732 - val_pred3_accuracy: 0.8530 - val_pred3_precision_m: 0.3350 - val_pred3_recall_m: 0.9122 - val_pred3_f1_m: 0.4855 - val_final_accuracy: 0.7979 - val_final_precision_m: 0.2693 - val_final_recall_m: 0.9558 - val_final_f1_m: 0.4172 - lr: 1.0000e-04 - 35s/epoch - 293ms/step
# Epoch 4/70
#
# Epoch 00004: val_final_loss improved from 0.58612 to 0.53071, saving model to Checkpoints/weights.04-0.53.hdf5
# 121/121 - 36s - loss: 2.0361 - pred1_loss: 0.5115 - pred2_loss: 0.4850 - pred3_loss: 0.4973 - final_loss: 0.5423 - pred1_accuracy: 0.9122 - pred1_precision_m: 0.4139 - pred1_recall_m: 0.7765 - pred1_f1_m: 0.5314 - pred2_accuracy: 0.9211 - pred2_precision_m: 0.4484 - pred2_recall_m: 0.8075 - pred2_f1_m: 0.5674 - pred3_accuracy: 0.9205 - pred3_precision_m: 0.4470 - pred3_recall_m: 0.8264 - pred3_f1_m: 0.5711 - final_accuracy: 0.8902 - final_precision_m: 0.3668 - final_recall_m: 0.8994 - final_f1_m: 0.5132 - val_loss: 2.0345 - val_pred1_loss: 0.5067 - val_pred2_loss: 0.4938 - val_pred3_loss: 0.5033 - val_final_loss: 0.5307 - val_pred1_accuracy: 0.8832 - val_pred1_precision_m: 0.3779 - val_pred1_recall_m: 0.8465 - val_pred1_f1_m: 0.5197 - val_pred2_accuracy: 0.9349 - val_pred2_precision_m: 0.5513 - val_pred2_recall_m: 0.6664 - val_pred2_f1_m: 0.6000 - val_pred3_accuracy: 0.9335 - val_pred3_precision_m: 0.5421 - val_pred3_recall_m: 0.7151 - val_pred3_f1_m: 0.6131 - val_final_accuracy: 0.9086 - val_final_precision_m: 0.4422 - val_final_recall_m: 0.8319 - val_final_f1_m: 0.5739 - lr: 1.0000e-04 - 36s/epoch - 296ms/step
# Epoch 5/70
#
# Epoch 00005: val_final_loss did not improve from 0.53071
# 121/121 - 34s - loss: 1.8972 - pred1_loss: 0.4806 - pred2_loss: 0.4472 - pred3_loss: 0.4594 - final_loss: 0.5101 - pred1_accuracy: 0.9220 - pred1_precision_m: 0.4480 - pred1_recall_m: 0.7819 - pred1_f1_m: 0.5624 - pred2_accuracy: 0.9324 - pred2_precision_m: 0.4910 - pred2_recall_m: 0.8109 - pred2_f1_m: 0.6049 - pred3_accuracy: 0.9323 - pred3_precision_m: 0.4905 - pred3_recall_m: 0.8244 - pred3_f1_m: 0.6086 - final_accuracy: 0.9078 - final_precision_m: 0.4080 - final_recall_m: 0.8897 - final_f1_m: 0.5534 - val_loss: 2.1577 - val_pred1_loss: 0.5953 - val_pred2_loss: 0.5031 - val_pred3_loss: 0.5093 - val_final_loss: 0.5499 - val_pred1_accuracy: 0.7901 - val_pred1_precision_m: 0.2533 - val_pred1_recall_m: 0.9082 - val_pred1_f1_m: 0.3940 - val_pred2_accuracy: 0.8669 - val_pred2_precision_m: 0.3542 - val_pred2_recall_m: 0.9127 - val_pred2_f1_m: 0.5063 - val_pred3_accuracy: 0.8710 - val_pred3_precision_m: 0.3644 - val_pred3_recall_m: 0.9191 - val_pred3_f1_m: 0.5173 - val_final_accuracy: 0.8233 - val_final_precision_m: 0.2967 - val_final_recall_m: 0.9592 - val_final_f1_m: 0.4498 - lr: 1.0000e-04 - 34s/epoch - 282ms/step
# Epoch 6/70
#
# Epoch 00006: val_final_loss improved from 0.53071 to 0.49358, saving model to Checkpoints/weights.06-0.49.hdf5
# 121/121 - 35s - loss: 1.7967 - pred1_loss: 0.4578 - pred2_loss: 0.4231 - pred3_loss: 0.4330 - final_loss: 0.4828 - pred1_accuracy: 0.9290 - pred1_precision_m: 0.4804 - pred1_recall_m: 0.7969 - pred1_f1_m: 0.5926 - pred2_accuracy: 0.9387 - pred2_precision_m: 0.5255 - pred2_recall_m: 0.8264 - pred2_f1_m: 0.6356 - pred3_accuracy: 0.9393 - pred3_precision_m: 0.5272 - pred3_recall_m: 0.8363 - pred3_f1_m: 0.6404 - final_accuracy: 0.9191 - final_precision_m: 0.4459 - final_recall_m: 0.8949 - final_f1_m: 0.5892 - val_loss: 1.8737 - val_pred1_loss: 0.5097 - val_pred2_loss: 0.4288 - val_pred3_loss: 0.4417 - val_final_loss: 0.4936 - val_pred1_accuracy: 0.9422 - val_pred1_precision_m: 0.6061 - val_pred1_recall_m: 0.6015 - val_pred1_f1_m: 0.6010 - val_pred2_accuracy: 0.9296 - val_pred2_precision_m: 0.5143 - val_pred2_recall_m: 0.8192 - val_pred2_f1_m: 0.6291 - val_pred3_accuracy: 0.9322 - val_pred3_precision_m: 0.5277 - val_pred3_recall_m: 0.8124 - val_pred3_f1_m: 0.6366 - val_final_accuracy: 0.9056 - val_final_precision_m: 0.4352 - val_final_recall_m: 0.8899 - val_final_f1_m: 0.5816 - lr: 1.0000e-04 - 35s/epoch - 291ms/step
# Epoch 7/70
#
# Epoch 00007: val_final_loss did not improve from 0.49358
# 121/121 - 34s - loss: 1.6981 - pred1_loss: 0.4345 - pred2_loss: 0.3995 - pred3_loss: 0.4087 - final_loss: 0.4554 - pred1_accuracy: 0.9359 - pred1_precision_m: 0.5104 - pred1_recall_m: 0.8129 - pred1_f1_m: 0.6191 - pred2_accuracy: 0.9444 - pred2_precision_m: 0.5522 - pred2_recall_m: 0.8356 - pred2_f1_m: 0.6583 - pred3_accuracy: 0.9453 - pred3_precision_m: 0.5568 - pred3_recall_m: 0.8416 - pred3_f1_m: 0.6639 - final_accuracy: 0.9287 - final_precision_m: 0.4784 - final_recall_m: 0.8944 - final_f1_m: 0.6173 - val_loss: 1.9779 - val_pred1_loss: 0.4378 - val_pred2_loss: 0.4594 - val_pred3_loss: 0.5338 - val_final_loss: 0.5469 - val_pred1_accuracy: 0.9376 - val_pred1_precision_m: 0.5585 - val_pred1_recall_m: 0.7581 - val_pred1_f1_m: 0.6400 - val_pred2_accuracy: 0.9122 - val_pred2_precision_m: 0.4529 - val_pred2_recall_m: 0.8415 - val_pred2_f1_m: 0.5851 - val_pred3_accuracy: 0.8617 - val_pred3_precision_m: 0.3482 - val_pred3_recall_m: 0.8743 - val_pred3_f1_m: 0.4911 - val_final_accuracy: 0.8171 - val_final_precision_m: 0.2896 - val_final_recall_m: 0.9222 - val_final_f1_m: 0.4357 - lr: 1.0000e-04 - 34s/epoch - 282ms/step
# Epoch 8/70
#
# Epoch 00008: val_final_loss improved from 0.49358 to 0.43204, saving model to Checkpoints/weights.08-0.43.hdf5
# 121/121 - 35s - loss: 1.5934 - pred1_loss: 0.4077 - pred2_loss: 0.3749 - pred3_loss: 0.3834 - final_loss: 0.4274 - pred1_accuracy: 0.9440 - pred1_precision_m: 0.5534 - pred1_recall_m: 0.8262 - pred1_f1_m: 0.6559 - pred2_accuracy: 0.9502 - pred2_precision_m: 0.5856 - pred2_recall_m: 0.8513 - pred2_f1_m: 0.6870 - pred3_accuracy: 0.9510 - pred3_precision_m: 0.5898 - pred3_recall_m: 0.8537 - pred3_f1_m: 0.6910 - final_accuracy: 0.9377 - final_precision_m: 0.5165 - final_recall_m: 0.8996 - final_f1_m: 0.6496 - val_loss: 1.6829 - val_pred1_loss: 0.4162 - val_pred2_loss: 0.4163 - val_pred3_loss: 0.4183 - val_final_loss: 0.4320 - val_pred1_accuracy: 0.9390 - val_pred1_precision_m: 0.5602 - val_pred1_recall_m: 0.7834 - val_pred1_f1_m: 0.6517 - val_pred2_accuracy: 0.9553 - val_pred2_precision_m: 0.6833 - val_pred2_recall_m: 0.7019 - val_pred2_f1_m: 0.6904 - val_pred3_accuracy: 0.9554 - val_pred3_precision_m: 0.6823 - val_pred3_recall_m: 0.7148 - val_pred3_f1_m: 0.6966 - val_final_accuracy: 0.9481 - val_final_precision_m: 0.6085 - val_final_recall_m: 0.7955 - val_final_f1_m: 0.6879 - lr: 1.0000e-04 - 35s/epoch - 292ms/step
# Epoch 9/70
#
# Epoch 00009: val_final_loss improved from 0.43204 to 0.39562, saving model to Checkpoints/weights.09-0.40.hdf5
# 121/121 - 35s - loss: 1.4617 - pred1_loss: 0.3775 - pred2_loss: 0.3430 - pred3_loss: 0.3506 - final_loss: 0.3906 - pred1_accuracy: 0.9500 - pred1_precision_m: 0.5843 - pred1_recall_m: 0.8411 - pred1_f1_m: 0.6852 - pred2_accuracy: 0.9566 - pred2_precision_m: 0.6235 - pred2_recall_m: 0.8636 - pred2_f1_m: 0.7204 - pred3_accuracy: 0.9572 - pred3_precision_m: 0.6268 - pred3_recall_m: 0.8666 - pred3_f1_m: 0.7237 - final_accuracy: 0.9470 - final_precision_m: 0.5601 - final_recall_m: 0.9051 - final_f1_m: 0.6878 - val_loss: 1.5054 - val_pred1_loss: 0.3939 - val_pred2_loss: 0.3562 - val_pred3_loss: 0.3597 - val_final_loss: 0.3956 - val_pred1_accuracy: 0.9255 - val_pred1_precision_m: 0.4965 - val_pred1_recall_m: 0.9004 - val_pred1_f1_m: 0.6384 - val_pred2_accuracy: 0.9396 - val_pred2_precision_m: 0.5552 - val_pred2_recall_m: 0.8975 - val_pred2_f1_m: 0.6838 - val_pred3_accuracy: 0.9454 - val_pred3_precision_m: 0.5876 - val_pred3_recall_m: 0.8750 - val_pred3_f1_m: 0.7008 - val_final_accuracy: 0.9350 - val_final_precision_m: 0.5347 - val_final_recall_m: 0.9088 - val_final_f1_m: 0.6712 - lr: 1.0000e-04 - 35s/epoch - 292ms/step
# Epoch 10/70
#
# Epoch 00010: val_final_loss improved from 0.39562 to 0.36165, saving model to Checkpoints/weights.10-0.36.hdf5
# 121/121 - 35s - loss: 1.4030 - pred1_loss: 0.3632 - pred2_loss: 0.3313 - pred3_loss: 0.3381 - final_loss: 0.3704 - pred1_accuracy: 0.9542 - pred1_precision_m: 0.6080 - pred1_recall_m: 0.8479 - pred1_f1_m: 0.7022 - pred2_accuracy: 0.9591 - pred2_precision_m: 0.6346 - pred2_recall_m: 0.8696 - pred2_f1_m: 0.7286 - pred3_accuracy: 0.9597 - pred3_precision_m: 0.6390 - pred3_recall_m: 0.8726 - pred3_f1_m: 0.7326 - final_accuracy: 0.9515 - final_precision_m: 0.5801 - final_recall_m: 0.9055 - final_f1_m: 0.7017 - val_loss: 1.3944 - val_pred1_loss: 0.3585 - val_pred2_loss: 0.3370 - val_pred3_loss: 0.3372 - val_final_loss: 0.3617 - val_pred1_accuracy: 0.9561 - val_pred1_precision_m: 0.6629 - val_pred1_recall_m: 0.8050 - val_pred1_f1_m: 0.7263 - val_pred2_accuracy: 0.9514 - val_pred2_precision_m: 0.6161 - val_pred2_recall_m: 0.8694 - val_pred2_f1_m: 0.7199 - val_pred3_accuracy: 0.9546 - val_pred3_precision_m: 0.6402 - val_pred3_recall_m: 0.8608 - val_pred3_f1_m: 0.7330 - val_final_accuracy: 0.9450 - val_final_precision_m: 0.5793 - val_final_recall_m: 0.8991 - val_final_f1_m: 0.7033 - lr: 1.0000e-04 - 35s/epoch - 291ms/step
# Epoch 11/70
#
# Epoch 00011: val_final_loss improved from 0.36165 to 0.34326, saving model to Checkpoints/weights.11-0.34.hdf5
# 121/121 - 36s - loss: 1.3088 - pred1_loss: 0.3372 - pred2_loss: 0.3119 - pred3_loss: 0.3181 - final_loss: 0.3415 - pred1_accuracy: 0.9588 - pred1_precision_m: 0.6349 - pred1_recall_m: 0.8650 - pred1_f1_m: 0.7269 - pred2_accuracy: 0.9622 - pred2_precision_m: 0.6551 - pred2_recall_m: 0.8773 - pred2_f1_m: 0.7459 - pred3_accuracy: 0.9624 - pred3_precision_m: 0.6565 - pred3_recall_m: 0.8793 - pred3_f1_m: 0.7478 - final_accuracy: 0.9556 - final_precision_m: 0.6043 - final_recall_m: 0.9069 - final_f1_m: 0.7210 - val_loss: 1.3345 - val_pred1_loss: 0.3476 - val_pred2_loss: 0.3185 - val_pred3_loss: 0.3250 - val_final_loss: 0.3433 - val_pred1_accuracy: 0.9577 - val_pred1_precision_m: 0.6775 - val_pred1_recall_m: 0.8029 - val_pred1_f1_m: 0.7338 - val_pred2_accuracy: 0.9542 - val_pred2_precision_m: 0.6299 - val_pred2_recall_m: 0.8848 - val_pred2_f1_m: 0.7347 - val_pred3_accuracy: 0.9577 - val_pred3_precision_m: 0.6600 - val_pred3_recall_m: 0.8629 - val_pred3_f1_m: 0.7466 - val_final_accuracy: 0.9499 - val_final_precision_m: 0.6050 - val_final_recall_m: 0.8992 - val_final_f1_m: 0.7219 - lr: 1.0000e-04 - 36s/epoch - 295ms/step
# Epoch 12/70
#
# Epoch 00012: val_final_loss improved from 0.34326 to 0.31328, saving model to Checkpoints/weights.12-0.31.hdf5
# 121/121 - 35s - loss: 1.2579 - pred1_loss: 0.3235 - pred2_loss: 0.3031 - pred3_loss: 0.3090 - final_loss: 0.3223 - pred1_accuracy: 0.9621 - pred1_precision_m: 0.6576 - pred1_recall_m: 0.8703 - pred1_f1_m: 0.7444 - pred2_accuracy: 0.9640 - pred2_precision_m: 0.6671 - pred2_recall_m: 0.8861 - pred2_f1_m: 0.7564 - pred3_accuracy: 0.9642 - pred3_precision_m: 0.6686 - pred3_recall_m: 0.8863 - pred3_f1_m: 0.7574 - final_accuracy: 0.9583 - final_precision_m: 0.6205 - final_recall_m: 0.9110 - final_f1_m: 0.7333 - val_loss: 1.2565 - val_pred1_loss: 0.3316 - val_pred2_loss: 0.2995 - val_pred3_loss: 0.3121 - val_final_loss: 0.3133 - val_pred1_accuracy: 0.9435 - val_pred1_precision_m: 0.5719 - val_pred1_recall_m: 0.9208 - val_pred1_f1_m: 0.7045 - val_pred2_accuracy: 0.9570 - val_pred2_precision_m: 0.6457 - val_pred2_recall_m: 0.9002 - val_pred2_f1_m: 0.7513 - val_pred3_accuracy: 0.9537 - val_pred3_precision_m: 0.6261 - val_pred3_recall_m: 0.9075 - val_pred3_f1_m: 0.7401 - val_final_accuracy: 0.9473 - val_final_precision_m: 0.5896 - val_final_recall_m: 0.9224 - val_final_f1_m: 0.7184 - lr: 1.0000e-04 - 35s/epoch - 291ms/step
# Epoch 13/70
#
# Epoch 00013: val_final_loss improved from 0.31328 to 0.29173, saving model to Checkpoints/weights.13-0.29.hdf5
# 121/121 - 35s - loss: 1.2005 - pred1_loss: 0.3098 - pred2_loss: 0.2920 - pred3_loss: 0.2970 - final_loss: 0.3016 - pred1_accuracy: 0.9641 - pred1_precision_m: 0.6722 - pred1_recall_m: 0.8791 - pred1_f1_m: 0.7573 - pred2_accuracy: 0.9657 - pred2_precision_m: 0.6827 - pred2_recall_m: 0.8907 - pred2_f1_m: 0.7686 - pred3_accuracy: 0.9659 - pred3_precision_m: 0.6836 - pred3_recall_m: 0.8915 - pred3_f1_m: 0.7699 - final_accuracy: 0.9611 - final_precision_m: 0.6430 - final_recall_m: 0.9114 - final_f1_m: 0.7499 - val_loss: 1.2027 - val_pred1_loss: 0.3077 - val_pred2_loss: 0.2996 - val_pred3_loss: 0.3036 - val_final_loss: 0.2917 - val_pred1_accuracy: 0.9569 - val_pred1_precision_m: 0.6523 - val_pred1_recall_m: 0.8871 - val_pred1_f1_m: 0.7504 - val_pred2_accuracy: 0.9614 - val_pred2_precision_m: 0.6858 - val_pred2_recall_m: 0.8683 - val_pred2_f1_m: 0.7651 - val_pred3_accuracy: 0.9595 - val_pred3_precision_m: 0.6686 - val_pred3_recall_m: 0.8855 - val_pred3_f1_m: 0.7604 - val_final_accuracy: 0.9556 - val_final_precision_m: 0.6391 - val_final_recall_m: 0.9023 - val_final_f1_m: 0.7468 - lr: 1.0000e-04 - 35s/epoch - 292ms/step
# Epoch 14/70
#
# Epoch 00014: val_final_loss improved from 0.29173 to 0.28395, saving model to Checkpoints/weights.14-0.28.hdf5
# ...
# Epoch 59/70
#
# Epoch 00059: val_final_loss did not improve from 0.10947
# 121/121 - 34s - loss: 0.4575 - pred1_loss: 0.0897 - pred2_loss: 0.1196 - pred3_loss: 0.1537 - final_loss: 0.0945 - pred1_accuracy: 0.9943 - pred1_precision_m: 0.9382 - pred1_recall_m: 0.9777 - pred1_f1_m: 0.9573 - pred2_accuracy: 0.9906 - pred2_precision_m: 0.8937 - pred2_recall_m: 0.9709 - pred2_f1_m: 0.9304 - pred3_accuracy: 0.9858 - pred3_precision_m: 0.8454 - pred3_recall_m: 0.9582 - pred3_f1_m: 0.8979 - final_accuracy: 0.9839 - final_precision_m: 0.8284 - final_recall_m: 0.9517 - final_f1_m: 0.8853 - val_loss: 0.5866 - val_pred1_loss: 0.1198 - val_pred2_loss: 0.1561 - val_pred3_loss: 0.1913 - val_final_loss: 0.1194 - val_pred1_accuracy: 0.9914 - val_pred1_precision_m: 0.9371 - val_pred1_recall_m: 0.9430 - val_pred1_f1_m: 0.9396 - val_pred2_accuracy: 0.9868 - val_pred2_precision_m: 0.8937 - val_pred2_recall_m: 0.9269 - val_pred2_f1_m: 0.9098 - val_pred3_accuracy: 0.9823 - val_pred3_precision_m: 0.8585 - val_pred3_recall_m: 0.9031 - val_pred3_f1_m: 0.8800 - val_final_accuracy: 0.9806 - val_final_precision_m: 0.8411 - val_final_recall_m: 0.9010 - val_final_f1_m: 0.8698 - lr: 1.0000e-04 - 34s/epoch - 283ms/step
# Epoch 60/70
#
# Epoch 00060: val_final_loss improved from 0.10947 to 0.10274, saving model to Checkpoints/weights.60-0.10.hdf5
# 121/121 - 35s - loss: 0.4676 - pred1_loss: 0.0929 - pred2_loss: 0.1225 - pred3_loss: 0.1560 - final_loss: 0.0962 - pred1_accuracy: 0.9940 - pred1_precision_m: 0.9310 - pred1_recall_m: 0.9787 - pred1_f1_m: 0.9535 - pred2_accuracy: 0.9902 - pred2_precision_m: 0.8905 - pred2_recall_m: 0.9702 - pred2_f1_m: 0.9283 - pred3_accuracy: 0.9854 - pred3_precision_m: 0.8443 - pred3_recall_m: 0.9571 - pred3_f1_m: 0.8966 - final_accuracy: 0.9836 - final_precision_m: 0.8266 - final_recall_m: 0.9509 - final_f1_m: 0.8838 - val_loss: 0.4987 - val_pred1_loss: 0.0943 - val_pred2_loss: 0.1336 - val_pred3_loss: 0.1681 - val_final_loss: 0.1027 - val_pred1_accuracy: 0.9929 - val_pred1_precision_m: 0.9356 - val_pred1_recall_m: 0.9673 - val_pred1_f1_m: 0.9510 - val_pred2_accuracy: 0.9881 - val_pred2_precision_m: 0.8917 - val_pred2_recall_m: 0.9503 - val_pred2_f1_m: 0.9199 - val_pred3_accuracy: 0.9834 - val_pred3_precision_m: 0.8506 - val_pred3_recall_m: 0.9328 - val_pred3_f1_m: 0.8896 - val_final_accuracy: 0.9809 - val_final_precision_m: 0.8247 - val_final_recall_m: 0.9340 - val_final_f1_m: 0.8758 - lr: 1.0000e-04 - 35s/epoch - 292ms/step
# Epoch 61/70
#
# Epoch 00061: val_final_loss did not improve from 0.10274
# 121/121 - 34s - loss: 0.4743 - pred1_loss: 0.0964 - pred2_loss: 0.1234 - pred3_loss: 0.1574 - final_loss: 0.0972 - pred1_accuracy: 0.9940 - pred1_precision_m: 0.9319 - pred1_recall_m: 0.9762 - pred1_f1_m: 0.9527 - pred2_accuracy: 0.9904 - pred2_precision_m: 0.8882 - pred2_recall_m: 0.9690 - pred2_f1_m: 0.9258 - pred3_accuracy: 0.9855 - pred3_precision_m: 0.8403 - pred3_recall_m: 0.9564 - pred3_f1_m: 0.8936 - final_accuracy: 0.9837 - final_precision_m: 0.8218 - final_recall_m: 0.9505 - final_f1_m: 0.8801 - val_loss: 0.6190 - val_pred1_loss: 0.1332 - val_pred2_loss: 0.1645 - val_pred3_loss: 0.1981 - val_final_loss: 0.1232 - val_pred1_accuracy: 0.9906 - val_pred1_precision_m: 0.9392 - val_pred1_recall_m: 0.9287 - val_pred1_f1_m: 0.9334 - val_pred2_accuracy: 0.9858 - val_pred2_precision_m: 0.8868 - val_pred2_recall_m: 0.9206 - val_pred2_f1_m: 0.9032 - val_pred3_accuracy: 0.9815 - val_pred3_precision_m: 0.8528 - val_pred3_recall_m: 0.8986 - val_pred3_f1_m: 0.8750 - val_final_accuracy: 0.9799 - val_final_precision_m: 0.8356 - val_final_recall_m: 0.8973 - val_final_f1_m: 0.8652 - lr: 1.0000e-04 - 34s/epoch - 282ms/step
# Epoch 62/70
#
# Epoch 00062: val_final_loss did not improve from 0.10274
# 121/121 - 34s - loss: 0.5108 - pred1_loss: 0.1040 - pred2_loss: 0.1353 - pred3_loss: 0.1674 - final_loss: 0.1042 - pred1_accuracy: 0.9933 - pred1_precision_m: 0.9263 - pred1_recall_m: 0.9716 - pred1_f1_m: 0.9480 - pred2_accuracy: 0.9892 - pred2_precision_m: 0.8780 - pred2_recall_m: 0.9621 - pred2_f1_m: 0.9176 - pred3_accuracy: 0.9845 - pred3_precision_m: 0.8319 - pred3_recall_m: 0.9496 - pred3_f1_m: 0.8861 - final_accuracy: 0.9827 - final_precision_m: 0.8145 - final_recall_m: 0.9437 - final_f1_m: 0.8732 - val_loss: 0.5638 - val_pred1_loss: 0.1174 - val_pred2_loss: 0.1463 - val_pred3_loss: 0.1852 - val_final_loss: 0.1149 - val_pred1_accuracy: 0.9911 - val_pred1_precision_m: 0.9281 - val_pred1_recall_m: 0.9478 - val_pred1_f1_m: 0.9375 - val_pred2_accuracy: 0.9862 - val_pred2_precision_m: 0.8730 - val_pred2_recall_m: 0.9475 - val_pred2_f1_m: 0.9086 - val_pred3_accuracy: 0.9808 - val_pred3_precision_m: 0.8283 - val_pred3_recall_m: 0.9266 - val_pred3_f1_m: 0.8744 - val_final_accuracy: 0.9786 - val_final_precision_m: 0.8066 - val_final_recall_m: 0.9259 - val_final_f1_m: 0.8619 - lr: 1.0000e-04 - 34s/epoch - 283ms/step
# Epoch 63/70
#
# Epoch 00063: val_final_loss did not improve from 0.10274
# 121/121 - 34s - loss: 0.4636 - pred1_loss: 0.0942 - pred2_loss: 0.1200 - pred3_loss: 0.1542 - final_loss: 0.0951 - pred1_accuracy: 0.9940 - pred1_precision_m: 0.9346 - pred1_recall_m: 0.9761 - pred1_f1_m: 0.9546 - pred2_accuracy: 0.9906 - pred2_precision_m: 0.8951 - pred2_recall_m: 0.9710 - pred2_f1_m: 0.9313 - pred3_accuracy: 0.9859 - pred3_precision_m: 0.8475 - pred3_recall_m: 0.9575 - pred3_f1_m: 0.8988 - final_accuracy: 0.9839 - final_precision_m: 0.8283 - final_recall_m: 0.9512 - final_f1_m: 0.8849 - val_loss: 0.5148 - val_pred1_loss: 0.1088 - val_pred2_loss: 0.1340 - val_pred3_loss: 0.1680 - val_final_loss: 0.1040 - val_pred1_accuracy: 0.9919 - val_pred1_precision_m: 0.9353 - val_pred1_recall_m: 0.9508 - val_pred1_f1_m: 0.9426 - val_pred2_accuracy: 0.9873 - val_pred2_precision_m: 0.8768 - val_pred2_recall_m: 0.9571 - val_pred2_f1_m: 0.9150 - val_pred3_accuracy: 0.9821 - val_pred3_precision_m: 0.8302 - val_pred3_recall_m: 0.9454 - val_pred3_f1_m: 0.8838 - val_final_accuracy: 0.9803 - val_final_precision_m: 0.8178 - val_final_recall_m: 0.9356 - val_final_f1_m: 0.8726 - lr: 1.0000e-04 - 34s/epoch - 283ms/step
# Epoch 64/70
#
# Epoch 00064: val_final_loss did not improve from 0.10274
# 121/121 - 34s - loss: 0.4694 - pred1_loss: 0.0964 - pred2_loss: 0.1216 - pred3_loss: 0.1556 - final_loss: 0.0958 - pred1_accuracy: 0.9937 - pred1_precision_m: 0.9288 - pred1_recall_m: 0.9766 - pred1_f1_m: 0.9517 - pred2_accuracy: 0.9904 - pred2_precision_m: 0.8916 - pred2_recall_m: 0.9702 - pred2_f1_m: 0.9289 - pred3_accuracy: 0.9856 - pred3_precision_m: 0.8444 - pred3_recall_m: 0.9568 - pred3_f1_m: 0.8966 - final_accuracy: 0.9836 - final_precision_m: 0.8250 - final_recall_m: 0.9507 - final_f1_m: 0.8827 - val_loss: 0.5333 - val_pred1_loss: 0.1073 - val_pred2_loss: 0.1520 - val_pred3_loss: 0.1689 - val_final_loss: 0.1051 - val_pred1_accuracy: 0.9931 - val_pred1_precision_m: 0.9560 - val_pred1_recall_m: 0.9444 - val_pred1_f1_m: 0.9500 - val_pred2_accuracy: 0.9877 - val_pred2_precision_m: 0.9085 - val_pred2_recall_m: 0.9229 - val_pred2_f1_m: 0.9155 - val_pred3_accuracy: 0.9832 - val_pred3_precision_m: 0.8483 - val_pred3_recall_m: 0.9327 - val_pred3_f1_m: 0.8884 - val_final_accuracy: 0.9815 - val_final_precision_m: 0.8362 - val_final_recall_m: 0.9230 - val_final_f1_m: 0.8773 - lr: 1.0000e-04 - 34s/epoch - 282ms/step
# Epoch 65/70
#
# Epoch 00065: val_final_loss did not improve from 0.10274
# 121/121 - 34s - loss: 0.4477 - pred1_loss: 0.0881 - pred2_loss: 0.1160 - pred3_loss: 0.1509 - final_loss: 0.0927 - pred1_accuracy: 0.9945 - pred1_precision_m: 0.9397 - pred1_recall_m: 0.9791 - pred1_f1_m: 0.9589 - pred2_accuracy: 0.9910 - pred2_precision_m: 0.8982 - pred2_recall_m: 0.9727 - pred2_f1_m: 0.9337 - pred3_accuracy: 0.9862 - pred3_precision_m: 0.8489 - pred3_recall_m: 0.9595 - pred3_f1_m: 0.9004 - final_accuracy: 0.9842 - final_precision_m: 0.8301 - final_recall_m: 0.9525 - final_f1_m: 0.8866 - val_loss: 0.4966 - val_pred1_loss: 0.0974 - val_pred2_loss: 0.1299 - val_pred3_loss: 0.1665 - val_final_loss: 0.1028 - val_pred1_accuracy: 0.9933 - val_pred1_precision_m: 0.9470 - val_pred1_recall_m: 0.9563 - val_pred1_f1_m: 0.9516 - val_pred2_accuracy: 0.9883 - val_pred2_precision_m: 0.8906 - val_pred2_recall_m: 0.9549 - val_pred2_f1_m: 0.9215 - val_pred3_accuracy: 0.9833 - val_pred3_precision_m: 0.8465 - val_pred3_recall_m: 0.9375 - val_pred3_f1_m: 0.8895 - val_final_accuracy: 0.9812 - val_final_precision_m: 0.8299 - val_final_recall_m: 0.9299 - val_final_f1_m: 0.8769 - lr: 1.0000e-04 - 34s/epoch - 282ms/step
# Epoch 66/70
#
# Epoch 00066: val_final_loss did not improve from 0.10274
# 121/121 - 34s - loss: 0.4451 - pred1_loss: 0.0903 - pred2_loss: 0.1142 - pred3_loss: 0.1492 - final_loss: 0.0915 - pred1_accuracy: 0.9944 - pred1_precision_m: 0.9277 - pred1_recall_m: 0.9726 - pred1_f1_m: 0.9494 - pred2_accuracy: 0.9913 - pred2_precision_m: 0.8971 - pred2_recall_m: 0.9736 - pred2_f1_m: 0.9326 - pred3_accuracy: 0.9865 - pred3_precision_m: 0.8498 - pred3_recall_m: 0.9607 - pred3_f1_m: 0.9014 - final_accuracy: 0.9845 - final_precision_m: 0.8307 - final_recall_m: 0.9536 - final_f1_m: 0.8871 - val_loss: 0.5248 - val_pred1_loss: 0.1050 - val_pred2_loss: 0.1377 - val_pred3_loss: 0.1755 - val_final_loss: 0.1065 - val_pred1_accuracy: 0.9926 - val_pred1_precision_m: 0.9445 - val_pred1_recall_m: 0.9553 - val_pred1_f1_m: 0.9497 - val_pred2_accuracy: 0.9878 - val_pred2_precision_m: 0.8890 - val_pred2_recall_m: 0.9472 - val_pred2_f1_m: 0.9170 - val_pred3_accuracy: 0.9829 - val_pred3_precision_m: 0.8490 - val_pred3_recall_m: 0.9269 - val_pred3_f1_m: 0.8861 - val_final_accuracy: 0.9804 - val_final_precision_m: 0.8204 - val_final_recall_m: 0.9311 - val_final_f1_m: 0.8721 - lr: 1.0000e-04 - 34s/epoch - 282ms/step
# Epoch 67/70
#
# Epoch 00067: val_final_loss did not improve from 0.10274
# 121/121 - 34s - loss: 0.4795 - pred1_loss: 0.1004 - pred2_loss: 0.1245 - pred3_loss: 0.1575 - final_loss: 0.0971 - pred1_accuracy: 0.9936 - pred1_precision_m: 0.9336 - pred1_recall_m: 0.9702 - pred1_f1_m: 0.9511 - pred2_accuracy: 0.9902 - pred2_precision_m: 0.8922 - pred2_recall_m: 0.9665 - pred2_f1_m: 0.9275 - pred3_accuracy: 0.9855 - pred3_precision_m: 0.8462 - pred3_recall_m: 0.9537 - pred3_f1_m: 0.8963 - final_accuracy: 0.9835 - final_precision_m: 0.8255 - final_recall_m: 0.9483 - final_f1_m: 0.8818 - val_loss: 0.5284 - val_pred1_loss: 0.1161 - val_pred2_loss: 0.1368 - val_pred3_loss: 0.1702 - val_final_loss: 0.1053 - val_pred1_accuracy: 0.9925 - val_pred1_precision_m: 0.9561 - val_pred1_recall_m: 0.9387 - val_pred1_f1_m: 0.9472 - val_pred2_accuracy: 0.9883 - val_pred2_precision_m: 0.8987 - val_pred2_recall_m: 0.9433 - val_pred2_f1_m: 0.9203 - val_pred3_accuracy: 0.9830 - val_pred3_precision_m: 0.8467 - val_pred3_recall_m: 0.9333 - val_pred3_f1_m: 0.8877 - val_final_accuracy: 0.9814 - val_final_precision_m: 0.8356 - val_final_recall_m: 0.9237 - val_final_f1_m: 0.8773 - lr: 1.0000e-04 - 34s/epoch - 281ms/step
# Epoch 68/70
#
# Epoch 00068: val_final_loss improved from 0.10274 to 0.10163, saving model to Checkpoints/weights.68-0.10.hdf5
# 121/121 - 35s - loss: 0.4361 - pred1_loss: 0.0861 - pred2_loss: 0.1114 - pred3_loss: 0.1481 - final_loss: 0.0905 - pred1_accuracy: 0.9948 - pred1_precision_m: 0.9427 - pred1_recall_m: 0.9806 - pred1_f1_m: 0.9611 - pred2_accuracy: 0.9917 - pred2_precision_m: 0.9061 - pred2_recall_m: 0.9733 - pred2_f1_m: 0.9382 - pred3_accuracy: 0.9866 - pred3_precision_m: 0.8544 - pred3_recall_m: 0.9598 - pred3_f1_m: 0.9036 - final_accuracy: 0.9846 - final_precision_m: 0.8347 - final_recall_m: 0.9536 - final_f1_m: 0.8896 - val_loss: 0.5045 - val_pred1_loss: 0.1066 - val_pred2_loss: 0.1311 - val_pred3_loss: 0.1652 - val_final_loss: 0.1016 - val_pred1_accuracy: 0.9918 - val_pred1_precision_m: 0.9322 - val_pred1_recall_m: 0.9591 - val_pred1_f1_m: 0.9454 - val_pred2_accuracy: 0.9887 - val_pred2_precision_m: 0.9002 - val_pred2_recall_m: 0.9486 - val_pred2_f1_m: 0.9237 - val_pred3_accuracy: 0.9832 - val_pred3_precision_m: 0.8453 - val_pred3_recall_m: 0.9396 - val_pred3_f1_m: 0.8899 - val_final_accuracy: 0.9808 - val_final_precision_m: 0.8236 - val_final_recall_m: 0.9354 - val_final_f1_m: 0.8758 - lr: 1.0000e-04 - 35s/epoch - 291ms/step
# Epoch 69/70
#
# Epoch 00069: val_final_loss improved from 0.10163 to 0.09956, saving model to Checkpoints/weights.69-0.10.hdf5
# 121/121 - 35s - loss: 0.4605 - pred1_loss: 0.0978 - pred2_loss: 0.1174 - pred3_loss: 0.1521 - final_loss: 0.0932 - pred1_accuracy: 0.9936 - pred1_precision_m: 0.9273 - pred1_recall_m: 0.9784 - pred1_f1_m: 0.9518 - pred2_accuracy: 0.9910 - pred2_precision_m: 0.8986 - pred2_recall_m: 0.9720 - pred2_f1_m: 0.9336 - pred3_accuracy: 0.9861 - pred3_precision_m: 0.8488 - pred3_recall_m: 0.9591 - pred3_f1_m: 0.9002 - final_accuracy: 0.9841 - final_precision_m: 0.8296 - final_recall_m: 0.9522 - final_f1_m: 0.8859 - val_loss: 0.4789 - val_pred1_loss: 0.0874 - val_pred2_loss: 0.1294 - val_pred3_loss: 0.1627 - val_final_loss: 0.0996 - val_pred1_accuracy: 0.9932 - val_pred1_precision_m: 0.9361 - val_pred1_recall_m: 0.9733 - val_pred1_f1_m: 0.9541 - val_pred2_accuracy: 0.9885 - val_pred2_precision_m: 0.8954 - val_pred2_recall_m: 0.9517 - val_pred2_f1_m: 0.9226 - val_pred3_accuracy: 0.9830 - val_pred3_precision_m: 0.8394 - val_pred3_recall_m: 0.9452 - val_pred3_f1_m: 0.8890 - val_final_accuracy: 0.9811 - val_final_precision_m: 0.8243 - val_final_recall_m: 0.9384 - val_final_f1_m: 0.8775 - lr: 1.0000e-04 - 35s/epoch - 291ms/step
# Epoch 70/70
#
# Epoch 00070: val_final_loss did not improve from 0.09956
# 121/121 - 34s - loss: 0.4334 - pred1_loss: 0.0837 - pred2_loss: 0.1123 - pred3_loss: 0.1472 - final_loss: 0.0902 - pred1_accuracy: 0.9949 - pred1_precision_m: 0.9411 - pred1_recall_m: 0.9784 - pred1_f1_m: 0.9592 - pred2_accuracy: 0.9915 - pred2_precision_m: 0.9020 - pred2_recall_m: 0.9707 - pred2_f1_m: 0.9348 - pred3_accuracy: 0.9867 - pred3_precision_m: 0.8533 - pred3_recall_m: 0.9585 - pred3_f1_m: 0.9023 - final_accuracy: 0.9847 - final_precision_m: 0.8329 - final_recall_m: 0.9516 - final_f1_m: 0.8876 - val_loss: 0.5290 - val_pred1_loss: 0.1028 - val_pred2_loss: 0.1405 - val_pred3_loss: 0.1774 - val_final_loss: 0.1083 - val_pred1_accuracy: 0.9922 - val_pred1_precision_m: 0.9334 - val_pred1_recall_m: 0.9600 - val_pred1_f1_m: 0.9464 - val_pred2_accuracy: 0.9879 - val_pred2_precision_m: 0.8982 - val_pred2_recall_m: 0.9401 - val_pred2_f1_m: 0.9186 - val_pred3_accuracy: 0.9833 - val_pred3_precision_m: 0.8595 - val_pred3_recall_m: 0.9194 - val_pred3_f1_m: 0.8883 - val_final_accuracy: 0.9814 - val_final_precision_m: 0.8399 - val_final_recall_m: 0.9166 - val_final_f1_m: 0.8764 - lr: 1.0000e-04 - 34s/epoch - 282ms/step
# 5/5 - 11s - loss: 2.1459 - pred1_loss: 0.6227 - pred2_loss: 0.5566 - pred3_loss: 0.5378 - final_loss: 0.4288 - pred1_accuracy: 0.9299 - pred1_precision_m: 0.5474 - pred1_recall_m: 0.4340 - pred1_f1_m: 0.4832 - pred2_accuracy: 0.9380 - pred2_precision_m: 0.6009 - pred2_recall_m: 0.5132 - pred2_f1_m: 0.5528 - pred3_accuracy: 0.9405 - pred3_precision_m: 0.6157 - pred3_recall_m: 0.5354 - pred3_f1_m: 0.5719 - final_accuracy: 0.9406 - final_precision_m: 0.6127 - final_recall_m: 0.5500 - final_f1_m: 0.5788 - 11s/epoch - 2s/step
# The metrics for the test set with learning rate 0.0001,  filters 32, and batch size 16 is [2.145928144454956, 0.6226965188980103, 0.5566276907920837, 0.5377618074417114, 0.42884209752082825, 0.9298760890960693, 0.5473917722702026, 0.43398237228393555, 0.48322638869285583, 0.9379714727401733, 0.6009413599967957, 0.5132207870483398, 0.5528075695037842, 0.9404532313346863, 0.6156629323959351, 0.535422682762146, 0.5719212889671326, 0.940632164478302, 0.6126745939254761, 0.5499546527862549, 0.5787784457206726]
# __________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ### Visualise the curves of training error and loss

# %%
# Plot learning curves

#Training Loss curve
plt.plot(history.history["loss"])
plt.title("Sample net training curve loss")
plt.ylabel("Loss")
plt.xlabel("epoch")
plt.show()

#Validation Loss curve
plt.plot(history.history["val_loss"])
plt.title("Sample net validation curve loss")
plt.ylabel("Loss")
plt.xlabel("epoch")
plt.show()

#Training accuracy curve
plt.plot(history.history["f1_m"])
plt.title("Sample net training f1 curve")
plt.ylabel("F1")
plt.xlabel("epoch")
plt.show()

#Validation accuracy curve
plt.plot(history.history["val_f1_m"])
plt.title("Sample net validation f1 curve")
plt.ylabel("F1")
plt.xlabel("epoch")
plt.show()

# %% [markdown]
# ## Testing the model

# %% [markdown]
# ### Evaluate the model

# %% [markdown]
# LOAD MODELS FROM SAVED WEIGHTS (FOR PARTICULAR EPOCH WITH BEST PERFORMANCE)

# %%
def ms_attUNet(lr,filtersFirstLayer, pretrained_weights = None, input_size = (PATCHSIZE, PATCHSIZE, NBANDS)):
    
                img_input = Input(shape=input_size, name='input_scale1')
                scale_img_2 = AveragePooling2D(pool_size=(2, 2), name='input_scale2')(img_input)
                scale_img_3 = AveragePooling2D(pool_size=(2, 2), name='input_scale3')(scale_img_2)
                scale_img_4 = AveragePooling2D(pool_size=(2, 2), name='input_scale4')(scale_img_3)

                conv1 = UnetConv2D(img_input, filtersFirstLayer, is_batchnorm=True, name='conv1')
                pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

                input2 = Conv2D(filtersFirstLayer*2, (3, 3), padding='same', activation='relu', name='conv_scale2')(scale_img_2)
                input2 = concatenate([input2, pool1], axis=3)
                conv2 = UnetConv2D(input2, filtersFirstLayer*2, is_batchnorm=True, name='conv2')
                pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

                input3 = Conv2D(filtersFirstLayer*4, (3, 3), padding='same', activation='relu', name='conv_scale3')(scale_img_3)
                input3 = concatenate([input3, pool2], axis=3)
                conv3 = UnetConv2D(input3, filtersFirstLayer*4, is_batchnorm=True, name='conv3')
                pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

                input4 = Conv2D(filtersFirstLayer*8, (3, 3), padding='same', activation='relu', name='conv_scale4')(scale_img_4)
                input4 = concatenate([input4, pool3], axis=3)
                conv4 = UnetConv2D(input4, filtersFirstLayer*2, is_batchnorm=True, name='conv4')
                pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)

                center = UnetConv2D(pool4, filtersFirstLayer*16, is_batchnorm=True, name='center')

                g1 = UnetGatingSignal(center, is_batchnorm=True, name='g1')
                attn1 = AttnGatingBlock(conv4, g1, filtersFirstLayer*4, '_1')
                up1 = concatenate([Conv2DTranspose(filtersFirstLayer, (3,3), strides=(2,2), padding='same', activation='relu', kernel_initializer=kinit)(center), attn1], name='up1')

                g2 = UnetGatingSignal(up1, is_batchnorm=True, name='g2')
                attn2 = AttnGatingBlock(conv3, g2, filtersFirstLayer*2, '_2')
                up2 = concatenate([Conv2DTranspose(filtersFirstLayer*2, (3,3), strides=(2,2), padding='same', activation='relu', kernel_initializer=kinit)(up1), attn2], name='up2')

                g3 = UnetGatingSignal(up1, is_batchnorm=True, name='g3')
                attn3 = AttnGatingBlock(conv2, g3, filtersFirstLayer, '_3')
                up3 = concatenate([Conv2DTranspose(filtersFirstLayer, (3,3), strides=(2,2), padding='same', activation='relu', kernel_initializer=kinit)(up2), attn3], name='up3')

                up4 = concatenate([Conv2DTranspose(filtersFirstLayer, (3,3), strides=(2,2), padding='same', activation='relu', kernel_initializer=kinit)(up3), conv1], name='up4')

                conv6 = UnetConv2D(up1, filtersFirstLayer*8, is_batchnorm=True, name='conv6')
                conv7 = UnetConv2D(up2, filtersFirstLayer*4, is_batchnorm=True, name='conv7')
                conv8 = UnetConv2D(up3, filtersFirstLayer*2, is_batchnorm=True, name='conv8')
                conv9 = UnetConv2D(up4, filtersFirstLayer, is_batchnorm=True, name='conv9')

                out6 = Conv2D(1, (1, 1), activation='sigmoid', name='pred1')(conv6)
                out7 = Conv2D(1, (1, 1), activation='sigmoid', name='pred2')(conv7)
                out8 = Conv2D(1, (1, 1), activation='sigmoid', name='pred3')(conv8)
                out9 = Conv2D(1, (1, 1), activation='sigmoid', name='final')(conv9)

                model = Model(inputs=[img_input], outputs=[out6, out7, out8, out9])

                loss = {'pred1':focal_tversky,
                        'pred2':focal_tversky,
                        'pred3':focal_tversky,
                        'final':losses.tversky_loss}

                loss_weights = {'pred1':1,
                                'pred2':1,
                                'pred3':1,
                                'final':1}
                model.compile(optimizer=Adam(lr = lr), loss=loss, loss_weights=loss_weights,
                              metrics=metrics)
                model.summary()
                
                if(pretrained_weights):
                    model.load_weights(pretrained_weights)
                    
                return model

# To load model weights from older runs, if present.
# Please load previous metrics and functions and other required variables.
# Also, insert the argument values manually for the model.

best_model = ms_attUNet(lr=1e-4, filtersFirstLayer=32,pretrained_weights=None, input_size=(PATCHSIZE, PATCHSIZE, NBANDS))
best_model.load_weights("Checkpoints/weights.196-0.06.hdf5")
results = best_model.evaluate(X_test, gt_test, verbose=0)
print(f'The metric evaluations are {results}')

# RUN TO SAVE THE MODEL IF YOU HAVE NOT SET ANY CHECKPOINTS; OTHERWISE NO NEED TO RUN THIS CODE
# This saves the weight as the model (might not be the best; depends which one you choose)

import imp, h5py
imp.reload(h5py)
model_fname = "Checkpoints/model_attnUNet.hdf5".format(filters, batch_size_list, lr)
best_model.save(model_fname)
print("Model Saved !!")
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_scale1 (InputLayer)      [(None, 128, 128, 5  0           []
#                                 )]
#
#  conv1_1 (Conv2D)               (None, 128, 128, 32  1472        ['input_scale1[0][0]']
#                                 )
#
#  conv1_1_bn (BatchNormalization  (None, 128, 128, 32  128        ['conv1_1[0][0]']
#  )                              )
#
#  conv1_1_act (Activation)       (None, 128, 128, 32  0           ['conv1_1_bn[0][0]']
#                                 )
#
#  conv1_2 (Conv2D)               (None, 128, 128, 32  9248        ['conv1_1_act[0][0]']
#                                 )
#
#  conv1_2_bn (BatchNormalization  (None, 128, 128, 32  128        ['conv1_2[0][0]']
#  )                              )
#
#  input_scale2 (AveragePooling2D  (None, 64, 64, 5)   0           ['input_scale1[0][0]']
#  )
#
#  conv1_2_act (Activation)       (None, 128, 128, 32  0           ['conv1_2_bn[0][0]']
#                                 )
#
#  conv_scale2 (Conv2D)           (None, 64, 64, 64)   2944        ['input_scale2[0][0]']
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 64, 64, 32)  0           ['conv1_2_act[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 64, 64, 96)   0           ['conv_scale2[0][0]',
#                                                                   'max_pooling2d_4[0][0]']
#
#  conv2_1 (Conv2D)               (None, 64, 64, 64)   55360       ['concatenate_3[0][0]']
#
#  conv2_1_bn (BatchNormalization  (None, 64, 64, 64)  256         ['conv2_1[0][0]']
#  )
#
#  conv2_1_act (Activation)       (None, 64, 64, 64)   0           ['conv2_1_bn[0][0]']
#
#  conv2_2 (Conv2D)               (None, 64, 64, 64)   36928       ['conv2_1_act[0][0]']
#
#  conv2_2_bn (BatchNormalization  (None, 64, 64, 64)  256         ['conv2_2[0][0]']
#  )
#
#  input_scale3 (AveragePooling2D  (None, 32, 32, 5)   0           ['input_scale2[0][0]']
#  )
#
#  conv2_2_act (Activation)       (None, 64, 64, 64)   0           ['conv2_2_bn[0][0]']
#
#  conv_scale3 (Conv2D)           (None, 32, 32, 128)  5888        ['input_scale3[0][0]']
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 32, 32, 64)  0           ['conv2_2_act[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 32, 32, 192)  0           ['conv_scale3[0][0]',
#                                                                   'max_pooling2d_5[0][0]']
#
#  conv3_1 (Conv2D)               (None, 32, 32, 128)  221312      ['concatenate_4[0][0]']
#
#  conv3_1_bn (BatchNormalization  (None, 32, 32, 128)  512        ['conv3_1[0][0]']
#  )
#
#  conv3_1_act (Activation)       (None, 32, 32, 128)  0           ['conv3_1_bn[0][0]']
#
#  conv3_2 (Conv2D)               (None, 32, 32, 128)  147584      ['conv3_1_act[0][0]']
#
#  conv3_2_bn (BatchNormalization  (None, 32, 32, 128)  512        ['conv3_2[0][0]']
#  )
#
#  input_scale4 (AveragePooling2D  (None, 16, 16, 5)   0           ['input_scale3[0][0]']
#  )
#
#  conv3_2_act (Activation)       (None, 32, 32, 128)  0           ['conv3_2_bn[0][0]']
#
#  conv_scale4 (Conv2D)           (None, 16, 16, 256)  11776       ['input_scale4[0][0]']
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 16, 16, 128)  0          ['conv3_2_act[0][0]']
#
#  concatenate_5 (Concatenate)    (None, 16, 16, 384)  0           ['conv_scale4[0][0]',
#                                                                   'max_pooling2d_6[0][0]']
#
#  conv4_1 (Conv2D)               (None, 16, 16, 64)   221248      ['concatenate_5[0][0]']
#
#  conv4_1_bn (BatchNormalization  (None, 16, 16, 64)  256         ['conv4_1[0][0]']
#  )
#
#  conv4_1_act (Activation)       (None, 16, 16, 64)   0           ['conv4_1_bn[0][0]']
#
#  conv4_2 (Conv2D)               (None, 16, 16, 64)   36928       ['conv4_1_act[0][0]']
#
#  conv4_2_bn (BatchNormalization  (None, 16, 16, 64)  256         ['conv4_2[0][0]']
#  )
#
#  conv4_2_act (Activation)       (None, 16, 16, 64)   0           ['conv4_2_bn[0][0]']
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 8, 8, 64)    0           ['conv4_2_act[0][0]']
#
#  center_1 (Conv2D)              (None, 8, 8, 512)    295424      ['max_pooling2d_7[0][0]']
#
#  center_1_bn (BatchNormalizatio  (None, 8, 8, 512)   2048        ['center_1[0][0]']
#  n)
#
#  center_1_act (Activation)      (None, 8, 8, 512)    0           ['center_1_bn[0][0]']
#
#  center_2 (Conv2D)              (None, 8, 8, 512)    2359808     ['center_1_act[0][0]']
#
#  center_2_bn (BatchNormalizatio  (None, 8, 8, 512)   2048        ['center_2[0][0]']
#  n)
#
#  center_2_act (Activation)      (None, 8, 8, 512)    0           ['center_2_bn[0][0]']
#
#  g1_conv (Conv2D)               (None, 8, 8, 512)    262656      ['center_2_act[0][0]']
#
#  g1_bn (BatchNormalization)     (None, 8, 8, 512)    2048        ['g1_conv[0][0]']
#
#  g1_act (Activation)            (None, 8, 8, 512)    0           ['g1_bn[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 8, 8, 128)    65664       ['g1_act[0][0]']
#
#  g_up_1 (Conv2DTranspose)       (None, 8, 8, 128)    147584      ['conv2d_3[0][0]']
#
#  xl_1 (Conv2D)                  (None, 8, 8, 128)    32896       ['conv4_2_act[0][0]']
#
#  add_3 (Add)                    (None, 8, 8, 128)    0           ['g_up_1[0][0]',
#                                                                   'xl_1[0][0]']
#
#  activation_6 (Activation)      (None, 8, 8, 128)    0           ['add_3[0][0]']
#
#  psi_1 (Conv2D)                 (None, 8, 8, 1)      129         ['activation_6[0][0]']
#
#  activation_7 (Activation)      (None, 8, 8, 1)      0           ['psi_1[0][0]']
#
#  up_sampling2d_3 (UpSampling2D)  (None, 16, 16, 1)   0           ['activation_7[0][0]']
#
#  psi_up_1 (Lambda)              (None, 16, 16, 64)   0           ['up_sampling2d_3[0][0]']
#
#  q_attn_1 (Multiply)            (None, 16, 16, 64)   0           ['psi_up_1[0][0]',
#                                                                   'conv4_2_act[0][0]']
#
#  q_attn_conv_1 (Conv2D)         (None, 16, 16, 64)   4160        ['q_attn_1[0][0]']
#
#  conv2d_transpose_4 (Conv2DTran  (None, 16, 16, 32)  147488      ['center_2_act[0][0]']
#  spose)
#
#  q_attn_bn_1 (BatchNormalizatio  (None, 16, 16, 64)  256         ['q_attn_conv_1[0][0]']
#  n)
#
#  up1 (Concatenate)              (None, 16, 16, 96)   0           ['conv2d_transpose_4[0][0]',
#                                                                   'q_attn_bn_1[0][0]']
#
#  g2_conv (Conv2D)               (None, 16, 16, 96)   9312        ['up1[0][0]']
#
#  g2_bn (BatchNormalization)     (None, 16, 16, 96)   384         ['g2_conv[0][0]']
#
#  g2_act (Activation)            (None, 16, 16, 96)   0           ['g2_bn[0][0]']
#
#  g3_conv (Conv2D)               (None, 16, 16, 96)   9312        ['up1[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 16, 16, 64)   6208        ['g2_act[0][0]']
#
#  g3_bn (BatchNormalization)     (None, 16, 16, 96)   384         ['g3_conv[0][0]']
#
#  g_up_2 (Conv2DTranspose)       (None, 16, 16, 64)   36928       ['conv2d_4[0][0]']
#
#  xl_2 (Conv2D)                  (None, 16, 16, 64)   32832       ['conv3_2_act[0][0]']
#
#  g3_act (Activation)            (None, 16, 16, 96)   0           ['g3_bn[0][0]']
#
#  add_4 (Add)                    (None, 16, 16, 64)   0           ['g_up_2[0][0]',
#                                                                   'xl_2[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 16, 16, 32)   3104        ['g3_act[0][0]']
#
#  activation_8 (Activation)      (None, 16, 16, 64)   0           ['add_4[0][0]']
#
#  g_up_3 (Conv2DTranspose)       (None, 32, 32, 32)   9248        ['conv2d_5[0][0]']
#
#  xl_3 (Conv2D)                  (None, 32, 32, 32)   8224        ['conv2_2_act[0][0]']
#
#  psi_2 (Conv2D)                 (None, 16, 16, 1)    65          ['activation_8[0][0]']
#
#  add_5 (Add)                    (None, 32, 32, 32)   0           ['g_up_3[0][0]',
#                                                                   'xl_3[0][0]']
#
#  activation_9 (Activation)      (None, 16, 16, 1)    0           ['psi_2[0][0]']
#
#  activation_10 (Activation)     (None, 32, 32, 32)   0           ['add_5[0][0]']
#
#  up_sampling2d_4 (UpSampling2D)  (None, 32, 32, 1)   0           ['activation_9[0][0]']
#
#  psi_3 (Conv2D)                 (None, 32, 32, 1)    33          ['activation_10[0][0]']
#
#  psi_up_2 (Lambda)              (None, 32, 32, 128)  0           ['up_sampling2d_4[0][0]']
#
#  activation_11 (Activation)     (None, 32, 32, 1)    0           ['psi_3[0][0]']
#
#  q_attn_2 (Multiply)            (None, 32, 32, 128)  0           ['psi_up_2[0][0]',
#                                                                   'conv3_2_act[0][0]']
#
#  up_sampling2d_5 (UpSampling2D)  (None, 64, 64, 1)   0           ['activation_11[0][0]']
#
#  q_attn_conv_2 (Conv2D)         (None, 32, 32, 128)  16512       ['q_attn_2[0][0]']
#
#  psi_up_3 (Lambda)              (None, 64, 64, 64)   0           ['up_sampling2d_5[0][0]']
#
#  conv2d_transpose_5 (Conv2DTran  (None, 32, 32, 64)  55360       ['up1[0][0]']
#  spose)
#
#  q_attn_bn_2 (BatchNormalizatio  (None, 32, 32, 128)  512        ['q_attn_conv_2[0][0]']
#  n)
#
#  q_attn_3 (Multiply)            (None, 64, 64, 64)   0           ['psi_up_3[0][0]',
#                                                                   'conv2_2_act[0][0]']
#
#  up2 (Concatenate)              (None, 32, 32, 192)  0           ['conv2d_transpose_5[0][0]',
#                                                                   'q_attn_bn_2[0][0]']
#
#  q_attn_conv_3 (Conv2D)         (None, 64, 64, 64)   4160        ['q_attn_3[0][0]']
#
#  conv2d_transpose_6 (Conv2DTran  (None, 64, 64, 32)  55328       ['up2[0][0]']
#  spose)
#
#  q_attn_bn_3 (BatchNormalizatio  (None, 64, 64, 64)  256         ['q_attn_conv_3[0][0]']
#  n)
#
#  up3 (Concatenate)              (None, 64, 64, 96)   0           ['conv2d_transpose_6[0][0]',
#                                                                   'q_attn_bn_3[0][0]']
#
#  conv2d_transpose_7 (Conv2DTran  (None, 128, 128, 32  27680      ['up3[0][0]']
#  spose)                         )
#
#  up4 (Concatenate)              (None, 128, 128, 64  0           ['conv2d_transpose_7[0][0]',
#                                 )                                 'conv1_2_act[0][0]']
#
#  conv6_1 (Conv2D)               (None, 16, 16, 256)  221440      ['up1[0][0]']
#
#  conv7_1 (Conv2D)               (None, 32, 32, 128)  221312      ['up2[0][0]']
#
#  conv8_1 (Conv2D)               (None, 64, 64, 64)   55360       ['up3[0][0]']
#
#  conv9_1 (Conv2D)               (None, 128, 128, 32  18464       ['up4[0][0]']
#                                 )
#
#  conv6_1_bn (BatchNormalization  (None, 16, 16, 256)  1024       ['conv6_1[0][0]']
#  )
#
#  conv7_1_bn (BatchNormalization  (None, 32, 32, 128)  512        ['conv7_1[0][0]']
#  )
#
#  conv8_1_bn (BatchNormalization  (None, 64, 64, 64)  256         ['conv8_1[0][0]']
#  )
#
#  conv9_1_bn (BatchNormalization  (None, 128, 128, 32  128        ['conv9_1[0][0]']
#  )                              )
#
#  conv6_1_act (Activation)       (None, 16, 16, 256)  0           ['conv6_1_bn[0][0]']
#
#  conv7_1_act (Activation)       (None, 32, 32, 128)  0           ['conv7_1_bn[0][0]']
#
#  conv8_1_act (Activation)       (None, 64, 64, 64)   0           ['conv8_1_bn[0][0]']
#
#  conv9_1_act (Activation)       (None, 128, 128, 32  0           ['conv9_1_bn[0][0]']
#                                 )
#
#  conv6_2 (Conv2D)               (None, 16, 16, 256)  590080      ['conv6_1_act[0][0]']
#
#  conv7_2 (Conv2D)               (None, 32, 32, 128)  147584      ['conv7_1_act[0][0]']
#
#  conv8_2 (Conv2D)               (None, 64, 64, 64)   36928       ['conv8_1_act[0][0]']
#
#  conv9_2 (Conv2D)               (None, 128, 128, 32  9248        ['conv9_1_act[0][0]']
#                                 )
#
#  conv6_2_bn (BatchNormalization  (None, 16, 16, 256)  1024       ['conv6_2[0][0]']
#  )
#
#  conv7_2_bn (BatchNormalization  (None, 32, 32, 128)  512        ['conv7_2[0][0]']
#  )
#
#  conv8_2_bn (BatchNormalization  (None, 64, 64, 64)  256         ['conv8_2[0][0]']
#  )
#
#  conv9_2_bn (BatchNormalization  (None, 128, 128, 32  128        ['conv9_2[0][0]']
#  )                              )
#
#  conv6_2_act (Activation)       (None, 16, 16, 256)  0           ['conv6_2_bn[0][0]']
#
#  conv7_2_act (Activation)       (None, 32, 32, 128)  0           ['conv7_2_bn[0][0]']
#
#  conv8_2_act (Activation)       (None, 64, 64, 64)   0           ['conv8_2_bn[0][0]']
#
#  conv9_2_act (Activation)       (None, 128, 128, 32  0           ['conv9_2_bn[0][0]']
#                                 )
#
#  pred1 (Conv2D)                 (None, 16, 16, 1)    257         ['conv6_2_act[0][0]']
#
#  pred2 (Conv2D)                 (None, 32, 32, 1)    129         ['conv7_2_act[0][0]']
#
#  pred3 (Conv2D)                 (None, 64, 64, 1)    65          ['conv8_2_act[0][0]']
#
#  final (Conv2D)                 (None, 128, 128, 1)  33          ['conv9_2_act[0][0]']
#
# ==================================================================================================
# Total params: 5,655,783
# Trainable params: 5,648,743
# Non-trainable params: 7,040
# __________________________________________________________________________________________________
# The metric evaluations are [1.5975234508514404, 0.4717070460319519, 0.4159907400608063, 0.41075021028518677, 0.29907554388046265, 0.9513102173805237, 0.7086248397827148, 0.6254640221595764, 0.6625404357910156, 0.9558195471763611, 0.7082841992378235, 0.6847774386405945, 0.6946845054626465, 0.9558541178703308, 0.7038665413856506, 0.6925947666168213, 0.6966127753257751, 0.9549261331558228, 0.6901781558990479, 0.7092174887657166, 0.6980204582214355]
# /usr/local/lib/python3.8/dist-packages/keras/engine/functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# Model Saved !!

# %% [markdown]
# LOAD MODELS FROM CURRENT RUN (Last Model)

# %%
# To load model from current run
model.evaluate(Xtest, Ytest, verbose=2)

# %% [markdown]
# ### Predict the model

# %%
def visualize_prediction(data,mask,predict):
    f, axarr = plt.subplots(1,3)
    data = data[:, :, 3] 
    axarr[0].imshow(data)
    axarr[0].set_title("Satellite image")

    a=axarr[1]
    values = np.unique(mask.ravel())
    im = axarr[1].imshow(mask[:,:,0])
    a.set_title("Ground truth labeled image")
    colors = [im.cmap(im.norm(value)) for value in values]

    b=axarr[2]
    values = np.unique(predict.ravel())
    im = axarr[2].imshow(predict[:,:,0])
    b.set_title("Predicted image")
    colors = [im.cmap(im.norm(value)) for value in values]

    mask = ["Background", "Landslide footprints"]
    patches = [mpatches.Patch(color=colors[i], label=j) for i, j in zip(range(len(values)), mask)]
    plt.legend(handles=patches, bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0. )

# %%
# Select the model and predict on the test image
prediction = best_model.predict(Xtest)

# Run this code if the predicted data needs to be in "int" type and if you need to do THRESHOLDING.
prediction[prediction>0.5]=1
prediction[prediction<0.5]=0

PATCH_NO = random.randint(0, len(Xtest)-1)
test = Ytest[PATCH_NO]

print("Precision: ", (precision_m(test, prediction[PATCH_NO])))
print("Recall: " , recall_m(test, prediction[PATCH_NO]))
print("F1-score: " , f1_m(test, prediction[PATCH_NO]))

visualize_prediction(Xtest[PATCH_NO].astype('uint8'),Ytest[PATCH_NO], prediction[PATCH_NO])
print("Site number= %i" % (PATCH_NO))

# %%
# Plot the first few predictions
for i in range(10):
    preds_train_1 = best_model.predict(np.expand_dims(X_test[i],axis = 0), verbose=1)
    # It's possible to change the 0.5 threshold to show better results;
    preds_train_t1 = (preds_train_1[3] > 0.5).astype(np.uint8)
    f, axarr = plt.subplots(1,3,figsize=(10,10))
    axarr[0].imshow(X_test[i][:,:,:3])
    axarr[1].imshow(np.squeeze(Y_test[i]))
    axarr[2].imshow(np.squeeze(preds_train_t1))
# Out:
# 1/1 [==============================] - 2s 2s/step
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 1/1 [==============================] - 0s 57ms/step
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 1/1 [==============================] - 0s 55ms/step
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 1/1 [==============================] - 0s 57ms/step
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 1/1 [==============================] - 0s 57ms/step
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 1/1 [==============================] - 0s 59ms/step
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 1/1 [==============================] - 0s 57ms/step
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 1/1 [==============================] - 0s 54ms/step
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 1/1 [==============================] - 0s 58ms/step
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 1/1 [==============================] - 0s 54ms/step
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
