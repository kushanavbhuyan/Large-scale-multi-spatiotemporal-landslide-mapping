# %% [markdown]
# # **Landslide Detection over Time**
#
# **Model: Multi-scale Attention U-Net**
#
# **Code Author: Kushanav Bhuyan**

# %% [markdown]
# ## Libraries

# %%
# Import the required Libraries

# %load_ext autotime
print("Importing packages.......")

import os
import numpy as np
from osgeo import gdal
import tensorflow.keras
import tensorflow as tf

# physical_devices = tf.config.list_physical_devices('GPU')
# tf.config.experimental.set_memory_growth(physical_devices[0], True)

# from tensorflow.compat.v1 import ConfigProto
# from tensorflow.compat.v1 import InteractiveSession

# config = ConfigProto()
# config.gpu_options.allow_growth = True
# session = InteractiveSession(config=config

# %matplotlib inline
# %pylab inline

pylab.rcParams['figure.figsize'] = (15, 10)
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from skimage import exposure
from sklearn.model_selection import train_test_split
import pandas as pd

from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler
from tensorflow.keras import regularizers
from tensorflow.keras import backend as keras
from tensorflow.python.keras import backend as K
sess = K.get_session()
from tensorflow.compat.v1.keras.backend import set_session
from tensorflow.keras.layers import LeakyReLU

import pickle
import matplotlib.pyplot as plt 
import sys

# print("Installing packages.......")

# !pip install keras-tqdm
# from keras_tqdm import TQDMCallback, TQDMNotebookCallback

# !pip install ipython-autotime
# %load_ext autotime
import imgaug.augmenters as iaa

print("Importing helper functions !!")

from utils import *
from losses import *
from attention_Unets import *

print("Libraries imported....")
print("Helpers imported....")
# Out:
# Importing packages.......
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib
# 2022-04-07 11:01:07.852362: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# Importing helper functions !!
# Libraries imported....
# Helpers imported....
# time: 6.47 s (started: 2022-04-07 11:01:02 +02:00)
# /usr/local/lib/python3.8/dist-packages/geopandas/_compat.py:111: UserWarning: The Shapely GEOS version (3.10.2-CAPI-1.16.0) is incompatible with the GEOS version PyGEOS was compiled with (3.10.1-CAPI-1.16.0). Conversions between both will be slow.
#   warnings.warn(

# %% [markdown]
# ## Loading the data

# %% [markdown]
# ### Define file directories

# %%
# Set file directory of the location where the data is stored
Data_folder= "path_to_data"
# Out:
# time: 414 µs (started: 2022-04-07 11:01:09 +02:00)

# %% [markdown]
# ### Prepare required dataset
# Make a list of the satellite images

# %%
def readdata(directory, folder_name):
      
    data_path = os.path.join(directory, folder_name)
    data_list = {}

    for f in sorted(os.listdir(data_path)):
        fdir = os.path.join(data_path, f)
        _, ext = os.path.splitext(f)
        if ext.lower() == ".tif":
            imgtype = f[-45:-4] # Number of characters of the image file. Example, "Image_1.tif" = 11 characters
            image_data=gdal.Open(fdir)
            bands = [image_data.GetRasterBand(i+1).ReadAsArray() for i in range(image_data.RasterCount)]
            data_list[imgtype] = np.stack(bands, axis=2) 

    return data_list
# Out:
# time: 58.9 ms (started: 2022-04-07 11:01:09 +02:00)

# %%
image_list = readdata(directory=Data_folder, folder_name="Satellite images")
label_list = readdata(directory=Data_folder, folder_name="Label images")
# Out:
# time: 17.3 s (started: 2022-04-07 11:01:09 +02:00)

# %%
#Check If Everything Works (CIEW)
print("Number of satellite images: " + str(len(image_list)))
print("Shape of the image: "+ str(image_list["L1_train_2017"].shape))

print("Number of label images: " + str(len(label_list)))
print("Shape of the image: "+ str(label_list["L1_train_2017"].shape))
# Out:
# Number of satellite images: 17
# Shape of the image: (2190, 2486, 5)
# Number of label images: 19
# Shape of the image: (2190, 2486, 1)
# time: 772 µs (started: 2022-04-07 11:01:26 +02:00)

# %%
# Print all the stacks that are collected
print("The collection of images available in the list are:")
print("-"*30)
print(*image_list, sep='\n')

# %% [markdown]
# ### Visualise the images

# %%
# Visualise both satellite and label images together
# IMPORTANT NOTE: Use an 8-bit unsigned integer label image otherwise any other data type won't be visualised. 

sample_image="L3_train_2018"
sample_label="L3_train_2018"

def visualise_data(data,data2):
    f, axarr = plt.subplots(1,2)   
    data = data.astype(float)
    for i in range(data.shape[2]):
        p2, p98 = np.percentile(data[:, :, i], (2, 98))
        data[:, :, i] = exposure.rescale_intensity(data[:, :, i],
                                                      in_range=(p2, p98))
    axarr[0].imshow(data[:,:,3])
    axarr[0].set_title("Satellite image")

    a=axarr[1]
    values = np.unique(data2.ravel())
    im = axarr[1].imshow(data2[:,:,0].astype("uint8"))
    a.set_title("Labelled image")
    colors = [im.cmap(im.norm(value)) for value in values] 
    data2 = ["Background", "Landslide footprints"]
    patches = [mpatches.Patch(color=colors[i], label=j) for i, j in zip(range(len(values)), data2)]
    plt.legend(handles=patches, bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0. )

# visualise_data(image_list[sample_image],label_list[sample_label])
# Out:
# time: 31.1 ms (started: 2022-04-07 11:01:26 +02:00)

# %% [markdown]
# ## Design patches, encode into categorical data, remove zero patches, and data augmentations

# %% [markdown]
# ### Generate Patches and encode

# %%
def gridwise_sample(imgarray, patchsize):

    """Extract sample patches of size patchsize x patchsize from an image (imgarray) in a gridwise manner.
    """
    nrows, ncols, nbands = imgarray.shape
    patchsamples = np.zeros(shape=(0, patchsize, patchsize, nbands),
                            dtype=imgarray.dtype)
    for i in range(int(nrows/patchsize)):
        for j in range(int(ncols/patchsize)):
            tocat = imgarray[i*patchsize:(i+1)*patchsize,
                             j*patchsize:(j+1)*patchsize, :]
            tocat = np.expand_dims(tocat, axis=0)
            patchsamples = np.concatenate((patchsamples, tocat),
                                          axis=0)
    return patchsamples
# Out:
# time: 33.7 ms (started: 2022-04-07 11:01:26 +02:00)

# %%
# FOR GENERATING TRAINING SITES

PATCHSIZE = 128 # 224
NBANDS = image_list["L1_train_2017"].shape[-1]

Xtrain = np.zeros(shape=(0, PATCHSIZE, PATCHSIZE, NBANDS), dtype=np.float32)
Ytrain = np.zeros(shape=(0, PATCHSIZE, PATCHSIZE, 1), dtype=np.float32)

# Sample each training tile systematically in a gridwise manner
train_areas = ["add images here"]

for area in train_areas:
    X_toadd = gridwise_sample(image_list[area], PATCHSIZE)
    Y_toadd = gridwise_sample(label_list[area], PATCHSIZE)
    Xtrain = np.concatenate((Xtrain, X_toadd), axis=0)
    Ytrain = np.concatenate((Ytrain, Y_toadd), axis=0)

print(np.unique(Ytrain))
# Encode all landslide and background labels into their respective classes "0" and "1" (Categorical)
Ytrain[Ytrain==0] = 0
# Ytrain[Ytrain==-1] = 0
Ytrain[Ytrain==255] = 1
print(np.unique(Ytrain))

print("There are %i number of training patches" % (Xtrain.shape[0]))
# Out:
# [  0. 255.]
# [0. 1.]
# There are 2880 number of training patches
# time: 20.7 s (started: 2022-04-07 11:01:26 +02:00)

# %%
#CIEW for training patches
bd_px=len(Ytrain[Ytrain==1])/(len(Ytrain[Ytrain==1])+len(Ytrain[Ytrain==0]))
bg_px=len(Ytrain[Ytrain==0])/(len(Ytrain[Ytrain==1])+len(Ytrain[Ytrain==0]))

print("Pixel percentage of landslides = " + str(bd_px* 100)+ " %") 
print("Pixel percentage of background = " + str(bg_px* 100)+ " %")
# Out:
# Pixel percentage of landslides = 8.721563551161024 %
# Pixel percentage of background = 91.27843644883897 %
# time: 561 ms (started: 2022-04-07 11:01:47 +02:00)

# %%
Xtrain, Xtest, Ytrain, Ytest = train_test_split(Xtrain, Ytrain, test_size=0.33, random_state=42)
# Out:
# time: 441 ms (started: 2022-04-07 11:01:47 +02:00)

# %%
# # FOR GENERATING TEST SITES

# Xtest = np.zeros(shape=(0, PATCHSIZE, PATCHSIZE, NBANDS), dtype=np.float32)
# Ytest = np.zeros(shape=(0, PATCHSIZE, PATCHSIZE, 1), dtype=np.float32)

# # Sample each testing tile systematically in a gridwise manner

# test_areas = ["image_2019_T14"]
# for area in test_areas:
#     X_toadd = gridwise_sample(image_list[area], PATCHSIZE)
#     Y_toadd = gridwise_sample(label_list[area], PATCHSIZE)
#     Xtest = np.concatenate((Xtest, X_toadd), axis=0)
#     Ytest = np.concatenate((Ytest, Y_toadd), axis=0)

# print(np.unique(Ytest))
# # encode all landslide and background classes as one class (Categorical)
# Ytest[Ytest==0] = 0
# Ytest[Ytest==65535] = 0
# Ytest[Ytest!=0] = 1
# print(np.unique(Ytest))

# print("There are %i number of testing patches" % (Xtest.shape[0]))
# Out:
# time: 609 µs (started: 2022-04-07 11:01:48 +02:00)

# %%
#CIEW for test patches
bd_px=len(Ytest[Ytest==1])/(len(Ytest[Ytest==1])+len(Ytest[Ytest==0]))
bg_px=len(Ytest[Ytest==0])/(len(Ytest[Ytest==1])+len(Ytest[Ytest==0]))

print("Pixel percentage of landslides = " + str(bd_px* 100) + " %") 
print("Pixel percentage of background = " + str(bg_px* 100)+ " %")
# Out:
# Pixel percentage of landslides = 8.21032599319795 %
# Pixel percentage of background = 91.78967400680204 %
# time: 216 ms (started: 2022-04-07 11:01:48 +02:00)

# %% [markdown]
# ### Remove Zero Patches

# %%
def remove_zeros(images_array,masks_array):
    
    all_zeros = []
    for i in range(masks_array.shape[0]):
        if masks_array[i].max() == 0:
            all_zeros.append(i)
    print("There are: {} arrays with just 0 values, and {} arrays with non zero values ".format(len(all_zeros), (
                images_array.shape[0] - len(all_zeros))))
    images = []
    masks = []
    for i in range(images_array.shape[0]):
        if i not in all_zeros:
            images.append(images_array[i])
            masks.append(masks_array[i])

    # Convert to array
    images = np.array(images, dtype="float64")
    masks = np.array(masks, dtype="float32")
    print("Image shape: {}, Mask shape: {}".format(images.shape, masks.shape))
    return images, masks
# Out:
# time: 926 µs (started: 2022-04-07 11:01:48 +02:00)

# %%
X_train, Y_train = remove_zeros(Xtrain, Ytrain)

print("----"*15)

X_test, Y_test = remove_zeros(Xtest, Ytest)

print("----"*15)

print("There are %i number of training patches" % (X_train.shape[0]))
print("There are %i number of testing patches" % (X_test.shape[0]))
# Out:
# There are: 757 arrays with just 0 values, and 1172 arrays with non zero values
# Image shape: (1172, 128, 128, 5), Mask shape: (1172, 128, 128, 1)
# ------------------------------------------------------------
# There are: 382 arrays with just 0 values, and 569 arrays with non zero values
# Image shape: (569, 128, 128, 5), Mask shape: (569, 128, 128, 1)
# ------------------------------------------------------------
# There are 1172 number of training patches
# There are 569 number of testing patches
# time: 560 ms (started: 2022-04-07 11:01:48 +02:00)

# %%
#CIEW for training patches
bd_px=len(Y_train[Y_train==1])/(len(Y_train[Y_train==1])+len(Y_train[Y_train==0]))
bg_px=len(Y_train[Y_train==0])/(len(Y_train[Y_train==1])+len(Y_train[Y_train==0]))

print("Pixel percentage of landslides = " + str(bd_px* 100)+ " %") 
print("Pixel percentage of background = " + str(bg_px* 100)+ " %")
# Out:
# Pixel percentage of landslides = 14.769695399157424 %
# Pixel percentage of background = 85.23030460084257 %
# time: 225 ms (started: 2022-04-07 11:01:49 +02:00)

# %%
#CIEW for testing patches
bd_px=len(Y_test[Y_test==1])/(len(Y_test[Y_test==1])+len(Y_test[Y_test==0]))
bg_px=len(Y_test[Y_test==0])/(len(Y_test[Y_test==1])+len(Y_test[Y_test==0]))

print("Pixel percentage of landslides = " + str(bd_px* 100)+ " %") 
print("Pixel percentage of background = " + str(bg_px* 100)+ " %")
# Out:
# Pixel percentage of landslides = 13.722355043112918 %
# Pixel percentage of background = 86.27764495688707 %
# time: 75.3 ms (started: 2022-04-07 11:01:49 +02:00)

# %% [markdown]
# ### Data augmentations

# %%
print(f'Shape of the image collection before augmentation: {X_train.shape}')
print(f'Shape of the label collection before augmentation: {Y_train.shape}')

# Geometric
seq = iaa.Sequential([
    iaa.Fliplr(1)
])
seq1 = iaa.Sequential([
    iaa.Flipud(1)
])

seq2 = iaa.Sequential([
    iaa.ShearX((-20, 20))
])

seq3 = iaa.Sequential([
    iaa.ShearY((-20, 20))
])

seq4 = iaa.Sequential([
    iaa.Rotate((-45, 45))
])

# Horizontal Flip
X_aug, Y_aug = seq(images=X_train, heatmaps=Y_train)
# Vertical Flip
X_aug1, Y_aug1 = seq1(images=X_train, heatmaps=Y_train)
# Shear X
X_aug2, Y_aug2 = seq2(images=X_train, heatmaps=Y_train)
# Shear Y
X_aug3, Y_aug3 = seq3(images=X_train, heatmaps=Y_train)
# Rotate +-45
X_aug4, Y_aug4 = seq4(images=X_train, heatmaps=Y_train)

# X_train = np.concatenate((X_train, X_aug1, X_aug2, X_aug3,  X_aug4), axis=0)
# Y_train = np.concatenate((Y_train, Y_aug1, Y_aug2, Y_aug3,  Y_aug4), axis=0)

# Radiometric
seq5 = iaa.Sequential([
    iaa.GaussianBlur(sigma=(0.0, 3.0))
])

seq6 = iaa.Sequential([
    iaa.Sharpen(alpha=(0.0, 1.0), lightness=(0.75, 2.0))
])

# seq7 = iaa.Sequential([
#     iaa.AdditiveGaussianNoise(scale=(0, 0.2*255))
# ])

# Blur
X_aug5, Y_aug5 = seq5(images=X_train, heatmaps=Y_train)
# Sharp
X_aug6, Y_aug6 = seq6(images=X_train, heatmaps=Y_train)
# # Noise
# X_aug7, Y_aug7 = seq7(images=X_train.astype(np.uint8), heatmaps=Y_train)

X_train = np.concatenate((X_train, X_aug1, X_aug2, X_aug3,  X_aug4, X_aug5 ,X_aug6), axis=0)
Y_train = np.concatenate((Y_train, Y_aug1, Y_aug2, Y_aug3,  Y_aug4, Y_aug5 ,Y_aug6), axis=0)

print("--"*20)
print(f'Shape of the image collection after augmentation: {X_train.shape}')
print(f'Shape of the label collection after augmentation: {Y_train.shape}')
# Out:
# Shape of the image collection before augmentation: (1172, 128, 128, 5)
# Shape of the label collection before augmentation: (1172, 128, 128, 1)
# ----------------------------------------
# Shape of the image collection after augmentation: (8204, 128, 128, 5)
# Shape of the label collection after augmentation: (8204, 128, 128, 1)
# time: 18.6 s (started: 2022-04-07 11:01:49 +02:00)

# %%
print("There are %i number of training patches" % (X_train.shape[0]))

#CIEW for training patches
bd_px=len(Y_train[Y_train==1])/(len(Y_train[Y_train==1])+len(Y_train[Y_train==0]))
bg_px=len(Y_train[Y_train==0])/(len(Y_train[Y_train==1])+len(Y_train[Y_train==0]))

print("----"*15)

print("Pixel percentage of landslides = " + str(bd_px* 100)+ " %") 
print("Pixel percentage of background = " + str(bg_px* 100)+ " %")
# Out:
# There are 8204 number of training patches
# ------------------------------------------------------------
# Pixel percentage of landslides = 13.729523265246193 %
# Pixel percentage of background = 86.27047673475381 %
# time: 1.86 s (started: 2022-04-07 11:02:08 +02:00)

# %%
# # Save train and test as NP arrays 

# np.save("Arrays/X_train_2.npy", X_train)
# np.save("Arrays/Y_train_2.npy", Y_train)
# np.save("Arrays/X_test_2.npy", X_test)
# np.save("Arrays/Y_test_2.npy", Y_test)
# Out:
# time: 341 µs (started: 2022-04-07 11:02:09 +02:00)

# %%
# # LOAD ARRAYS IF YOU ARE USING NP ARRAYS

# train_x = np.load("Arrays/X_train.npy")
# test_x = np.load("Arrays/X_test.npy")
# train_y = np.load("Arrays/Y_train.npy")
# test_y = np.load("Arrays/Y_test.npy")

# train_x_2 = np.load("Arrays/X_train_2.npy")
# test_x_2 = np.load("Arrays/X_test_2.npy")
# train_y_2 = np.load("Arrays/Y_train_2.npy")
# test_y_2 = np.load("Arrays/Y_test_2.npy")
# Out:
# time: 81.2 ms (started: 2022-04-07 11:02:09 +02:00)

# %%
# print(train_x.shape)
# print(train_y.shape)

# print(train_x_2.shape)
# print(train_y_2.shape)
# Out:
# time: 27.4 ms (started: 2022-04-07 11:02:10 +02:00)

# %%
# # Concatenate the different arrays

# X_train = np.concatenate((train_x, train_x_2), axis=0)
# Y_train = np.concatenate((train_y, train_y_2), axis=0)
# X_test = np.concatenate((test_x, test_x_2), axis=0)
# Y_test = np.concatenate((test_y, test_y_2), axis=0)

# print(X_train.shape)
# print(Y_train.shape)
# print(X_test.shape)
# print(Y_test.shape)
# Out:
# time: 40.4 ms (started: 2022-04-07 11:02:10 +02:00)

# %%
X_train, X_val, Y_train, Y_val = train_test_split(X_train, Y_train, test_size=0.33, random_state=42)
# Out:
# time: 2.32 s (started: 2022-04-07 11:02:10 +02:00)

# %% [markdown]
# ## Training the model

# %%
# Number of epochs
NUMBER_EPOCHS = 100

# List of hyperparameters
PATCHSIZE=128
NBANDS=5

lr = [1e-4]
batch_size_list = [8]
filters = [32]

# Dictionary of results
results = {
           "filters": [],
           "learning_rate": [],
           "batch_size": [],
           "loss": [],
           "accuracy": [],
           "precision": [],
           "recall": [],
           "f1": []
           }

# Multi-scales for training and testing
gt1 = Y_train[:,::8,::8,:]
gt2 = Y_train[:,::4,::4,:]
gt3 = Y_train[:,::2,::2,:]
gt4 = Y_train
gt_train = [gt1,gt2,gt3,gt4]

gv1 = Y_val[:,::8,::8,:]
gv2 = Y_val[:,::4,::4,:]
gv3 = Y_val[:,::2,::2,:]
gv4 = Y_val
gv_val = [gv1,gv2,gv3,gv4]

gte1 = Y_test[:,::8,::8,:]
gte2 = Y_test[:,::4,::4,:]
gte3 = Y_test[:,::2,::2,:]
gte4 = Y_test
gt_test = [gte1,gte2,gte3,gte4]

# Choose pre-trained weights if necessary for transfer learning
pretrained_weights = "Checkpoints/try.hdf5"

for learning_rate in lr:

    for batch_size in batch_size_list:

        for no_filters in filters:

            # Define the model architecture
            def ms_attUNet(lr,filtersFirstLayer, pretrained_weights=None, input_size=(PATCHSIZE, PATCHSIZE, NBANDS)):

                img_input = Input(shape=input_size, name='input_scale1')
                scale_img_2 = AveragePooling2D(pool_size=(2, 2), name='input_scale2')(img_input)
                scale_img_3 = AveragePooling2D(pool_size=(2, 2), name='input_scale3')(scale_img_2)
                scale_img_4 = AveragePooling2D(pool_size=(2, 2), name='input_scale4')(scale_img_3)

                conv1 = UnetConv2D(img_input, filtersFirstLayer, is_batchnorm=True, name='conv1')
                pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

                input2 = Conv2D(filtersFirstLayer*2, (3, 3), padding='same', activation='relu', name='conv_scale2')(scale_img_2)
                input2 = concatenate([input2, pool1], axis=3)
                conv2 = UnetConv2D(input2, filtersFirstLayer*2, is_batchnorm=True, name='conv2')
                pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

                input3 = Conv2D(filtersFirstLayer*4, (3, 3), padding='same', activation='relu', name='conv_scale3')(scale_img_3)
                input3 = concatenate([input3, pool2], axis=3)
                conv3 = UnetConv2D(input3, filtersFirstLayer*4, is_batchnorm=True, name='conv3')
                pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

                input4 = Conv2D(filtersFirstLayer*8, (3, 3), padding='same', activation='relu', name='conv_scale4')(scale_img_4)
                input4 = concatenate([input4, pool3], axis=3)
                conv4 = UnetConv2D(input4, filtersFirstLayer*2, is_batchnorm=True, name='conv4')
                pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)

                center = UnetConv2D(pool4, filtersFirstLayer*16, is_batchnorm=True, name='center')

                g1 = UnetGatingSignal(center, is_batchnorm=True, name='g1')
                attn1 = AttnGatingBlock(conv4, g1, filtersFirstLayer*4, '_1')
                up1 = concatenate([Conv2DTranspose(filtersFirstLayer, (3,3), strides=(2,2), padding='same', activation='relu', kernel_initializer=kinit)(center), attn1], name='up1')

                g2 = UnetGatingSignal(up1, is_batchnorm=True, name='g2')
                attn2 = AttnGatingBlock(conv3, g2, filtersFirstLayer*2, '_2')
                up2 = concatenate([Conv2DTranspose(filtersFirstLayer*2, (3,3), strides=(2,2), padding='same', activation='relu', kernel_initializer=kinit)(up1), attn2], name='up2')

                g3 = UnetGatingSignal(up1, is_batchnorm=True, name='g3')
                attn3 = AttnGatingBlock(conv2, g3, filtersFirstLayer, '_3')
                up3 = concatenate([Conv2DTranspose(filtersFirstLayer, (3,3), strides=(2,2), padding='same', activation='relu', kernel_initializer=kinit)(up2), attn3], name='up3')

                up4 = concatenate([Conv2DTranspose(filtersFirstLayer, (3,3), strides=(2,2), padding='same', activation='relu', kernel_initializer=kinit)(up3), conv1], name='up4')

                conv6 = UnetConv2D(up1, filtersFirstLayer*8, is_batchnorm=True, name='conv6')
                conv7 = UnetConv2D(up2, filtersFirstLayer*4, is_batchnorm=True, name='conv7')
                conv8 = UnetConv2D(up3, filtersFirstLayer*2, is_batchnorm=True, name='conv8')
                conv9 = UnetConv2D(up4, filtersFirstLayer, is_batchnorm=True, name='conv9')

                out6 = Conv2D(1, (1, 1), activation='sigmoid', name='pred1')(conv6)
                out7 = Conv2D(1, (1, 1), activation='sigmoid', name='pred2')(conv7)
                out8 = Conv2D(1, (1, 1), activation='sigmoid', name='pred3')(conv8)
                out9 = Conv2D(1, (1, 1), activation='sigmoid', name='final')(conv9)

                model = Model(inputs=[img_input], outputs=[out6, out7, out8, out9])

                loss = {'pred1':focal_tversky,
                        'pred2':focal_tversky,
                        'pred3':focal_tversky,
                        'final':losses.tversky_loss}

                loss_weights = {'pred1':1,
                                'pred2':1,
                                'pred3':1,
                                'final':1}
                model.compile(optimizer=Adam(learning_rate=lr), loss=loss, loss_weights=loss_weights,
                              metrics=metrics)
                # model.summary()
                
                if(pretrained_weights):
                    model.load_weights(pretrained_weights)
                    
                return model
            
            # Load the model
            model = ms_attUNet(lr=learning_rate, filtersFirstLayer=no_filters,pretrained_weights=None, input_size=(PATCHSIZE, PATCHSIZE, NBANDS))
    
            print("---------------------------------------------------------------------------------------------------------------------")

            print("Initialising in 3..........2..........1......................................")

            print(f'Training on {X_train.shape[0]} images with learning rate {learning_rate}, batch size {batch_size}, and number of filters {no_filters}')

            # Checkpoint for saving the weights 
            checkpoint_path = os.path.join('Checkpoints/','weights.{epoch:02d}-{val_final_loss:.2f}.hdf5')

            # Create a callback that saves the model's weights at every epoch
            callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                            save_weights_only=True, save_best_only=True, monitor="val_final_loss", mode = "min",
                                                            verbose=1)

            # Create a callback to reduce the learning rate using the ReduceLROnPlateau function
            reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor="val_final_loss", factor=0.33, patience=15, mode="min")
            
            early_stop = tf.keras.callbacks.EarlyStopping(monitor = 'val_final_loss', # what is the metric to measure
                              patience = 40, # how many epochs to continue running the model after seeing an increase in val_loss
                              restore_best_weights = True) # update the mod
            
            # Compile the checkpoints and other settings as a callback
            callback_list = [callback, reduce_lr, early_stop]

            history = model.fit(X_train, gt_train,
                        epochs=NUMBER_EPOCHS,
                        batch_size=batch_size,
                        # validation_split = 0.1,
                        validation_data=(X_val, gv_val),
                        callbacks=callback_list,
                        verbose=2) 

            ########      EVALUATION      ###########
            tf.keras.backend.clear_session()
            evaluate = model.evaluate(X_test, gt_test, verbose=2)

            ########      Saving results      ###########
            results["filters"].append(no_filters)
            results["learning_rate"].append(learning_rate)
            results["batch_size"].append(batch_size)
            results["loss"].append(evaluate[16])
            results["accuracy"].append(evaluate[17])
            results["precision"].append(evaluate[18])
            results["recall"].append(evaluate[19])
            results["f1"].append(evaluate[20])

            # Convert results to a pandas dataframe
            results_df = pd.DataFrame(results)

            # Export as a CSV
            save_path_results = f'Results in CSV'
            if not os.path.exists(save_path_results):
                os.makedirs(save_path_results)

            results_df.to_csv(f'{save_path_results}/learning_rate_{learning_rate}_batch_size_{batch_size}_filters_{no_filters}.csv', index=False)

            tf.compat.v1.reset_default_graph()

            print(f"The metrics for the test set with learning rate {learning_rate},  filters {no_filters}, and batch size {batch_size} is {evaluate}")
            print("__________________________________________________________________________________________________________________________________________________________________________")
# Out:
# ---------------------------------------------------------------------------------------------------------------------
# Initialising in 3..........2..........1......................................
# Training on 5496 images with learning rate 0.0001, batch size 8, and number of filters 32
# Epoch 1/100
#
# Epoch 00001: val_final_loss improved from inf to 0.49796, saving model to Checkpoints/weights.01-0.50.hdf5
# 687/687 - 55s - loss: 2.2875 - pred1_loss: 0.5952 - pred2_loss: 0.5829 - pred3_loss: 0.5883 - final_loss: 0.5211 - pred1_accuracy: 0.6987 - pred1_precision_m: 0.2936 - pred1_recall_m: 0.7697 - pred1_f1_m: 0.4145 - pred2_accuracy: 0.7035 - pred2_precision_m: 0.3024 - pred2_recall_m: 0.7919 - pred2_f1_m: 0.4271 - pred3_accuracy: 0.7137 - pred3_precision_m: 0.3074 - pred3_recall_m: 0.7772 - pred3_f1_m: 0.4294 - final_accuracy: 0.6623 - final_precision_m: 0.2811 - final_recall_m: 0.8303 - final_f1_m: 0.4101 - val_loss: 2.2522 - val_pred1_loss: 0.5894 - val_pred2_loss: 0.5911 - val_pred3_loss: 0.5737 - val_final_loss: 0.4980 - val_pred1_accuracy: 0.7238 - val_pred1_precision_m: 0.2996 - val_pred1_recall_m: 0.7658 - val_pred1_f1_m: 0.4211 - val_pred2_accuracy: 0.6538 - val_pred2_precision_m: 0.2671 - val_pred2_recall_m: 0.8724 - val_pred2_f1_m: 0.4010 - val_pred3_accuracy: 0.6990 - val_pred3_precision_m: 0.2945 - val_pred3_recall_m: 0.8435 - val_pred3_f1_m: 0.4275 - val_final_accuracy: 0.6724 - val_final_precision_m: 0.2796 - val_final_recall_m: 0.8674 - val_final_f1_m: 0.4144 - lr: 1.0000e-04 - 55s/epoch - 80ms/step
# Epoch 2/100
#
# Epoch 00002: val_final_loss improved from 0.49796 to 0.47145, saving model to Checkpoints/weights.02-0.47.hdf5
# 687/687 - 40s - loss: 2.1465 - pred1_loss: 0.5662 - pred2_loss: 0.5552 - pred3_loss: 0.5553 - final_loss: 0.4698 - pred1_accuracy: 0.7428 - pred1_precision_m: 0.3286 - pred1_recall_m: 0.7683 - pred1_f1_m: 0.4486 - pred2_accuracy: 0.7454 - pred2_precision_m: 0.3354 - pred2_recall_m: 0.7857 - pred2_f1_m: 0.4584 - pred3_accuracy: 0.7455 - pred3_precision_m: 0.3363 - pred3_recall_m: 0.7891 - pred3_f1_m: 0.4600 - final_accuracy: 0.7316 - final_precision_m: 0.3260 - final_recall_m: 0.8099 - final_f1_m: 0.4537 - val_loss: 2.1835 - val_pred1_loss: 0.5847 - val_pred2_loss: 0.5646 - val_pred3_loss: 0.5626 - val_final_loss: 0.4715 - val_pred1_accuracy: 0.7950 - val_pred1_precision_m: 0.3637 - val_pred1_recall_m: 0.6462 - val_pred1_f1_m: 0.4530 - val_pred2_accuracy: 0.7984 - val_pred2_precision_m: 0.3761 - val_pred2_recall_m: 0.6820 - val_pred2_f1_m: 0.4725 - val_pred3_accuracy: 0.7878 - val_pred3_precision_m: 0.3670 - val_pred3_recall_m: 0.7055 - val_pred3_f1_m: 0.4702 - val_final_accuracy: 0.7856 - val_final_precision_m: 0.3647 - val_final_recall_m: 0.7123 - val_final_f1_m: 0.4701 - lr: 1.0000e-04 - 40s/epoch - 58ms/step
# Epoch 3/100
#
# Epoch 00003: val_final_loss improved from 0.47145 to 0.46568, saving model to Checkpoints/weights.03-0.47.hdf5
# 687/687 - 41s - loss: 2.0907 - pred1_loss: 0.5544 - pred2_loss: 0.5434 - pred3_loss: 0.5425 - final_loss: 0.4504 - pred1_accuracy: 0.7543 - pred1_precision_m: 0.3402 - pred1_recall_m: 0.7732 - pred1_f1_m: 0.4611 - pred2_accuracy: 0.7599 - pred2_precision_m: 0.3496 - pred2_recall_m: 0.7864 - pred2_f1_m: 0.4726 - pred3_accuracy: 0.7593 - pred3_precision_m: 0.3500 - pred3_recall_m: 0.7907 - pred3_f1_m: 0.4739 - final_accuracy: 0.7530 - final_precision_m: 0.3446 - final_recall_m: 0.8005 - final_f1_m: 0.4707 - val_loss: 2.1693 - val_pred1_loss: 0.5806 - val_pred2_loss: 0.5633 - val_pred3_loss: 0.5597 - val_final_loss: 0.4657 - val_pred1_accuracy: 0.7655 - val_pred1_precision_m: 0.3335 - val_pred1_recall_m: 0.7031 - val_pred1_f1_m: 0.4414 - val_pred2_accuracy: 0.7676 - val_pred2_precision_m: 0.3433 - val_pred2_recall_m: 0.7362 - val_pred2_f1_m: 0.4571 - val_pred3_accuracy: 0.7716 - val_pred3_precision_m: 0.3489 - val_pred3_recall_m: 0.7375 - val_pred3_f1_m: 0.4624 - val_final_accuracy: 0.7661 - val_final_precision_m: 0.3440 - val_final_recall_m: 0.7501 - val_final_f1_m: 0.4607 - lr: 1.0000e-04 - 41s/epoch - 59ms/step
# Epoch 4/100
#
# Epoch 00004: val_final_loss improved from 0.46568 to 0.45882, saving model to Checkpoints/weights.04-0.46.hdf5
# 687/687 - 41s - loss: 2.0509 - pred1_loss: 0.5443 - pred2_loss: 0.5344 - pred3_loss: 0.5336 - final_loss: 0.4386 - pred1_accuracy: 0.7648 - pred1_precision_m: 0.3525 - pred1_recall_m: 0.7764 - pred1_f1_m: 0.4728 - pred2_accuracy: 0.7698 - pred2_precision_m: 0.3613 - pred2_recall_m: 0.7871 - pred2_f1_m: 0.4832 - pred3_accuracy: 0.7687 - pred3_precision_m: 0.3610 - pred3_recall_m: 0.7914 - pred3_f1_m: 0.4839 - final_accuracy: 0.7654 - final_precision_m: 0.3578 - final_recall_m: 0.7964 - final_f1_m: 0.4820 - val_loss: 2.1398 - val_pred1_loss: 0.5556 - val_pred2_loss: 0.5647 - val_pred3_loss: 0.5606 - val_final_loss: 0.4588 - val_pred1_accuracy: 0.7885 - val_pred1_precision_m: 0.3631 - val_pred1_recall_m: 0.7173 - val_pred1_f1_m: 0.4711 - val_pred2_accuracy: 0.8285 - val_pred2_precision_m: 0.4210 - val_pred2_recall_m: 0.6247 - val_pred2_f1_m: 0.4899 - val_pred3_accuracy: 0.8239 - val_pred3_precision_m: 0.4153 - val_pred3_recall_m: 0.6413 - val_pred3_f1_m: 0.4910 - val_final_accuracy: 0.8176 - val_final_precision_m: 0.4059 - val_final_recall_m: 0.6666 - val_final_f1_m: 0.4920 - lr: 1.0000e-04 - 41s/epoch - 59ms/step
# Epoch 5/100
#
# Epoch 00005: val_final_loss improved from 0.45882 to 0.43200, saving model to Checkpoints/weights.05-0.43.hdf5
# 687/687 - 41s - loss: 2.0050 - pred1_loss: 0.5330 - pred2_loss: 0.5237 - pred3_loss: 0.5226 - final_loss: 0.4257 - pred1_accuracy: 0.7787 - pred1_precision_m: 0.3679 - pred1_recall_m: 0.7760 - pred1_f1_m: 0.4872 - pred2_accuracy: 0.7826 - pred2_precision_m: 0.3762 - pred2_recall_m: 0.7871 - pred2_f1_m: 0.4969 - pred3_accuracy: 0.7833 - pred3_precision_m: 0.3776 - pred3_recall_m: 0.7886 - pred3_f1_m: 0.4985 - final_accuracy: 0.7814 - final_precision_m: 0.3754 - final_recall_m: 0.7910 - final_f1_m: 0.4972 - val_loss: 2.0302 - val_pred1_loss: 0.5414 - val_pred2_loss: 0.5288 - val_pred3_loss: 0.5280 - val_final_loss: 0.4320 - val_pred1_accuracy: 0.7874 - val_pred1_precision_m: 0.3663 - val_pred1_recall_m: 0.7497 - val_pred1_f1_m: 0.4813 - val_pred2_accuracy: 0.7897 - val_pred2_precision_m: 0.3732 - val_pred2_recall_m: 0.7714 - val_pred2_f1_m: 0.4925 - val_pred3_accuracy: 0.7861 - val_pred3_precision_m: 0.3701 - val_pred3_recall_m: 0.7806 - val_pred3_f1_m: 0.4917 - val_final_accuracy: 0.7857 - val_final_precision_m: 0.3694 - val_final_recall_m: 0.7788 - val_final_f1_m: 0.4907 - lr: 1.0000e-04 - 41s/epoch - 59ms/step
# Epoch 6/100
#
# Epoch 00006: val_final_loss did not improve from 0.43200
# 687/687 - 39s - loss: 1.9552 - pred1_loss: 0.5220 - pred2_loss: 0.5107 - pred3_loss: 0.5104 - final_loss: 0.4120 - pred1_accuracy: 0.7906 - pred1_precision_m: 0.3835 - pred1_recall_m: 0.7731 - pred1_f1_m: 0.5012 - pred2_accuracy: 0.7965 - pred2_precision_m: 0.3945 - pred2_recall_m: 0.7843 - pred2_f1_m: 0.5137 - pred3_accuracy: 0.7961 - pred3_precision_m: 0.3945 - pred3_recall_m: 0.7856 - pred3_f1_m: 0.5140 - final_accuracy: 0.7947 - final_precision_m: 0.3928 - final_recall_m: 0.7869 - final_f1_m: 0.5129 - val_loss: 2.0254 - val_pred1_loss: 0.5359 - val_pred2_loss: 0.5280 - val_pred3_loss: 0.5291 - val_final_loss: 0.4323 - val_pred1_accuracy: 0.7815 - val_pred1_precision_m: 0.3607 - val_pred1_recall_m: 0.7748 - val_pred1_f1_m: 0.4818 - val_pred2_accuracy: 0.8054 - val_pred2_precision_m: 0.3903 - val_pred2_recall_m: 0.7440 - val_pred2_f1_m: 0.5009 - val_pred3_accuracy: 0.8200 - val_pred3_precision_m: 0.4106 - val_pred3_recall_m: 0.7127 - val_pred3_f1_m: 0.5096 - val_final_accuracy: 0.8208 - val_final_precision_m: 0.4115 - val_final_recall_m: 0.7101 - val_final_f1_m: 0.5097 - lr: 1.0000e-04 - 39s/epoch - 56ms/step
# Epoch 7/100
#
# Epoch 00007: val_final_loss did not improve from 0.43200
# 687/687 - 39s - loss: 1.8986 - pred1_loss: 0.5079 - pred2_loss: 0.4968 - pred3_loss: 0.4965 - final_loss: 0.3973 - pred1_accuracy: 0.8039 - pred1_precision_m: 0.4018 - pred1_recall_m: 0.7814 - pred1_f1_m: 0.5182 - pred2_accuracy: 0.8100 - pred2_precision_m: 0.4135 - pred2_recall_m: 0.7899 - pred2_f1_m: 0.5306 - pred3_accuracy: 0.8100 - pred3_precision_m: 0.4141 - pred3_recall_m: 0.7902 - pred3_f1_m: 0.5311 - final_accuracy: 0.8096 - final_precision_m: 0.4133 - final_recall_m: 0.7892 - final_f1_m: 0.5304 - val_loss: 2.0737 - val_pred1_loss: 0.5547 - val_pred2_loss: 0.5366 - val_pred3_loss: 0.5385 - val_final_loss: 0.4439 - val_pred1_accuracy: 0.8514 - val_pred1_precision_m: 0.4610 - val_pred1_recall_m: 0.6028 - val_pred1_f1_m: 0.5111 - val_pred2_accuracy: 0.8553 - val_pred2_precision_m: 0.4746 - val_pred2_recall_m: 0.6283 - val_pred2_f1_m: 0.5294 - val_pred3_accuracy: 0.8563 - val_pred3_precision_m: 0.4773 - val_pred3_recall_m: 0.6236 - val_pred3_f1_m: 0.5295 - val_final_accuracy: 0.8563 - val_final_precision_m: 0.4772 - val_final_recall_m: 0.6200 - val_final_f1_m: 0.5281 - lr: 1.0000e-04 - 39s/epoch - 57ms/step
# Epoch 8/100
#
# Epoch 00008: val_final_loss improved from 0.43200 to 0.41830, saving model to Checkpoints/weights.08-0.42.hdf5
# 687/687 - 39s - loss: 1.8354 - pred1_loss: 0.4926 - pred2_loss: 0.4808 - pred3_loss: 0.4811 - final_loss: 0.3810 - pred1_accuracy: 0.8196 - pred1_precision_m: 0.4259 - pred1_recall_m: 0.7811 - pred1_f1_m: 0.5387 - pred2_accuracy: 0.8263 - pred2_precision_m: 0.4392 - pred2_recall_m: 0.7887 - pred2_f1_m: 0.5522 - pred3_accuracy: 0.8251 - pred3_precision_m: 0.4378 - pred3_recall_m: 0.7902 - pred3_f1_m: 0.5514 - final_accuracy: 0.8249 - final_precision_m: 0.4373 - final_recall_m: 0.7880 - final_f1_m: 0.5506 - val_loss: 1.9670 - val_pred1_loss: 0.5220 - val_pred2_loss: 0.5104 - val_pred3_loss: 0.5163 - val_final_loss: 0.4183 - val_pred1_accuracy: 0.7971 - val_pred1_precision_m: 0.3789 - val_pred1_recall_m: 0.7731 - val_pred1_f1_m: 0.4991 - val_pred2_accuracy: 0.7837 - val_pred2_precision_m: 0.3695 - val_pred2_recall_m: 0.8257 - val_pred2_f1_m: 0.5013 - val_pred3_accuracy: 0.7645 - val_pred3_precision_m: 0.3513 - val_pred3_recall_m: 0.8512 - val_pred3_f1_m: 0.4884 - val_final_accuracy: 0.7650 - val_final_precision_m: 0.3515 - val_final_recall_m: 0.8482 - val_final_f1_m: 0.4881 - lr: 1.0000e-04 - 39s/epoch - 57ms/step
# Epoch 9/100
#
# Epoch 00009: val_final_loss improved from 0.41830 to 0.41249, saving model to Checkpoints/weights.09-0.41.hdf5
# 687/687 - 40s - loss: 1.7622 - pred1_loss: 0.4749 - pred2_loss: 0.4624 - pred3_loss: 0.4628 - final_loss: 0.3621 - pred1_accuracy: 0.8316 - pred1_precision_m: 0.4454 - pred1_recall_m: 0.7915 - pred1_f1_m: 0.5584 - pred2_accuracy: 0.8390 - pred2_precision_m: 0.4614 - pred2_recall_m: 0.7981 - pred2_f1_m: 0.5734 - pred3_accuracy: 0.8380 - pred3_precision_m: 0.4603 - pred3_recall_m: 0.7992 - pred3_f1_m: 0.5727 - final_accuracy: 0.8377 - final_precision_m: 0.4595 - final_recall_m: 0.7963 - final_f1_m: 0.5716 - val_loss: 1.9598 - val_pred1_loss: 0.5247 - val_pred2_loss: 0.5129 - val_pred3_loss: 0.5097 - val_final_loss: 0.4125 - val_pred1_accuracy: 0.8249 - val_pred1_precision_m: 0.4130 - val_pred1_recall_m: 0.7148 - val_pred1_f1_m: 0.5128 - val_pred2_accuracy: 0.8135 - val_pred2_precision_m: 0.4000 - val_pred2_recall_m: 0.7631 - val_pred2_f1_m: 0.5150 - val_pred3_accuracy: 0.8177 - val_pred3_precision_m: 0.4070 - val_pred3_recall_m: 0.7604 - val_pred3_f1_m: 0.5202 - val_final_accuracy: 0.8136 - val_final_precision_m: 0.4010 - val_final_recall_m: 0.7647 - val_final_f1_m: 0.5162 - lr: 1.0000e-04 - 40s/epoch - 58ms/step
# Epoch 10/100
#
# Epoch 00010: val_final_loss improved from 0.41249 to 0.38485, saving model to Checkpoints/weights.10-0.38.hdf5
# 687/687 - 39s - loss: 1.6901 - pred1_loss: 0.4566 - pred2_loss: 0.4441 - pred3_loss: 0.4450 - final_loss: 0.3444 - pred1_accuracy: 0.8470 - pred1_precision_m: 0.4743 - pred1_recall_m: 0.7969 - pred1_f1_m: 0.5819 - pred2_accuracy: 0.8536 - pred2_precision_m: 0.4891 - pred2_recall_m: 0.8042 - pred2_f1_m: 0.5961 - pred3_accuracy: 0.8529 - pred3_precision_m: 0.4884 - pred3_recall_m: 0.8038 - pred3_f1_m: 0.5952 - final_accuracy: 0.8532 - final_precision_m: 0.4885 - final_recall_m: 0.7985 - final_f1_m: 0.5943 - val_loss: 1.8524 - val_pred1_loss: 0.4983 - val_pred2_loss: 0.4852 - val_pred3_loss: 0.4840 - val_final_loss: 0.3849 - val_pred1_accuracy: 0.8333 - val_pred1_precision_m: 0.4297 - val_pred1_recall_m: 0.7527 - val_pred1_f1_m: 0.5380 - val_pred2_accuracy: 0.8534 - val_pred2_precision_m: 0.4694 - val_pred2_recall_m: 0.7311 - val_pred2_f1_m: 0.5629 - val_pred3_accuracy: 0.8473 - val_pred3_precision_m: 0.4582 - val_pred3_recall_m: 0.7470 - val_pred3_f1_m: 0.5591 - val_final_accuracy: 0.8462 - val_final_precision_m: 0.4561 - val_final_recall_m: 0.7459 - val_final_f1_m: 0.5571 - lr: 1.0000e-04 - 39s/epoch - 57ms/step
# Epoch 11/100
#
# Epoch 00011: val_final_loss improved from 0.38485 to 0.36336, saving model to Checkpoints/weights.11-0.36.hdf5
# 687/687 - 41s - loss: 1.6156 - pred1_loss: 0.4385 - pred2_loss: 0.4251 - pred3_loss: 0.4264 - final_loss: 0.3256 - pred1_accuracy: 0.8605 - pred1_precision_m: 0.5015 - pred1_recall_m: 0.8016 - pred1_f1_m: 0.6047 - pred2_accuracy: 0.8676 - pred2_precision_m: 0.5192 - pred2_recall_m: 0.8071 - pred2_f1_m: 0.6206 - pred3_accuracy: 0.8657 - pred3_precision_m: 0.5157 - pred3_recall_m: 0.8092 - pred3_f1_m: 0.6182 - final_accuracy: 0.8656 - final_precision_m: 0.5154 - final_recall_m: 0.8040 - final_f1_m: 0.6168 - val_loss: 1.7656 - val_pred1_loss: 0.4762 - val_pred2_loss: 0.4634 - val_pred3_loss: 0.4627 - val_final_loss: 0.3634 - val_pred1_accuracy: 0.8377 - val_pred1_precision_m: 0.4394 - val_pred1_recall_m: 0.7862 - val_pred1_f1_m: 0.5554 - val_pred2_accuracy: 0.8559 - val_pred2_precision_m: 0.4761 - val_pred2_recall_m: 0.7669 - val_pred2_f1_m: 0.5792 - val_pred3_accuracy: 0.8552 - val_pred3_precision_m: 0.4753 - val_pred3_recall_m: 0.7700 - val_pred3_f1_m: 0.5795 - val_final_accuracy: 0.8527 - val_final_precision_m: 0.4701 - val_final_recall_m: 0.7718 - val_final_f1_m: 0.5759 - lr: 1.0000e-04 - 41s/epoch - 59ms/step
# Epoch 12/100
#
# Epoch 00012: val_final_loss improved from 0.36336 to 0.36186, saving model to Checkpoints/weights.12-0.36.hdf5
# 687/687 - 40s - loss: 1.5348 - pred1_loss: 0.4173 - pred2_loss: 0.4044 - pred3_loss: 0.4065 - final_loss: 0.3066 - pred1_accuracy: 0.8721 - pred1_precision_m: 0.5276 - pred1_recall_m: 0.8130 - pred1_f1_m: 0.6288 - pred2_accuracy: 0.8776 - pred2_precision_m: 0.5424 - pred2_recall_m: 0.8203 - pred2_f1_m: 0.6427 - pred3_accuracy: 0.8761 - pred3_precision_m: 0.5395 - pred3_recall_m: 0.8197 - pred3_f1_m: 0.6401 - final_accuracy: 0.8761 - final_precision_m: 0.5397 - final_recall_m: 0.8135 - final_f1_m: 0.6386 - val_loss: 1.7524 - val_pred1_loss: 0.4669 - val_pred2_loss: 0.4618 - val_pred3_loss: 0.4619 - val_final_loss: 0.3619 - val_pred1_accuracy: 0.8686 - val_pred1_precision_m: 0.5021 - val_pred1_recall_m: 0.7322 - val_pred1_f1_m: 0.5876 - val_pred2_accuracy: 0.8737 - val_pred2_precision_m: 0.5167 - val_pred2_recall_m: 0.7281 - val_pred2_f1_m: 0.5967 - val_pred3_accuracy: 0.8744 - val_pred3_precision_m: 0.5191 - val_pred3_recall_m: 0.7258 - val_pred3_f1_m: 0.5976 - val_final_accuracy: 0.8730 - val_final_precision_m: 0.5154 - val_final_recall_m: 0.7264 - val_final_f1_m: 0.5953 - lr: 1.0000e-04 - 40s/epoch - 58ms/step
# Epoch 13/100
#
# Epoch 00013: val_final_loss improved from 0.36186 to 0.34808, saving model to Checkpoints/weights.13-0.35.hdf5
# 687/687 - 40s - loss: 1.4612 - pred1_loss: 0.3988 - pred2_loss: 0.3859 - pred3_loss: 0.3880 - final_loss: 0.2885 - pred1_accuracy: 0.8848 - pred1_precision_m: 0.5582 - pred1_recall_m: 0.8180 - pred1_f1_m: 0.6525 - pred2_accuracy: 0.8897 - pred2_precision_m: 0.5725 - pred2_recall_m: 0.8251 - pred2_f1_m: 0.6659 - pred3_accuracy: 0.8879 - pred3_precision_m: 0.5683 - pred3_recall_m: 0.8260 - pred3_f1_m: 0.6629 - final_accuracy: 0.8879 - final_precision_m: 0.5687 - final_recall_m: 0.8191 - final_f1_m: 0.6612 - val_loss: 1.7007 - val_pred1_loss: 0.4604 - val_pred2_loss: 0.4459 - val_pred3_loss: 0.4462 - val_final_loss: 0.3481 - val_pred1_accuracy: 0.8694 - val_pred1_precision_m: 0.5025 - val_pred1_recall_m: 0.7432 - val_pred1_f1_m: 0.5926 - val_pred2_accuracy: 0.8822 - val_pred2_precision_m: 0.5392 - val_pred2_recall_m: 0.7360 - val_pred2_f1_m: 0.6157 - val_pred3_accuracy: 0.8795 - val_pred3_precision_m: 0.5320 - val_pred3_recall_m: 0.7421 - val_pred3_f1_m: 0.6129 - val_final_accuracy: 0.8798 - val_final_precision_m: 0.5333 - val_final_recall_m: 0.7344 - val_final_f1_m: 0.6111 - lr: 1.0000e-04 - 40s/epoch - 58ms/step
# Epoch 14/100
#
# Epoch 00014: val_final_loss did not improve from 0.34808
# 687/687 - 39s - loss: 1.3957 - pred1_loss: 0.3824 - pred2_loss: 0.3690 - pred3_loss: 0.3715 - final_loss: 0.2728 - pred1_accuracy: 0.8914 - pred1_precision_m: 0.5752 - pred1_recall_m: 0.8285 - pred1_f1_m: 0.6697 - pred2_accuracy: 0.8972 - pred2_precision_m: 0.5931 - pred2_recall_m: 0.8342 - pred2_f1_m: 0.6848 - pred3_accuracy: 0.8955 - pred3_precision_m: 0.5890 - pred3_recall_m: 0.8334 - pred3_f1_m: 0.6814 - final_accuracy: 0.8953 - final_precision_m: 0.5892 - final_recall_m: 0.8265 - final_f1_m: 0.6794 - val_loss: 1.8913 - val_pred1_loss: 0.4759 - val_pred2_loss: 0.5060 - val_pred3_loss: 0.5030 - val_final_loss: 0.4064 - val_pred1_accuracy: 0.8975 - val_pred1_precision_m: 0.6008 - val_pred1_recall_m: 0.6452 - val_pred1_f1_m: 0.6151 - val_pred2_accuracy: 0.9048 - val_pred2_precision_m: 0.6595 - val_pred2_recall_m: 0.5767 - val_pred2_f1_m: 0.6075 - val_pred3_accuracy: 0.9047 - val_pred3_precision_m: 0.6581 - val_pred3_recall_m: 0.5818 - val_pred3_f1_m: 0.6103 - val_final_accuracy: 0.9040 - val_final_precision_m: 0.6553 - val_final_recall_m: 0.5792 - val_final_f1_m: 0.6079 - lr: 1.0000e-04 - 39s/epoch - 57ms/step
# Epoch 15/100
#
# Epoch 00015: val_final_loss did not improve from 0.34808
# 687/687 - 40s - loss: 1.3297 - pred1_loss: 0.3647 - pred2_loss: 0.3526 - pred3_loss: 0.3551 - final_loss: 0.2572 - pred1_accuracy: 0.9016 - pred1_precision_m: 0.6028 - pred1_recall_m: 0.8361 - pred1_f1_m: 0.6913 - pred2_accuracy: 0.9051 - pred2_precision_m: 0.6145 - pred2_recall_m: 0.8437 - pred2_f1_m: 0.7027 - pred3_accuracy: 0.9036 - pred3_precision_m: 0.6112 - pred3_recall_m: 0.8427 - pred3_f1_m: 0.6997 - final_accuracy: 0.9033 - final_precision_m: 0.6112 - final_recall_m: 0.8362 - final_f1_m: 0.6975 - val_loss: 1.6984 - val_pred1_loss: 0.4539 - val_pred2_loss: 0.4483 - val_pred3_loss: 0.4459 - val_final_loss: 0.3503 - val_pred1_accuracy: 0.8988 - val_pred1_precision_m: 0.5973 - val_pred1_recall_m: 0.6810 - val_pred1_f1_m: 0.6303 - val_pred2_accuracy: 0.9037 - val_pred2_precision_m: 0.6221 - val_pred2_recall_m: 0.6762 - val_pred2_f1_m: 0.6417 - val_pred3_accuracy: 0.9014 - val_pred3_precision_m: 0.6106 - val_pred3_recall_m: 0.6865 - val_pred3_f1_m: 0.6403 - val_final_accuracy: 0.9012 - val_final_precision_m: 0.6122 - val_final_recall_m: 0.6766 - val_final_f1_m: 0.6368 - lr: 1.0000e-04 - 40s/epoch - 58ms/step
# Epoch 16/100
#
# Epoch 00016: val_final_loss improved from 0.34808 to 0.31982, saving model to Checkpoints/weights.16-0.32.hdf5
# 687/687 - 41s - loss: 1.2630 - pred1_loss: 0.3482 - pred2_loss: 0.3356 - pred3_loss: 0.3381 - final_loss: 0.2410 - pred1_accuracy: 0.9084 - pred1_precision_m: 0.6232 - pred1_recall_m: 0.8443 - pred1_f1_m: 0.7097 - pred2_accuracy: 0.9121 - pred2_precision_m: 0.6367 - pred2_recall_m: 0.8516 - pred2_f1_m: 0.7219 - pred3_accuracy: 0.9107 - pred3_precision_m: 0.6331 - pred3_recall_m: 0.8505 - pred3_f1_m: 0.7188 - final_accuracy: 0.9102 - final_precision_m: 0.6327 - final_recall_m: 0.8442 - final_f1_m: 0.7163 - val_loss: 1.5771 - val_pred1_loss: 0.4258 - val_pred2_loss: 0.4137 - val_pred3_loss: 0.4178 - val_final_loss: 0.3198 - val_pred1_accuracy: 0.8799 - val_pred1_precision_m: 0.5289 - val_pred1_recall_m: 0.7823 - val_pred1_f1_m: 0.6249 - val_pred2_accuracy: 0.8928 - val_pred2_precision_m: 0.5692 - val_pred2_recall_m: 0.7675 - val_pred2_f1_m: 0.6477 - val_pred3_accuracy: 0.8954 - val_pred3_precision_m: 0.5796 - val_pred3_recall_m: 0.7521 - val_pred3_f1_m: 0.6489 - val_final_accuracy: 0.8945 - val_final_precision_m: 0.5773 - val_final_recall_m: 0.7473 - val_final_f1_m: 0.6456 - lr: 1.0000e-04 - 41s/epoch - 59ms/step
# Epoch 17/100
#
# Epoch 00017: val_final_loss improved from 0.31982 to 0.31724, saving model to Checkpoints/weights.17-0.32.hdf5
# 687/687 - 38s - loss: 1.2308 - pred1_loss: 0.3393 - pred2_loss: 0.3279 - pred3_loss: 0.3300 - final_loss: 0.2335 - pred1_accuracy: 0.9127 - pred1_precision_m: 0.6324 - pred1_recall_m: 0.8520 - pred1_f1_m: 0.7183 - pred2_accuracy: 0.9161 - pred2_precision_m: 0.6454 - pred2_recall_m: 0.8571 - pred2_f1_m: 0.7294 - pred3_accuracy: 0.9149 - pred3_precision_m: 0.6424 - pred3_recall_m: 0.8558 - pred3_f1_m: 0.7268 - final_accuracy: 0.9149 - final_precision_m: 0.6441 - final_recall_m: 0.8484 - final_f1_m: 0.7253 - val_loss: 1.5740 - val_pred1_loss: 0.4250 - val_pred2_loss: 0.4156 - val_pred3_loss: 0.4162 - val_final_loss: 0.3172 - val_pred1_accuracy: 0.8766 - val_pred1_precision_m: 0.5200 - val_pred1_recall_m: 0.7928 - val_pred1_f1_m: 0.6214 - val_pred2_accuracy: 0.8778 - val_pred2_precision_m: 0.5240 - val_pred2_recall_m: 0.8066 - val_pred2_f1_m: 0.6289 - val_pred3_accuracy: 0.8780 - val_pred3_precision_m: 0.5252 - val_pred3_recall_m: 0.8040 - val_pred3_f1_m: 0.6290 - val_final_accuracy: 0.8761 - val_final_precision_m: 0.5204 - val_final_recall_m: 0.8028 - val_final_f1_m: 0.6251 - lr: 1.0000e-04 - 38s/epoch - 56ms/step
# Epoch 18/100
#
# Epoch 00018: val_final_loss improved from 0.31724 to 0.30516, saving model to Checkpoints/weights.18-0.31.hdf5
# 687/687 - 40s - loss: 1.1759 - pred1_loss: 0.3244 - pred2_loss: 0.3141 - pred3_loss: 0.3167 - final_loss: 0.2208 - pred1_accuracy: 0.9188 - pred1_precision_m: 0.6539 - pred1_recall_m: 0.8572 - pred1_f1_m: 0.7358 - pred2_accuracy: 0.9206 - pred2_precision_m: 0.6614 - pred2_recall_m: 0.8649 - pred2_f1_m: 0.7441 - pred3_accuracy: 0.9194 - pred3_precision_m: 0.6584 - pred3_recall_m: 0.8631 - pred3_f1_m: 0.7411 - final_accuracy: 0.9192 - final_precision_m: 0.6597 - final_recall_m: 0.8563 - final_f1_m: 0.7395 - val_loss: 1.5269 - val_pred1_loss: 0.4164 - val_pred2_loss: 0.4017 - val_pred3_loss: 0.4037 - val_final_loss: 0.3052 - val_pred1_accuracy: 0.8926 - val_pred1_precision_m: 0.5673 - val_pred1_recall_m: 0.7651 - val_pred1_f1_m: 0.6452 - val_pred2_accuracy: 0.8891 - val_pred2_precision_m: 0.5554 - val_pred2_recall_m: 0.8010 - val_pred2_f1_m: 0.6500 - val_pred3_accuracy: 0.8932 - val_pred3_precision_m: 0.5694 - val_pred3_recall_m: 0.7850 - val_pred3_f1_m: 0.6541 - val_final_accuracy: 0.8927 - val_final_precision_m: 0.5683 - val_final_recall_m: 0.7799 - val_final_f1_m: 0.6515 - lr: 1.0000e-04 - 40s/epoch - 58ms/step
# Epoch 19/100
#
# Epoch 00019: val_final_loss did not improve from 0.30516
# 687/687 - 39s - loss: 1.1362 - pred1_loss: 0.3143 - pred2_loss: 0.3040 - pred3_loss: 0.3061 - final_loss: 0.2117 - pred1_accuracy: 0.9230 - pred1_precision_m: 0.6668 - pred1_recall_m: 0.8620 - pred1_f1_m: 0.7466 - pred2_accuracy: 0.9250 - pred2_precision_m: 0.6751 - pred2_recall_m: 0.8688 - pred2_f1_m: 0.7550 - pred3_accuracy: 0.9236 - pred3_precision_m: 0.6705 - pred3_recall_m: 0.8686 - pred3_f1_m: 0.7519 - final_accuracy: 0.9232 - final_precision_m: 0.6713 - final_recall_m: 0.8624 - final_f1_m: 0.7501 - val_loss: 1.6213 - val_pred1_loss: 0.4448 - val_pred2_loss: 0.4252 - val_pred3_loss: 0.4235 - val_final_loss: 0.3278 - val_pred1_accuracy: 0.9136 - val_pred1_precision_m: 0.6695 - val_pred1_recall_m: 0.6587 - val_pred1_f1_m: 0.6579 - val_pred2_accuracy: 0.9129 - val_pred2_precision_m: 0.6571 - val_pred2_recall_m: 0.6930 - val_pred2_f1_m: 0.6685 - val_pred3_accuracy: 0.9116 - val_pred3_precision_m: 0.6505 - val_pred3_recall_m: 0.6993 - val_pred3_f1_m: 0.6683 - val_final_accuracy: 0.9117 - val_final_precision_m: 0.6536 - val_final_recall_m: 0.6895 - val_final_f1_m: 0.6656 - lr: 1.0000e-04 - 39s/epoch - 57ms/step
# Epoch 20/100
#
# Epoch 00020: val_final_loss improved from 0.30516 to 0.30285, saving model to Checkpoints/weights.20-0.30.hdf5
# 687/687 - 41s - loss: 1.0858 - pred1_loss: 0.3006 - pred2_loss: 0.2915 - pred3_loss: 0.2938 - final_loss: 0.1998 - pred1_accuracy: 0.9273 - pred1_precision_m: 0.6825 - pred1_recall_m: 0.8712 - pred1_f1_m: 0.7607 - pred2_accuracy: 0.9287 - pred2_precision_m: 0.6900 - pred2_recall_m: 0.8764 - pred2_f1_m: 0.7679 - pred3_accuracy: 0.9275 - pred3_precision_m: 0.6853 - pred3_recall_m: 0.8762 - pred3_f1_m: 0.7647 - final_accuracy: 0.9271 - final_precision_m: 0.6860 - final_recall_m: 0.8704 - final_f1_m: 0.7631 - val_loss: 1.5047 - val_pred1_loss: 0.4041 - val_pred2_loss: 0.3987 - val_pred3_loss: 0.3991 - val_final_loss: 0.3028 - val_pred1_accuracy: 0.9086 - val_pred1_precision_m: 0.6243 - val_pred1_recall_m: 0.7440 - val_pred1_f1_m: 0.6736 - val_pred2_accuracy: 0.9142 - val_pred2_precision_m: 0.6519 - val_pred2_recall_m: 0.7346 - val_pred2_f1_m: 0.6855 - val_pred3_accuracy: 0.9127 - val_pred3_precision_m: 0.6450 - val_pred3_recall_m: 0.7380 - val_pred3_f1_m: 0.6832 - val_final_accuracy: 0.9125 - val_final_precision_m: 0.6461 - val_final_recall_m: 0.7302 - val_final_f1_m: 0.6804 - lr: 1.0000e-04 - 41s/epoch - 59ms/step
# Epoch 21/100
#
# Epoch 00021: val_final_loss did not improve from 0.30285
# 687/687 - 39s - loss: 1.0722 - pred1_loss: 0.2964 - pred2_loss: 0.2883 - pred3_loss: 0.2905 - final_loss: 0.1970 - pred1_accuracy: 0.9301 - pred1_precision_m: 0.6887 - pred1_recall_m: 0.8734 - pred1_f1_m: 0.7652 - pred2_accuracy: 0.9310 - pred2_precision_m: 0.6939 - pred2_recall_m: 0.8786 - pred2_f1_m: 0.7710 - pred3_accuracy: 0.9298 - pred3_precision_m: 0.6899 - pred3_recall_m: 0.8778 - pred3_f1_m: 0.7682 - final_accuracy: 0.9295 - final_precision_m: 0.6911 - final_recall_m: 0.8718 - final_f1_m: 0.7669 - val_loss: 1.5245 - val_pred1_loss: 0.4225 - val_pred2_loss: 0.3949 - val_pred3_loss: 0.4016 - val_final_loss: 0.3055 - val_pred1_accuracy: 0.9118 - val_pred1_precision_m: 0.6490 - val_pred1_recall_m: 0.7017 - val_pred1_f1_m: 0.6689 - val_pred2_accuracy: 0.9093 - val_pred2_precision_m: 0.6270 - val_pred2_recall_m: 0.7558 - val_pred2_f1_m: 0.6803 - val_pred3_accuracy: 0.9118 - val_pred3_precision_m: 0.6421 - val_pred3_recall_m: 0.7360 - val_pred3_f1_m: 0.6808 - val_final_accuracy: 0.9117 - val_final_precision_m: 0.6437 - val_final_recall_m: 0.7274 - val_final_f1_m: 0.6780 - lr: 1.0000e-04 - 39s/epoch - 57ms/step
# Epoch 22/100
#
# Epoch 00022: val_final_loss improved from 0.30285 to 0.28429, saving model to Checkpoints/weights.22-0.28.hdf5
# 687/687 - 41s - loss: 1.0219 - pred1_loss: 0.2824 - pred2_loss: 0.2756 - pred3_loss: 0.2779 - final_loss: 0.1859 - pred1_accuracy: 0.9338 - pred1_precision_m: 0.7058 - pred1_recall_m: 0.8806 - pred1_f1_m: 0.7799 - pred2_accuracy: 0.9342 - pred2_precision_m: 0.7082 - pred2_recall_m: 0.8862 - pred2_f1_m: 0.7838 - pred3_accuracy: 0.9330 - pred3_precision_m: 0.7042 - pred3_recall_m: 0.8850 - pred3_f1_m: 0.7809 - final_accuracy: 0.9324 - final_precision_m: 0.7043 - final_recall_m: 0.8797 - final_f1_m: 0.7789 - val_loss: 1.4436 - val_pred1_loss: 0.3965 - val_pred2_loss: 0.3807 - val_pred3_loss: 0.3821 - val_final_loss: 0.2843 - val_pred1_accuracy: 0.9103 - val_pred1_precision_m: 0.6296 - val_pred1_recall_m: 0.7530 - val_pred1_f1_m: 0.6802 - val_pred2_accuracy: 0.9054 - val_pred2_precision_m: 0.6063 - val_pred2_recall_m: 0.7946 - val_pred2_f1_m: 0.6823 - val_pred3_accuracy: 0.9053 - val_pred3_precision_m: 0.6068 - val_pred3_recall_m: 0.7919 - val_pred3_f1_m: 0.6817 - val_final_accuracy: 0.9037 - val_final_precision_m: 0.6015 - val_final_recall_m: 0.7900 - val_final_f1_m: 0.6775 - lr: 1.0000e-04 - 41s/epoch - 60ms/step
# Epoch 23/100
#
# Epoch 00023: val_final_loss did not improve from 0.28429
# 687/687 - 40s - loss: 1.0038 - pred1_loss: 0.2775 - pred2_loss: 0.2711 - pred3_loss: 0.2733 - final_loss: 0.1819 - pred1_accuracy: 0.9359 - pred1_precision_m: 0.7106 - pred1_recall_m: 0.8841 - pred1_f1_m: 0.7846 - pred2_accuracy: 0.9360 - pred2_precision_m: 0.7122 - pred2_recall_m: 0.8897 - pred2_f1_m: 0.7881 - pred3_accuracy: 0.9349 - pred3_precision_m: 0.7092 - pred3_recall_m: 0.8879 - pred3_f1_m: 0.7855 - final_accuracy: 0.9343 - final_precision_m: 0.7089 - final_recall_m: 0.8828 - final_f1_m: 0.7834 - val_loss: 1.5599 - val_pred1_loss: 0.4104 - val_pred2_loss: 0.4126 - val_pred3_loss: 0.4184 - val_final_loss: 0.3186 - val_pred1_accuracy: 0.9105 - val_pred1_precision_m: 0.6365 - val_pred1_recall_m: 0.7281 - val_pred1_f1_m: 0.6734 - val_pred2_accuracy: 0.9164 - val_pred2_precision_m: 0.6722 - val_pred2_recall_m: 0.7037 - val_pred2_f1_m: 0.6816 - val_pred3_accuracy: 0.9170 - val_pred3_precision_m: 0.6797 - val_pred3_recall_m: 0.6921 - val_pred3_f1_m: 0.6800 - val_final_accuracy: 0.9155 - val_final_precision_m: 0.6717 - val_final_recall_m: 0.6943 - val_final_f1_m: 0.6772 - lr: 1.0000e-04 - 40s/epoch - 58ms/step
# Epoch 24/100
#
# Epoch 00024: val_final_loss did not improve from 0.28429
# 687/687 - 40s - loss: 0.9617 - pred1_loss: 0.2650 - pred2_loss: 0.2604 - pred3_loss: 0.2631 - final_loss: 0.1731 - pred1_accuracy: 0.9400 - pred1_precision_m: 0.7268 - pred1_recall_m: 0.8901 - pred1_f1_m: 0.7974 - pred2_accuracy: 0.9392 - pred2_precision_m: 0.7243 - pred2_recall_m: 0.8957 - pred2_f1_m: 0.7984 - pred3_accuracy: 0.9379 - pred3_precision_m: 0.7201 - pred3_recall_m: 0.8941 - pred3_f1_m: 0.7951 - final_accuracy: 0.9373 - final_precision_m: 0.7199 - final_recall_m: 0.8889 - final_f1_m: 0.7931 - val_loss: 1.4784 - val_pred1_loss: 0.4056 - val_pred2_loss: 0.3891 - val_pred3_loss: 0.3908 - val_final_loss: 0.2928 - val_pred1_accuracy: 0.9145 - val_pred1_precision_m: 0.6552 - val_pred1_recall_m: 0.7231 - val_pred1_f1_m: 0.6819 - val_pred2_accuracy: 0.9148 - val_pred2_precision_m: 0.6509 - val_pred2_recall_m: 0.7504 - val_pred2_f1_m: 0.6918 - val_pred3_accuracy: 0.9138 - val_pred3_precision_m: 0.6477 - val_pred3_recall_m: 0.7499 - val_pred3_f1_m: 0.6899 - val_final_accuracy: 0.9115 - val_final_precision_m: 0.6378 - val_final_recall_m: 0.7511 - val_final_f1_m: 0.6846 - lr: 1.0000e-04 - 40s/epoch - 58ms/step
# Epoch 25/100
#
# Epoch 00025: val_final_loss did not improve from 0.28429
# 687/687 - 40s - loss: 0.9391 - pred1_loss: 0.2590 - pred2_loss: 0.2550 - pred3_loss: 0.2572 - final_loss: 0.1679 - pred1_accuracy: 0.9421 - pred1_precision_m: 0.7344 - pred1_recall_m: 0.8940 - pred1_f1_m: 0.8037 - pred2_accuracy: 0.9410 - pred2_precision_m: 0.7306 - pred2_recall_m: 0.8991 - pred2_f1_m: 0.8037 - pred3_accuracy: 0.9399 - pred3_precision_m: 0.7275 - pred3_recall_m: 0.8972 - pred3_f1_m: 0.8013 - final_accuracy: 0.9392 - final_precision_m: 0.7262 - final_recall_m: 0.8929 - final_f1_m: 0.7989 - val_loss: 1.4622 - val_pred1_loss: 0.3970 - val_pred2_loss: 0.3863 - val_pred3_loss: 0.3882 - val_final_loss: 0.2908 - val_pred1_accuracy: 0.9140 - val_pred1_precision_m: 0.6480 - val_pred1_recall_m: 0.7406 - val_pred1_f1_m: 0.6851 - val_pred2_accuracy: 0.9118 - val_pred2_precision_m: 0.6352 - val_pred2_recall_m: 0.7639 - val_pred2_f1_m: 0.6878 - val_pred3_accuracy: 0.9114 - val_pred3_precision_m: 0.6348 - val_pred3_recall_m: 0.7609 - val_pred3_f1_m: 0.6864 - val_final_accuracy: 0.9106 - val_final_precision_m: 0.6322 - val_final_recall_m: 0.7577 - val_final_f1_m: 0.6836 - lr: 1.0000e-04 - 40s/epoch - 58ms/step
# Epoch 26/100
#
# Epoch 00026: val_final_loss did not improve from 0.28429
# 687/687 - 40s - loss: 0.9280 - pred1_loss: 0.2552 - pred2_loss: 0.2522 - pred3_loss: 0.2549 - final_loss: 0.1658 - pred1_accuracy: 0.9434 - pred1_precision_m: 0.7392 - pred1_recall_m: 0.8965 - pred1_f1_m: 0.8075 - pred2_accuracy: 0.9421 - pred2_precision_m: 0.7353 - pred2_recall_m: 0.9000 - pred2_f1_m: 0.8068 - pred3_accuracy: 0.9408 - pred3_precision_m: 0.7315 - pred3_recall_m: 0.8979 - pred3_f1_m: 0.8038 - final_accuracy: 0.9401 - final_precision_m: 0.7310 - final_recall_m: 0.8933 - final_f1_m: 0.8018 - val_loss: 1.4596 - val_pred1_loss: 0.3954 - val_pred2_loss: 0.3858 - val_pred3_loss: 0.3883 - val_final_loss: 0.2901 - val_pred1_accuracy: 0.9021 - val_pred1_precision_m: 0.5956 - val_pred1_recall_m: 0.7772 - val_pred1_f1_m: 0.6685 - val_pred2_accuracy: 0.9021 - val_pred2_precision_m: 0.5958 - val_pred2_recall_m: 0.7922 - val_pred2_f1_m: 0.6745 - val_pred3_accuracy: 0.9046 - val_pred3_precision_m: 0.6062 - val_pred3_recall_m: 0.7802 - val_pred3_f1_m: 0.6769 - val_final_accuracy: 0.9032 - val_final_precision_m: 0.6015 - val_final_recall_m: 0.7793 - val_final_f1_m: 0.6735 - lr: 1.0000e-04 - 40s/epoch - 59ms/step
# Epoch 27/100
#
# Epoch 00027: val_final_loss did not improve from 0.28429
# 687/687 - 40s - loss: 0.8933 - pred1_loss: 0.2454 - pred2_loss: 0.2435 - pred3_loss: 0.2460 - final_loss: 0.1584 - pred1_accuracy: 0.9461 - pred1_precision_m: 0.7499 - pred1_recall_m: 0.9022 - pred1_f1_m: 0.8168 - pred2_accuracy: 0.9446 - pred2_precision_m: 0.7443 - pred2_recall_m: 0.9054 - pred2_f1_m: 0.8149 - pred3_accuracy: 0.9434 - pred3_precision_m: 0.7406 - pred3_recall_m: 0.9036 - pred3_f1_m: 0.8120 - final_accuracy: 0.9426 - final_precision_m: 0.7396 - final_recall_m: 0.8993 - final_f1_m: 0.8098 - val_loss: 1.4708 - val_pred1_loss: 0.3921 - val_pred2_loss: 0.3893 - val_pred3_loss: 0.3937 - val_final_loss: 0.2958 - val_pred1_accuracy: 0.9120 - val_pred1_precision_m: 0.6360 - val_pred1_recall_m: 0.7546 - val_pred1_f1_m: 0.6847 - val_pred2_accuracy: 0.9186 - val_pred2_precision_m: 0.6716 - val_pred2_recall_m: 0.7374 - val_pred2_f1_m: 0.6974 - val_pred3_accuracy: 0.9176 - val_pred3_precision_m: 0.6688 - val_pred3_recall_m: 0.7327 - val_pred3_f1_m: 0.6938 - val_final_accuracy: 0.9166 - val_final_precision_m: 0.6647 - val_final_recall_m: 0.7307 - val_final_f1_m: 0.6908 - lr: 1.0000e-04 - 40s/epoch - 58ms/step
# Epoch 28/100
#
# Epoch 00028: val_final_loss improved from 0.28429 to 0.28425, saving model to Checkpoints/weights.28-0.28.hdf5
# 687/687 - 40s - loss: 0.8719 - pred1_loss: 0.2383 - pred2_loss: 0.2384 - pred3_loss: 0.2410 - final_loss: 0.1542 - pred1_accuracy: 0.9488 - pred1_precision_m: 0.7602 - pred1_recall_m: 0.9051 - pred1_f1_m: 0.8244 - pred2_accuracy: 0.9465 - pred2_precision_m: 0.7507 - pred2_recall_m: 0.9079 - pred2_f1_m: 0.8199 - pred3_accuracy: 0.9453 - pred3_precision_m: 0.7473 - pred3_recall_m: 0.9060 - pred3_f1_m: 0.8172 - final_accuracy: 0.9446 - final_precision_m: 0.7463 - final_recall_m: 0.9016 - final_f1_m: 0.8149 - val_loss: 1.4319 - val_pred1_loss: 0.3878 - val_pred2_loss: 0.3793 - val_pred3_loss: 0.3805 - val_final_loss: 0.2842 - val_pred1_accuracy: 0.9099 - val_pred1_precision_m: 0.6242 - val_pred1_recall_m: 0.7699 - val_pred1_f1_m: 0.6839 - val_pred2_accuracy: 0.9124 - val_pred2_precision_m: 0.6345 - val_pred2_recall_m: 0.7754 - val_pred2_f1_m: 0.6925 - val_pred3_accuracy: 0.9082 - val_pred3_precision_m: 0.6172 - val_pred3_recall_m: 0.7853 - val_pred3_f1_m: 0.6859 - val_final_accuracy: 0.9081 - val_final_precision_m: 0.6182 - val_final_recall_m: 0.7775 - val_final_f1_m: 0.6835 - lr: 1.0000e-04 - 40s/epoch - 59ms/step
# Epoch 29/100
#
# Epoch 00029: val_final_loss improved from 0.28425 to 0.27895, saving model to Checkpoints/weights.29-0.28.hdf5
# 687/687 - 41s - loss: 0.8395 - pred1_loss: 0.2284 - pred2_loss: 0.2299 - pred3_loss: 0.2334 - final_loss: 0.1478 - pred1_accuracy: 0.9513 - pred1_precision_m: 0.7713 - pred1_recall_m: 0.9107 - pred1_f1_m: 0.8336 - pred2_accuracy: 0.9488 - pred2_precision_m: 0.7608 - pred2_recall_m: 0.9123 - pred2_f1_m: 0.8282 - pred3_accuracy: 0.9474 - pred3_precision_m: 0.7561 - pred3_recall_m: 0.9100 - pred3_f1_m: 0.8245 - final_accuracy: 0.9465 - final_precision_m: 0.7543 - final_recall_m: 0.9063 - final_f1_m: 0.8220 - val_loss: 1.4068 - val_pred1_loss: 0.3811 - val_pred2_loss: 0.3716 - val_pred3_loss: 0.3752 - val_final_loss: 0.2790 - val_pred1_accuracy: 0.9183 - val_pred1_precision_m: 0.6622 - val_pred1_recall_m: 0.7553 - val_pred1_f1_m: 0.7002 - val_pred2_accuracy: 0.9177 - val_pred2_precision_m: 0.6566 - val_pred2_recall_m: 0.7727 - val_pred2_f1_m: 0.7047 - val_pred3_accuracy: 0.9182 - val_pred3_precision_m: 0.6612 - val_pred3_recall_m: 0.7644 - val_pred3_f1_m: 0.7039 - val_final_accuracy: 0.9168 - val_final_precision_m: 0.6558 - val_final_recall_m: 0.7618 - val_final_f1_m: 0.6997 - lr: 1.0000e-04 - 41s/epoch - 60ms/step
# Epoch 30/100
#
# Epoch 00030: val_final_loss improved from 0.27895 to 0.27667, saving model to Checkpoints/weights.30-0.28.hdf5
# 687/687 - 40s - loss: 0.8347 - pred1_loss: 0.2269 - pred2_loss: 0.2289 - pred3_loss: 0.2321 - final_loss: 0.1468 - pred1_accuracy: 0.9520 - pred1_precision_m: 0.7733 - pred1_recall_m: 0.9114 - pred1_f1_m: 0.8349 - pred2_accuracy: 0.9495 - pred2_precision_m: 0.7640 - pred2_recall_m: 0.9123 - pred2_f1_m: 0.8297 - pred3_accuracy: 0.9480 - pred3_precision_m: 0.7588 - pred3_recall_m: 0.9106 - pred3_f1_m: 0.8261 - final_accuracy: 0.9471 - final_precision_m: 0.7568 - final_recall_m: 0.9068 - final_f1_m: 0.8234 - val_loss: 1.4022 - val_pred1_loss: 0.3806 - val_pred2_loss: 0.3716 - val_pred3_loss: 0.3733 - val_final_loss: 0.2767 - val_pred1_accuracy: 0.9210 - val_pred1_precision_m: 0.6764 - val_pred1_recall_m: 0.7484 - val_pred1_f1_m: 0.7049 - val_pred2_accuracy: 0.9209 - val_pred2_precision_m: 0.6748 - val_pred2_recall_m: 0.7622 - val_pred2_f1_m: 0.7105 - val_pred3_accuracy: 0.9199 - val_pred3_precision_m: 0.6705 - val_pred3_recall_m: 0.7618 - val_pred3_f1_m: 0.7080 - val_final_accuracy: 0.9181 - val_final_precision_m: 0.6629 - val_final_recall_m: 0.7610 - val_final_f1_m: 0.7034 - lr: 1.0000e-04 - 40s/epoch - 58ms/step
# Epoch 31/100
#
# Epoch 00031: val_final_loss did not improve from 0.27667
# 687/687 - 40s - loss: 0.8148 - pred1_loss: 0.2208 - pred2_loss: 0.2238 - pred3_loss: 0.2274 - final_loss: 0.1428 - pred1_accuracy: 0.9541 - pred1_precision_m: 0.7818 - pred1_recall_m: 0.9139 - pred1_f1_m: 0.8412 - pred2_accuracy: 0.9510 - pred2_precision_m: 0.7686 - pred2_recall_m: 0.9154 - pred2_f1_m: 0.8341 - pred3_accuracy: 0.9494 - pred3_precision_m: 0.7630 - pred3_recall_m: 0.9136 - pred3_f1_m: 0.8302 - final_accuracy: 0.9487 - final_precision_m: 0.7617 - final_recall_m: 0.9097 - final_f1_m: 0.8279 - val_loss: 1.4071 - val_pred1_loss: 0.3824 - val_pred2_loss: 0.3706 - val_pred3_loss: 0.3746 - val_final_loss: 0.2795 - val_pred1_accuracy: 0.9212 - val_pred1_precision_m: 0.6778 - val_pred1_recall_m: 0.7447 - val_pred1_f1_m: 0.7044 - val_pred2_accuracy: 0.9201 - val_pred2_precision_m: 0.6693 - val_pred2_recall_m: 0.7661 - val_pred2_f1_m: 0.7094 - val_pred3_accuracy: 0.9197 - val_pred3_precision_m: 0.6691 - val_pred3_recall_m: 0.7606 - val_pred3_f1_m: 0.7069 - val_final_accuracy: 0.9192 - val_final_precision_m: 0.6696 - val_final_recall_m: 0.7530 - val_final_f1_m: 0.7038 - lr: 1.0000e-04 - 40s/epoch - 58ms/step
# Epoch 32/100
#
# Epoch 00032: val_final_loss improved from 0.27667 to 0.26578, saving model to Checkpoints/weights.32-0.27.hdf5
# 687/687 - 40s - loss: 0.7892 - pred1_loss: 0.2134 - pred2_loss: 0.2172 - pred3_loss: 0.2210 - final_loss: 0.1376 - pred1_accuracy: 0.9557 - pred1_precision_m: 0.7904 - pred1_recall_m: 0.9183 - pred1_f1_m: 0.8481 - pred2_accuracy: 0.9525 - pred2_precision_m: 0.7764 - pred2_recall_m: 0.9192 - pred2_f1_m: 0.8405 - pred3_accuracy: 0.9510 - pred3_precision_m: 0.7709 - pred3_recall_m: 0.9169 - pred3_f1_m: 0.8364 - final_accuracy: 0.9501 - final_precision_m: 0.7691 - final_recall_m: 0.9133 - final_f1_m: 0.8338 - val_loss: 1.3524 - val_pred1_loss: 0.3640 - val_pred2_loss: 0.3607 - val_pred3_loss: 0.3620 - val_final_loss: 0.2658 - val_pred1_accuracy: 0.9151 - val_pred1_precision_m: 0.6397 - val_pred1_recall_m: 0.7979 - val_pred1_f1_m: 0.7043 - val_pred2_accuracy: 0.9089 - val_pred2_precision_m: 0.6134 - val_pred2_recall_m: 0.8215 - val_pred2_f1_m: 0.6969 - val_pred3_accuracy: 0.9077 - val_pred3_precision_m: 0.6098 - val_pred3_recall_m: 0.8217 - val_pred3_f1_m: 0.6947 - val_final_accuracy: 0.9054 - val_final_precision_m: 0.6019 - val_final_recall_m: 0.8216 - val_final_f1_m: 0.6894 - lr: 1.0000e-04 - 40s/epoch - 58ms/step
# Epoch 33/100
#
# Epoch 00033: val_final_loss did not improve from 0.26578
# 687/687 - 38s - loss: 0.7719 - pred1_loss: 0.2082 - pred2_loss: 0.2126 - pred3_loss: 0.2168 - final_loss: 0.1343 - pred1_accuracy: 0.9574 - pred1_precision_m: 0.7967 - pred1_recall_m: 0.9213 - pred1_f1_m: 0.8531 - pred2_accuracy: 0.9540 - pred2_precision_m: 0.7822 - pred2_recall_m: 0.9217 - pred2_f1_m: 0.8450 - pred3_accuracy: 0.9523 - pred3_precision_m: 0.7759 - pred3_recall_m: 0.9194 - pred3_f1_m: 0.8404 - final_accuracy: 0.9515 - final_precision_m: 0.7742 - final_recall_m: 0.9155 - final_f1_m: 0.8377 - val_loss: 1.3787 - val_pred1_loss: 0.3698 - val_pred2_loss: 0.3671 - val_pred3_loss: 0.3697 - val_final_loss: 0.2722 - val_pred1_accuracy: 0.9254 - val_pred1_precision_m: 0.6960 - val_pred1_recall_m: 0.7537 - val_pred1_f1_m: 0.7180 - val_pred2_accuracy: 0.9228 - val_pred2_precision_m: 0.6825 - val_pred2_recall_m: 0.7648 - val_pred2_f1_m: 0.7157 - val_pred3_accuracy: 0.9229 - val_pred3_precision_m: 0.6852 - val_pred3_recall_m: 0.7592 - val_pred3_f1_m: 0.7148 - val_final_accuracy: 0.9213 - val_final_precision_m: 0.6775 - val_final_recall_m: 0.7604 - val_final_f1_m: 0.7111 - lr: 1.0000e-04 - 38s/epoch - 55ms/step
# Epoch 34/100
#
# Epoch 00034: val_final_loss did not improve from 0.26578
# 687/687 - 40s - loss: 0.7578 - pred1_loss: 0.2028 - pred2_loss: 0.2093 - pred3_loss: 0.2137 - final_loss: 0.1319 - pred1_accuracy: 0.9593 - pred1_precision_m: 0.8042 - pred1_recall_m: 0.9235 - pred1_f1_m: 0.8584 - pred2_accuracy: 0.9553 - pred2_precision_m: 0.7864 - pred2_recall_m: 0.9229 - pred2_f1_m: 0.8479 - pred3_accuracy: 0.9534 - pred3_precision_m: 0.7790 - pred3_recall_m: 0.9213 - pred3_f1_m: 0.8430 - final_accuracy: 0.9525 - final_precision_m: 0.7767 - final_recall_m: 0.9175 - final_f1_m: 0.8402 - val_loss: 1.3698 - val_pred1_loss: 0.3700 - val_pred2_loss: 0.3662 - val_pred3_loss: 0.3643 - val_final_loss: 0.2693 - val_pred1_accuracy: 0.9251 - val_pred1_precision_m: 0.6944 - val_pred1_recall_m: 0.7538 - val_pred1_f1_m: 0.7174 - val_pred2_accuracy: 0.9241 - val_pred2_precision_m: 0.6891 - val_pred2_recall_m: 0.7616 - val_pred2_f1_m: 0.7180 - val_pred3_accuracy: 0.9215 - val_pred3_precision_m: 0.6741 - val_pred3_recall_m: 0.7726 - val_pred3_f1_m: 0.7148 - val_final_accuracy: 0.9207 - val_final_precision_m: 0.6724 - val_final_recall_m: 0.7670 - val_final_f1_m: 0.7114 - lr: 1.0000e-04 - 40s/epoch - 58ms/step
# Epoch 35/100
#
# Epoch 00035: val_final_loss did not improve from 0.26578
# 687/687 - 40s - loss: 0.7398 - pred1_loss: 0.1961 - pred2_loss: 0.2051 - pred3_loss: 0.2099 - final_loss: 0.1287 - pred1_accuracy: 0.9607 - pred1_precision_m: 0.8114 - pred1_recall_m: 0.9271 - pred1_f1_m: 0.8644 - pred2_accuracy: 0.9562 - pred2_precision_m: 0.7915 - pred2_recall_m: 0.9252 - pred2_f1_m: 0.8520 - pred3_accuracy: 0.9544 - pred3_precision_m: 0.7846 - pred3_recall_m: 0.9227 - pred3_f1_m: 0.8470 - final_accuracy: 0.9535 - final_precision_m: 0.7826 - final_recall_m: 0.9191 - final_f1_m: 0.8443 - val_loss: 1.4057 - val_pred1_loss: 0.3739 - val_pred2_loss: 0.3761 - val_pred3_loss: 0.3750 - val_final_loss: 0.2807 - val_pred1_accuracy: 0.9256 - val_pred1_precision_m: 0.7002 - val_pred1_recall_m: 0.7443 - val_pred1_f1_m: 0.7159 - val_pred2_accuracy: 0.9273 - val_pred2_precision_m: 0.7151 - val_pred2_recall_m: 0.7340 - val_pred2_f1_m: 0.7184 - val_pred3_accuracy: 0.9236 - val_pred3_precision_m: 0.6916 - val_pred3_recall_m: 0.7471 - val_pred3_f1_m: 0.7125 - val_final_accuracy: 0.9234 - val_final_precision_m: 0.6937 - val_final_recall_m: 0.7386 - val_final_f1_m: 0.7097 - lr: 1.0000e-04 - 40s/epoch - 58ms/step
# Epoch 36/100
#
# Epoch 00036: val_final_loss improved from 0.26578 to 0.26287, saving model to Checkpoints/weights.36-0.26.hdf5
# 687/687 - 40s - loss: 0.7268 - pred1_loss: 0.1937 - pred2_loss: 0.2013 - pred3_loss: 0.2061 - final_loss: 0.1257 - pred1_accuracy: 0.9617 - pred1_precision_m: 0.8156 - pred1_recall_m: 0.9277 - pred1_f1_m: 0.8669 - pred2_accuracy: 0.9575 - pred2_precision_m: 0.7964 - pred2_recall_m: 0.9270 - pred2_f1_m: 0.8556 - pred3_accuracy: 0.9555 - pred3_precision_m: 0.7884 - pred3_recall_m: 0.9251 - pred3_f1_m: 0.8502 - final_accuracy: 0.9547 - final_precision_m: 0.7866 - final_recall_m: 0.9213 - final_f1_m: 0.8477 - val_loss: 1.3411 - val_pred1_loss: 0.3633 - val_pred2_loss: 0.3556 - val_pred3_loss: 0.3594 - val_final_loss: 0.2629 - val_pred1_accuracy: 0.9150 - val_pred1_precision_m: 0.6380 - val_pred1_recall_m: 0.7982 - val_pred1_f1_m: 0.7033 - val_pred2_accuracy: 0.9163 - val_pred2_precision_m: 0.6431 - val_pred2_recall_m: 0.8068 - val_pred2_f1_m: 0.7101 - val_pred3_accuracy: 0.9135 - val_pred3_precision_m: 0.6323 - val_pred3_recall_m: 0.8080 - val_pred3_f1_m: 0.7039 - val_final_accuracy: 0.9118 - val_final_precision_m: 0.6260 - val_final_recall_m: 0.8081 - val_final_f1_m: 0.7000 - lr: 1.0000e-04 - 40s/epoch - 58ms/step
# Epoch 37/100
#
# Epoch 00037: val_final_loss did not improve from 0.26287
# 687/687 - 40s - loss: 0.7103 - pred1_loss: 0.1882 - pred2_loss: 0.1969 - pred3_loss: 0.2024 - final_loss: 0.1228 - pred1_accuracy: 0.9632 - pred1_precision_m: 0.8217 - pred1_recall_m: 0.9307 - pred1_f1_m: 0.8718 - pred2_accuracy: 0.9589 - pred2_precision_m: 0.8025 - pred2_recall_m: 0.9288 - pred2_f1_m: 0.8600 - pred3_accuracy: 0.9567 - pred3_precision_m: 0.7936 - pred3_recall_m: 0.9267 - pred3_f1_m: 0.8539 - final_accuracy: 0.9559 - final_precision_m: 0.7915 - final_recall_m: 0.9231 - final_f1_m: 0.8513 - val_loss: 1.4150 - val_pred1_loss: 0.3747 - val_pred2_loss: 0.3796 - val_pred3_loss: 0.3784 - val_final_loss: 0.2823 - val_pred1_accuracy: 0.9265 - val_pred1_precision_m: 0.7064 - val_pred1_recall_m: 0.7410 - val_pred1_f1_m: 0.7180 - val_pred2_accuracy: 0.9266 - val_pred2_precision_m: 0.7138 - val_pred2_recall_m: 0.7309 - val_pred2_f1_m: 0.7169 - val_pred3_accuracy: 0.9245 - val_pred3_precision_m: 0.6997 - val_pred3_recall_m: 0.7391 - val_pred3_f1_m: 0.7136 - val_final_accuracy: 0.9238 - val_final_precision_m: 0.6981 - val_final_recall_m: 0.7342 - val_final_f1_m: 0.7105 - lr: 1.0000e-04 - 40s/epoch - 59ms/step
# Epoch 38/100
#
# Epoch 00038: val_final_loss did not improve from 0.26287
# 687/687 - 39s - loss: 0.6948 - pred1_loss: 0.1830 - pred2_loss: 0.1933 - pred3_loss: 0.1986 - final_loss: 0.1199 - pred1_accuracy: 0.9644 - pred1_precision_m: 0.8269 - pred1_recall_m: 0.9339 - pred1_f1_m: 0.8762 - pred2_accuracy: 0.9596 - pred2_precision_m: 0.8059 - pred2_recall_m: 0.9311 - pred2_f1_m: 0.8630 - pred3_accuracy: 0.9575 - pred3_precision_m: 0.7975 - pred3_recall_m: 0.9290 - pred3_f1_m: 0.8573 - final_accuracy: 0.9565 - final_precision_m: 0.7941 - final_recall_m: 0.9259 - final_f1_m: 0.8541 - val_loss: 1.3710 - val_pred1_loss: 0.3670 - val_pred2_loss: 0.3672 - val_pred3_loss: 0.3664 - val_final_loss: 0.2704 - val_pred1_accuracy: 0.9239 - val_pred1_precision_m: 0.6849 - val_pred1_recall_m: 0.7633 - val_pred1_f1_m: 0.7166 - val_pred2_accuracy: 0.9274 - val_pred2_precision_m: 0.7088 - val_pred2_recall_m: 0.7491 - val_pred2_f1_m: 0.7230 - val_pred3_accuracy: 0.9250 - val_pred3_precision_m: 0.6943 - val_pred3_recall_m: 0.7579 - val_pred3_f1_m: 0.7195 - val_final_accuracy: 0.9236 - val_final_precision_m: 0.6876 - val_final_recall_m: 0.7570 - val_final_f1_m: 0.7155 - lr: 1.0000e-04 - 39s/epoch - 57ms/step
# Epoch 39/100
#
# Epoch 00039: val_final_loss did not improve from 0.26287
# ...
# Epoch 89/100
#
# Epoch 00089: val_final_loss did not improve from 0.24459
# 687/687 - 39s - loss: 0.3231 - pred1_loss: 0.0676 - pred2_loss: 0.0891 - pred3_loss: 0.1085 - final_loss: 0.0579 - pred1_accuracy: 0.9918 - pred1_precision_m: 0.9599 - pred1_recall_m: 0.9815 - pred1_f1_m: 0.9705 - pred2_accuracy: 0.9869 - pred2_precision_m: 0.9327 - pred2_recall_m: 0.9753 - pred2_f1_m: 0.9534 - pred3_accuracy: 0.9820 - pred3_precision_m: 0.9071 - pred3_recall_m: 0.9689 - pred3_f1_m: 0.9368 - final_accuracy: 0.9799 - final_precision_m: 0.8974 - final_recall_m: 0.9649 - final_f1_m: 0.9298 - val_loss: 1.2512 - val_pred1_loss: 0.3394 - val_pred2_loss: 0.3298 - val_pred3_loss: 0.3365 - val_final_loss: 0.2455 - val_pred1_accuracy: 0.9441 - val_pred1_precision_m: 0.8116 - val_pred1_recall_m: 0.7382 - val_pred1_f1_m: 0.7667 - val_pred2_accuracy: 0.9430 - val_pred2_precision_m: 0.7923 - val_pred2_recall_m: 0.7600 - val_pred2_f1_m: 0.7700 - val_pred3_accuracy: 0.9406 - val_pred3_precision_m: 0.7793 - val_pred3_recall_m: 0.7572 - val_pred3_f1_m: 0.7623 - val_final_accuracy: 0.9392 - val_final_precision_m: 0.7724 - val_final_recall_m: 0.7544 - val_final_f1_m: 0.7576 - lr: 3.3000e-05 - 39s/epoch - 57ms/step
# Epoch 90/100
#
# Epoch 00090: val_final_loss improved from 0.24459 to 0.24132, saving model to Checkpoints/weights.90-0.24.hdf5
# 687/687 - 41s - loss: 0.3200 - pred1_loss: 0.0672 - pred2_loss: 0.0879 - pred3_loss: 0.1075 - final_loss: 0.0574 - pred1_accuracy: 0.9919 - pred1_precision_m: 0.9601 - pred1_recall_m: 0.9817 - pred1_f1_m: 0.9706 - pred2_accuracy: 0.9871 - pred2_precision_m: 0.9337 - pred2_recall_m: 0.9760 - pred2_f1_m: 0.9542 - pred3_accuracy: 0.9822 - pred3_precision_m: 0.9080 - pred3_recall_m: 0.9695 - pred3_f1_m: 0.9376 - final_accuracy: 0.9801 - final_precision_m: 0.8981 - final_recall_m: 0.9654 - final_f1_m: 0.9304 - val_loss: 1.2381 - val_pred1_loss: 0.3379 - val_pred2_loss: 0.3267 - val_pred3_loss: 0.3321 - val_final_loss: 0.2413 - val_pred1_accuracy: 0.9438 - val_pred1_precision_m: 0.8059 - val_pred1_recall_m: 0.7424 - val_pred1_f1_m: 0.7666 - val_pred2_accuracy: 0.9419 - val_pred2_precision_m: 0.7798 - val_pred2_recall_m: 0.7692 - val_pred2_f1_m: 0.7687 - val_pred3_accuracy: 0.9390 - val_pred3_precision_m: 0.7632 - val_pred3_recall_m: 0.7701 - val_pred3_f1_m: 0.7610 - val_final_accuracy: 0.9375 - val_final_precision_m: 0.7555 - val_final_recall_m: 0.7676 - val_final_f1_m: 0.7559 - lr: 3.3000e-05 - 41s/epoch - 59ms/step
# Epoch 91/100
#
# Epoch 00091: val_final_loss did not improve from 0.24132
# 687/687 - 40s - loss: 0.3187 - pred1_loss: 0.0670 - pred2_loss: 0.0874 - pred3_loss: 0.1072 - final_loss: 0.0572 - pred1_accuracy: 0.9920 - pred1_precision_m: 0.9612 - pred1_recall_m: 0.9814 - pred1_f1_m: 0.9710 - pred2_accuracy: 0.9874 - pred2_precision_m: 0.9354 - pred2_recall_m: 0.9756 - pred2_f1_m: 0.9549 - pred3_accuracy: 0.9825 - pred3_precision_m: 0.9094 - pred3_recall_m: 0.9690 - pred3_f1_m: 0.9381 - final_accuracy: 0.9804 - final_precision_m: 0.8994 - final_recall_m: 0.9651 - final_f1_m: 0.9309 - val_loss: 1.2371 - val_pred1_loss: 0.3363 - val_pred2_loss: 0.3274 - val_pred3_loss: 0.3318 - val_final_loss: 0.2416 - val_pred1_accuracy: 0.9436 - val_pred1_precision_m: 0.8026 - val_pred1_recall_m: 0.7451 - val_pred1_f1_m: 0.7666 - val_pred2_accuracy: 0.9420 - val_pred2_precision_m: 0.7813 - val_pred2_recall_m: 0.7675 - val_pred2_f1_m: 0.7686 - val_pred3_accuracy: 0.9389 - val_pred3_precision_m: 0.7621 - val_pred3_recall_m: 0.7708 - val_pred3_f1_m: 0.7608 - val_final_accuracy: 0.9376 - val_final_precision_m: 0.7565 - val_final_recall_m: 0.7668 - val_final_f1_m: 0.7561 - lr: 3.3000e-05 - 40s/epoch - 58ms/step
# Epoch 92/100
#
# Epoch 00092: val_final_loss did not improve from 0.24132
# 687/687 - 39s - loss: 0.3150 - pred1_loss: 0.0660 - pred2_loss: 0.0863 - pred3_loss: 0.1060 - final_loss: 0.0566 - pred1_accuracy: 0.9921 - pred1_precision_m: 0.9615 - pred1_recall_m: 0.9819 - pred1_f1_m: 0.9715 - pred2_accuracy: 0.9876 - pred2_precision_m: 0.9362 - pred2_recall_m: 0.9761 - pred2_f1_m: 0.9556 - pred3_accuracy: 0.9827 - pred3_precision_m: 0.9104 - pred3_recall_m: 0.9696 - pred3_f1_m: 0.9389 - final_accuracy: 0.9805 - final_precision_m: 0.8998 - final_recall_m: 0.9657 - final_f1_m: 0.9314 - val_loss: 1.2621 - val_pred1_loss: 0.3409 - val_pred2_loss: 0.3328 - val_pred3_loss: 0.3397 - val_final_loss: 0.2487 - val_pred1_accuracy: 0.9440 - val_pred1_precision_m: 0.8112 - val_pred1_recall_m: 0.7369 - val_pred1_f1_m: 0.7659 - val_pred2_accuracy: 0.9432 - val_pred2_precision_m: 0.7964 - val_pred2_recall_m: 0.7542 - val_pred2_f1_m: 0.7687 - val_pred3_accuracy: 0.9409 - val_pred3_precision_m: 0.7848 - val_pred3_recall_m: 0.7506 - val_pred3_f1_m: 0.7614 - val_final_accuracy: 0.9394 - val_final_precision_m: 0.7767 - val_final_recall_m: 0.7483 - val_final_f1_m: 0.7564 - lr: 3.3000e-05 - 39s/epoch - 57ms/step
# Epoch 93/100
#
# Epoch 00093: val_final_loss did not improve from 0.24132
# 687/687 - 39s - loss: 0.3100 - pred1_loss: 0.0651 - pred2_loss: 0.0848 - pred3_loss: 0.1045 - final_loss: 0.0556 - pred1_accuracy: 0.9923 - pred1_precision_m: 0.9625 - pred1_recall_m: 0.9823 - pred1_f1_m: 0.9722 - pred2_accuracy: 0.9878 - pred2_precision_m: 0.9378 - pred2_recall_m: 0.9769 - pred2_f1_m: 0.9568 - pred3_accuracy: 0.9829 - pred3_precision_m: 0.9121 - pred3_recall_m: 0.9704 - pred3_f1_m: 0.9401 - final_accuracy: 0.9807 - final_precision_m: 0.9015 - final_recall_m: 0.9664 - final_f1_m: 0.9326 - val_loss: 1.2511 - val_pred1_loss: 0.3382 - val_pred2_loss: 0.3319 - val_pred3_loss: 0.3360 - val_final_loss: 0.2450 - val_pred1_accuracy: 0.9436 - val_pred1_precision_m: 0.8046 - val_pred1_recall_m: 0.7423 - val_pred1_f1_m: 0.7658 - val_pred2_accuracy: 0.9432 - val_pred2_precision_m: 0.7961 - val_pred2_recall_m: 0.7556 - val_pred2_f1_m: 0.7693 - val_pred3_accuracy: 0.9404 - val_pred3_precision_m: 0.7773 - val_pred3_recall_m: 0.7586 - val_pred3_f1_m: 0.7620 - val_final_accuracy: 0.9387 - val_final_precision_m: 0.7681 - val_final_recall_m: 0.7570 - val_final_f1_m: 0.7568 - lr: 3.3000e-05 - 39s/epoch - 57ms/step
# Epoch 94/100
#
# Epoch 00094: val_final_loss did not improve from 0.24132
# 687/687 - 39s - loss: 0.3098 - pred1_loss: 0.0652 - pred2_loss: 0.0846 - pred3_loss: 0.1044 - final_loss: 0.0557 - pred1_accuracy: 0.9923 - pred1_precision_m: 0.9626 - pred1_recall_m: 0.9820 - pred1_f1_m: 0.9721 - pred2_accuracy: 0.9880 - pred2_precision_m: 0.9381 - pred2_recall_m: 0.9767 - pred2_f1_m: 0.9569 - pred3_accuracy: 0.9831 - pred3_precision_m: 0.9126 - pred3_recall_m: 0.9702 - pred3_f1_m: 0.9403 - final_accuracy: 0.9809 - final_precision_m: 0.9019 - final_recall_m: 0.9661 - final_f1_m: 0.9327 - val_loss: 1.2653 - val_pred1_loss: 0.3432 - val_pred2_loss: 0.3336 - val_pred3_loss: 0.3396 - val_final_loss: 0.2489 - val_pred1_accuracy: 0.9441 - val_pred1_precision_m: 0.8156 - val_pred1_recall_m: 0.7318 - val_pred1_f1_m: 0.7648 - val_pred2_accuracy: 0.9434 - val_pred2_precision_m: 0.7994 - val_pred2_recall_m: 0.7519 - val_pred2_f1_m: 0.7688 - val_pred3_accuracy: 0.9410 - val_pred3_precision_m: 0.7858 - val_pred3_recall_m: 0.7503 - val_pred3_f1_m: 0.7617 - val_final_accuracy: 0.9395 - val_final_precision_m: 0.7782 - val_final_recall_m: 0.7474 - val_final_f1_m: 0.7566 - lr: 3.3000e-05 - 39s/epoch - 56ms/step
# Epoch 95/100
#
# Epoch 00095: val_final_loss improved from 0.24132 to 0.24120, saving model to Checkpoints/weights.95-0.24.hdf5
# 687/687 - 41s - loss: 0.3065 - pred1_loss: 0.0644 - pred2_loss: 0.0836 - pred3_loss: 0.1034 - final_loss: 0.0550 - pred1_accuracy: 0.9925 - pred1_precision_m: 0.9635 - pred1_recall_m: 0.9823 - pred1_f1_m: 0.9727 - pred2_accuracy: 0.9882 - pred2_precision_m: 0.9393 - pred2_recall_m: 0.9771 - pred2_f1_m: 0.9577 - pred3_accuracy: 0.9833 - pred3_precision_m: 0.9136 - pred3_recall_m: 0.9706 - pred3_f1_m: 0.9411 - final_accuracy: 0.9811 - final_precision_m: 0.9032 - final_recall_m: 0.9665 - final_f1_m: 0.9336 - val_loss: 1.2358 - val_pred1_loss: 0.3368 - val_pred2_loss: 0.3271 - val_pred3_loss: 0.3307 - val_final_loss: 0.2412 - val_pred1_accuracy: 0.9438 - val_pred1_precision_m: 0.8051 - val_pred1_recall_m: 0.7443 - val_pred1_f1_m: 0.7671 - val_pred2_accuracy: 0.9426 - val_pred2_precision_m: 0.7861 - val_pred2_recall_m: 0.7660 - val_pred2_f1_m: 0.7700 - val_pred3_accuracy: 0.9393 - val_pred3_precision_m: 0.7641 - val_pred3_recall_m: 0.7715 - val_pred3_f1_m: 0.7620 - val_final_accuracy: 0.9379 - val_final_precision_m: 0.7588 - val_final_recall_m: 0.7665 - val_final_f1_m: 0.7569 - lr: 3.3000e-05 - 41s/epoch - 59ms/step
# Epoch 96/100
#
# Epoch 00096: val_final_loss did not improve from 0.24120
# 687/687 - 38s - loss: 0.3062 - pred1_loss: 0.0645 - pred2_loss: 0.0834 - pred3_loss: 0.1033 - final_loss: 0.0552 - pred1_accuracy: 0.9925 - pred1_precision_m: 0.9641 - pred1_recall_m: 0.9820 - pred1_f1_m: 0.9729 - pred2_accuracy: 0.9883 - pred2_precision_m: 0.9404 - pred2_recall_m: 0.9768 - pred2_f1_m: 0.9581 - pred3_accuracy: 0.9835 - pred3_precision_m: 0.9144 - pred3_recall_m: 0.9702 - pred3_f1_m: 0.9413 - final_accuracy: 0.9812 - final_precision_m: 0.9033 - final_recall_m: 0.9662 - final_f1_m: 0.9335 - val_loss: 1.2376 - val_pred1_loss: 0.3357 - val_pred2_loss: 0.3273 - val_pred3_loss: 0.3325 - val_final_loss: 0.2422 - val_pred1_accuracy: 0.9437 - val_pred1_precision_m: 0.8026 - val_pred1_recall_m: 0.7463 - val_pred1_f1_m: 0.7671 - val_pred2_accuracy: 0.9425 - val_pred2_precision_m: 0.7861 - val_pred2_recall_m: 0.7657 - val_pred2_f1_m: 0.7698 - val_pred3_accuracy: 0.9399 - val_pred3_precision_m: 0.7703 - val_pred3_recall_m: 0.7664 - val_pred3_f1_m: 0.7626 - val_final_accuracy: 0.9384 - val_final_precision_m: 0.7633 - val_final_recall_m: 0.7631 - val_final_f1_m: 0.7574 - lr: 3.3000e-05 - 38s/epoch - 55ms/step
# Epoch 97/100
#
# Epoch 00097: val_final_loss did not improve from 0.24120
# 687/687 - 38s - loss: 0.2998 - pred1_loss: 0.0629 - pred2_loss: 0.0816 - pred3_loss: 0.1014 - final_loss: 0.0539 - pred1_accuracy: 0.9926 - pred1_precision_m: 0.9648 - pred1_recall_m: 0.9830 - pred1_f1_m: 0.9737 - pred2_accuracy: 0.9884 - pred2_precision_m: 0.9411 - pred2_recall_m: 0.9781 - pred2_f1_m: 0.9591 - pred3_accuracy: 0.9836 - pred3_precision_m: 0.9154 - pred3_recall_m: 0.9716 - pred3_f1_m: 0.9425 - final_accuracy: 0.9814 - final_precision_m: 0.9049 - final_recall_m: 0.9674 - final_f1_m: 0.9349 - val_loss: 1.2713 - val_pred1_loss: 0.3435 - val_pred2_loss: 0.3355 - val_pred3_loss: 0.3415 - val_final_loss: 0.2508 - val_pred1_accuracy: 0.9443 - val_pred1_precision_m: 0.8173 - val_pred1_recall_m: 0.7305 - val_pred1_f1_m: 0.7648 - val_pred2_accuracy: 0.9440 - val_pred2_precision_m: 0.8069 - val_pred2_recall_m: 0.7461 - val_pred2_f1_m: 0.7692 - val_pred3_accuracy: 0.9416 - val_pred3_precision_m: 0.7928 - val_pred3_recall_m: 0.7449 - val_pred3_f1_m: 0.7621 - val_final_accuracy: 0.9401 - val_final_precision_m: 0.7850 - val_final_recall_m: 0.7421 - val_final_f1_m: 0.7570 - lr: 3.3000e-05 - 38s/epoch - 56ms/step
# Epoch 98/100
#
# Epoch 00098: val_final_loss did not improve from 0.24120
# 687/687 - 40s - loss: 0.3005 - pred1_loss: 0.0632 - pred2_loss: 0.0817 - pred3_loss: 0.1016 - final_loss: 0.0540 - pred1_accuracy: 0.9927 - pred1_precision_m: 0.9644 - pred1_recall_m: 0.9828 - pred1_f1_m: 0.9734 - pred2_accuracy: 0.9886 - pred2_precision_m: 0.9416 - pred2_recall_m: 0.9777 - pred2_f1_m: 0.9592 - pred3_accuracy: 0.9837 - pred3_precision_m: 0.9158 - pred3_recall_m: 0.9712 - pred3_f1_m: 0.9425 - final_accuracy: 0.9815 - final_precision_m: 0.9051 - final_recall_m: 0.9671 - final_f1_m: 0.9349 - val_loss: 1.2784 - val_pred1_loss: 0.3482 - val_pred2_loss: 0.3365 - val_pred3_loss: 0.3418 - val_final_loss: 0.2519 - val_pred1_accuracy: 0.9445 - val_pred1_precision_m: 0.8255 - val_pred1_recall_m: 0.7223 - val_pred1_f1_m: 0.7634 - val_pred2_accuracy: 0.9437 - val_pred2_precision_m: 0.8058 - val_pred2_recall_m: 0.7459 - val_pred2_f1_m: 0.7683 - val_pred3_accuracy: 0.9413 - val_pred3_precision_m: 0.7911 - val_pred3_recall_m: 0.7454 - val_pred3_f1_m: 0.7614 - val_final_accuracy: 0.9400 - val_final_precision_m: 0.7858 - val_final_recall_m: 0.7405 - val_final_f1_m: 0.7563 - lr: 3.3000e-05 - 40s/epoch - 58ms/step
# Epoch 99/100
#
# Epoch 00099: val_final_loss did not improve from 0.24120
# 687/687 - 39s - loss: 0.2984 - pred1_loss: 0.0630 - pred2_loss: 0.0809 - pred3_loss: 0.1009 - final_loss: 0.0536 - pred1_accuracy: 0.9927 - pred1_precision_m: 0.9651 - pred1_recall_m: 0.9827 - pred1_f1_m: 0.9737 - pred2_accuracy: 0.9887 - pred2_precision_m: 0.9424 - pred2_recall_m: 0.9782 - pred2_f1_m: 0.9598 - pred3_accuracy: 0.9839 - pred3_precision_m: 0.9166 - pred3_recall_m: 0.9716 - pred3_f1_m: 0.9431 - final_accuracy: 0.9816 - final_precision_m: 0.9057 - final_recall_m: 0.9674 - final_f1_m: 0.9354 - val_loss: 1.2802 - val_pred1_loss: 0.3454 - val_pred2_loss: 0.3391 - val_pred3_loss: 0.3432 - val_final_loss: 0.2525 - val_pred1_accuracy: 0.9445 - val_pred1_precision_m: 0.8221 - val_pred1_recall_m: 0.7267 - val_pred1_f1_m: 0.7646 - val_pred2_accuracy: 0.9442 - val_pred2_precision_m: 0.8132 - val_pred2_recall_m: 0.7394 - val_pred2_f1_m: 0.7681 - val_pred3_accuracy: 0.9415 - val_pred3_precision_m: 0.7939 - val_pred3_recall_m: 0.7423 - val_pred3_f1_m: 0.7611 - val_final_accuracy: 0.9400 - val_final_precision_m: 0.7861 - val_final_recall_m: 0.7394 - val_final_f1_m: 0.7560 - lr: 3.3000e-05 - 39s/epoch - 57ms/step
# Epoch 100/100
#
# Epoch 00100: val_final_loss improved from 0.24120 to 0.24042, saving model to Checkpoints/weights.100-0.24.hdf5
# 687/687 - 40s - loss: 0.2956 - pred1_loss: 0.0623 - pred2_loss: 0.0801 - pred3_loss: 0.1000 - final_loss: 0.0532 - pred1_accuracy: 0.9928 - pred1_precision_m: 0.9659 - pred1_recall_m: 0.9828 - pred1_f1_m: 0.9742 - pred2_accuracy: 0.9889 - pred2_precision_m: 0.9433 - pred2_recall_m: 0.9782 - pred2_f1_m: 0.9603 - pred3_accuracy: 0.9841 - pred3_precision_m: 0.9176 - pred3_recall_m: 0.9717 - pred3_f1_m: 0.9438 - final_accuracy: 0.9817 - final_precision_m: 0.9061 - final_recall_m: 0.9678 - final_f1_m: 0.9358 - val_loss: 1.2307 - val_pred1_loss: 0.3339 - val_pred2_loss: 0.3263 - val_pred3_loss: 0.3300 - val_final_loss: 0.2404 - val_pred1_accuracy: 0.9430 - val_pred1_precision_m: 0.7952 - val_pred1_recall_m: 0.7516 - val_pred1_f1_m: 0.7666 - val_pred2_accuracy: 0.9425 - val_pred2_precision_m: 0.7846 - val_pred2_recall_m: 0.7679 - val_pred2_f1_m: 0.7701 - val_pred3_accuracy: 0.9393 - val_pred3_precision_m: 0.7635 - val_pred3_recall_m: 0.7730 - val_pred3_f1_m: 0.7624 - val_final_accuracy: 0.9382 - val_final_precision_m: 0.7600 - val_final_recall_m: 0.7672 - val_final_f1_m: 0.7579 - lr: 3.3000e-05 - 40s/epoch - 59ms/step
# 18/18 - 3s - loss: 2.6676 - pred1_loss: 0.7054 - pred2_loss: 0.6861 - pred3_loss: 0.6773 - final_loss: 0.5988 - pred1_accuracy: 0.8512 - pred1_precision_m: 0.4502 - pred1_recall_m: 0.3478 - pred1_f1_m: 0.3881 - pred2_accuracy: 0.8519 - pred2_precision_m: 0.4561 - pred2_recall_m: 0.3766 - pred2_f1_m: 0.4079 - pred3_accuracy: 0.8496 - pred3_precision_m: 0.4496 - pred3_recall_m: 0.3925 - pred3_f1_m: 0.4145 - final_accuracy: 0.8503 - final_precision_m: 0.4511 - final_recall_m: 0.3868 - final_f1_m: 0.4120 - 3s/epoch - 141ms/step
# The metrics for the test set with learning rate 0.0001,  filters 32, and batch size 8 is [2.667609930038452, 0.7054117918014526, 0.6861116290092468, 0.6772575974464417, 0.5988290309906006, 0.851198673248291, 0.45019641518592834, 0.347813218832016, 0.38807010650634766, 0.85187828540802, 0.45605647563934326, 0.3766290843486786, 0.4078744947910309, 0.8496471047401428, 0.4495624303817749, 0.3925381302833557, 0.4145342707633972, 0.8502619862556458, 0.451069712638855, 0.38675612211227417, 0.4120022654533386]
# __________________________________________________________________________________________________________________________________________________________________________
# time: 1h 6min 32s (started: 2022-04-07 11:02:12 +02:00)

# %% [markdown]
# ## Testing the model

# %% [markdown]
# ### Evaluate the model

# %% [markdown]
# LOAD MODELS FROM SAVED WEIGHTS (FOR PARTICULAR EPOCH WITH BEST PERFORMANCE)

# %%
# To load model weights from older runs, if present.
# Please load previous metrics and functions and other required variables.
# Also, insert the argument values manually for the model.

# Define the model architecture
            def ms_attUNet(lr,filtersFirstLayer, pretrained_weights=None, input_size=(PATCHSIZE, PATCHSIZE, NBANDS)):

                img_input = Input(shape=input_size, name='input_scale1')
                scale_img_2 = AveragePooling2D(pool_size=(2, 2), name='input_scale2')(img_input)
                scale_img_3 = AveragePooling2D(pool_size=(2, 2), name='input_scale3')(scale_img_2)
                scale_img_4 = AveragePooling2D(pool_size=(2, 2), name='input_scale4')(scale_img_3)

                conv1 = UnetConv2D(img_input, filtersFirstLayer, is_batchnorm=True, name='conv1')
                pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

                input2 = Conv2D(filtersFirstLayer*2, (3, 3), padding='same', activation='relu', name='conv_scale2')(scale_img_2)
                input2 = concatenate([input2, pool1], axis=3)
                conv2 = UnetConv2D(input2, filtersFirstLayer*2, is_batchnorm=True, name='conv2')
                pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

                input3 = Conv2D(filtersFirstLayer*4, (3, 3), padding='same', activation='relu', name='conv_scale3')(scale_img_3)
                input3 = concatenate([input3, pool2], axis=3)
                conv3 = UnetConv2D(input3, filtersFirstLayer*4, is_batchnorm=True, name='conv3')
                pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

                input4 = Conv2D(filtersFirstLayer*8, (3, 3), padding='same', activation='relu', name='conv_scale4')(scale_img_4)
                input4 = concatenate([input4, pool3], axis=3)
                conv4 = UnetConv2D(input4, filtersFirstLayer*2, is_batchnorm=True, name='conv4')
                pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)

                center = UnetConv2D(pool4, filtersFirstLayer*16, is_batchnorm=True, name='center')

                g1 = UnetGatingSignal(center, is_batchnorm=True, name='g1')
                attn1 = AttnGatingBlock(conv4, g1, filtersFirstLayer*4, '_1')
                up1 = concatenate([Conv2DTranspose(filtersFirstLayer, (3,3), strides=(2,2), padding='same', activation='relu', kernel_initializer=kinit)(center), attn1], name='up1')

                g2 = UnetGatingSignal(up1, is_batchnorm=True, name='g2')
                attn2 = AttnGatingBlock(conv3, g2, filtersFirstLayer*2, '_2')
                up2 = concatenate([Conv2DTranspose(filtersFirstLayer*2, (3,3), strides=(2,2), padding='same', activation='relu', kernel_initializer=kinit)(up1), attn2], name='up2')

                g3 = UnetGatingSignal(up1, is_batchnorm=True, name='g3')
                attn3 = AttnGatingBlock(conv2, g3, filtersFirstLayer, '_3')
                up3 = concatenate([Conv2DTranspose(filtersFirstLayer, (3,3), strides=(2,2), padding='same', activation='relu', kernel_initializer=kinit)(up2), attn3], name='up3')

                up4 = concatenate([Conv2DTranspose(filtersFirstLayer, (3,3), strides=(2,2), padding='same', activation='relu', kernel_initializer=kinit)(up3), conv1], name='up4')

                conv6 = UnetConv2D(up1, filtersFirstLayer*8, is_batchnorm=True, name='conv6')
                conv7 = UnetConv2D(up2, filtersFirstLayer*4, is_batchnorm=True, name='conv7')
                conv8 = UnetConv2D(up3, filtersFirstLayer*2, is_batchnorm=True, name='conv8')
                conv9 = UnetConv2D(up4, filtersFirstLayer, is_batchnorm=True, name='conv9')

                out6 = Conv2D(1, (1, 1), activation='sigmoid', name='pred1')(conv6)
                out7 = Conv2D(1, (1, 1), activation='sigmoid', name='pred2')(conv7)
                out8 = Conv2D(1, (1, 1), activation='sigmoid', name='pred3')(conv8)
                out9 = Conv2D(1, (1, 1), activation='sigmoid', name='final')(conv9)

                model = Model(inputs=[img_input], outputs=[out6, out7, out8, out9])

                loss = {'pred1':focal_tversky,
                        'pred2':focal_tversky,
                        'pred3':focal_tversky,
                        'final':losses.tversky_loss}

                loss_weights = {'pred1':1,
                                'pred2':1,
                                'pred3':1,
                                'final':1}
                model.compile(optimizer=Adam(learning_rate=lr), loss=loss, loss_weights=loss_weights,
                              metrics=metrics)
                # model.summary()
                
                if(pretrained_weights):
                    model.load_weights(pretrained_weights)
                    
                return model

best_model = UNet(loss=tversky_loss, lr=1e-4, filters=32,pretrained_weights=None, input_size=(PATCHSIZE, PATCHSIZE, NBANDS))
best_model.load_weights("Checkpoints/weights.97-0.28.hdf5")
results = best_model.evaluate(Xtest, gt_test, verbose=0)
print(f'The metric evaluations are {results}')

# RUN TO SAVE THE MODEL IF YOU HAVE NOT SET ANY CHECKPOINTS; OTHERWISE NO NEED TO RUN THIS CODE
# This saves the weight as the model (might not be the best; depends which one you choose)

# import imp, h5py
# imp.reload(h5py)
# model_fname = "Checkpoints/2018_new.hdf5".format(filters, batch_size_list, lr)
# best_model.save(model_fname)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 128, 128, 5) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 128, 128, 32) 1472        input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 128, 128, 32) 128         conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 128, 128, 32) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 128, 128, 32) 9248        activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 128, 128, 32) 128         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 128, 128, 32) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 64, 64, 32)   0           activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 64, 64, 64)   18496       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 64, 64, 64)   256         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 64, 64, 64)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 64, 64, 64)   36928       activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 64, 64, 64)   256         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 64, 64, 64)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 32, 32, 64)   0           activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 32, 32, 128)  73856       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 32, 32, 128)  512         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 32, 32, 128)  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 32, 32, 128)  147584      activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 32, 32, 128)  512         conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 32, 32, 128)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 16, 16, 128)  0           activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 16, 16, 256)  295168      max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 16, 16, 256)  1024        conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 16, 16, 256)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 16, 16, 256)  590080      activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 16, 16, 256)  1024        conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 16, 16, 256)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 8, 8, 256)    0           activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 8, 8, 512)    1180160     max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 8, 8, 512)    2048        conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 8, 8, 512)    0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 8, 8, 512)    2359808     activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 8, 8, 512)    2048        conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 8, 8, 512)    0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 16, 16, 128)  262272      activation_9[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 16, 16, 384)  0           conv2d_transpose[0][0]
#                                                                  activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 16, 16, 256)  884992      concatenate[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 16, 16, 256)  1024        conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 16, 16, 256)  0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 16, 16, 256)  590080      activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 16, 16, 256)  1024        conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 16, 16, 256)  0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 32, 32, 64)   65600       activation_11[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 32, 32, 192)  0           conv2d_transpose_1[0][0]
#                                                                  activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 32, 32, 128)  221312      concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 32, 32, 128)  512         conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 32, 32, 128)  0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 32, 32, 128)  147584      activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 32, 32, 128)  512         conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 32, 32, 128)  0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 64, 64, 32)   16416       activation_13[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 64, 64, 96)   0           conv2d_transpose_2[0][0]
#                                                                  activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 64, 64, 64)   55360       concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 64, 64, 64)   256         conv2d_14[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 64, 64, 64)   0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 64, 64, 64)   36928       activation_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 64, 64, 64)   256         conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 64, 64, 64)   0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 128, 128, 16) 4112        activation_15[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 128, 128, 48) 0           conv2d_transpose_3[0][0]
#                                                                  activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 128, 128, 32) 13856       concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 128, 128, 32) 128         conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 128, 128, 32) 0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 128, 128, 32) 9248        activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 128, 128, 32) 128         conv2d_17[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 128, 128, 32) 0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 128, 128, 1)  33          activation_17[0][0]
# ==================================================================================================
# Total params: 7,032,369
# Trainable params: 7,026,481
# Non-trainable params: 5,888
# __________________________________________________________________________________________________
# None
# The metric evaluations are [0.29718247056007385, 0.9907515048980713, 0.8282489776611328, 0.5508866906166077, 0.6528103351593018]

# %% [markdown]
# LOAD MODELS FROM CURRENT RUN (Last Model)

# %%
# To load model from current run
model.evaluate(Xtest, Ytest, verbose=2)
# Out:
# 9/9 - 1s - loss: -1.7326e+00 - accuracy: 0.8880 - precision_m: 36.7652 - recall_m: 0.9646 - f1_m: 1.8735
# [-1.7325900793075562,
#  0.8880049586296082,
#  36.765220642089844,
#  0.9645809531211853,
#  1.8735079765319824]

# %% [markdown]
# ### Predict the model

# %%
def visualize_prediction(data,mask,predict):
    f, axarr = plt.subplots(1,3)
    data = data[:, :, 3] 
    axarr[0].imshow(data)
    axarr[0].set_title("Satellite image")

    a=axarr[1]
    values = np.unique(mask.ravel())
    im = axarr[1].imshow(mask[:,:,0])
    a.set_title("Ground truth labeled image")
    colors = [im.cmap(im.norm(value)) for value in values]

    b=axarr[2]
    values = np.unique(predict.ravel())
    im = axarr[2].imshow(predict[:,:,0])
    b.set_title("Predicted image")
    colors = [im.cmap(im.norm(value)) for value in values]

    mask = ["Background", "Landslide footprints"]
    patches = [mpatches.Patch(color=colors[i], label=j) for i, j in zip(range(len(values)), mask)]
    plt.legend(handles=patches, bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0. )

# %%
# Select the model and predict on the test image
prediction = model.predict(Xtest)

# Run this code if the predicted data needs to be in "int" type and if you need to do THRESHOLDING.
prediction[prediction>0.5]=1
prediction[prediction<0.5]=0

PATCH_NO = random.randint(0, len(Xtest)-1)
test = Ytest[PATCH_NO]

print("Precision: ", (precision_m(test, prediction[PATCH_NO])))
print("Recall: " , recall_m(test, prediction[PATCH_NO]))
print("F1-score: " , f1_m(test, prediction[PATCH_NO]))

visualize_prediction(Xtest[PATCH_NO].astype('uint8'),Ytest[PATCH_NO], prediction[PATCH_NO])
print("Site number= %i" % (PATCH_NO))
# Out:
# Precision:  tf.Tensor(0.0, shape=(), dtype=float32)
# Recall:  tf.Tensor(0.0, shape=(), dtype=float32)
# F1-score:  tf.Tensor(0.0, shape=(), dtype=float32)
# Site number= 212

# %%
# Plot the first 10 predictions
for i in range(25):
    prediction = model.predict(np.expand_dims(X_test[i],axis = 0), verbose=1)
    # It's possible to change the 0.5 threshold to improve the results;
    prediction = (prediction > 0.5).astype(np.uint8)
    f, axarr = plt.subplots(1,3,figsize=(10,10))
    axarr[0].imshow(X_test[i][:,:,:3])
    axarr[1].imshow(np.squeeze(prediction))
    axarr[2].imshow(np.squeeze(Y_test[i]))
# Out:
# 1/1 [==============================] - 8s 8s/step
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 1/1 [==============================] - 0s 14ms/step
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 1/1 [==============================] - 0s 15ms/step
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 1/1 [==============================] - 0s 14ms/step
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 1/1 [==============================] - 0s 19ms/step
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 1/1 [==============================] - 0s 16ms/step
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 1/1 [==============================] - 0s 16ms/step
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 1/1 [==============================] - 0s 15ms/step
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 1/1 [==============================] - 0s 19ms/step
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 1/1 [==============================] - 0s 16ms/step
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 1/1 [==============================] - 0s 20ms/step
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 1/1 [==============================] - 0s 17ms/step
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 1/1 [==============================] - 0s 13ms/step
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 1/1 [==============================] - 0s 16ms/step
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 1/1 [==============================] - 0s 14ms/step
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 1/1 [==============================] - 0s 20ms/step
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 1/1 [==============================] - 0s 20ms/step
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 1/1 [==============================] - 0s 16ms/step
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 1/1 [==============================] - 0s 16ms/step
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 1/1 [==============================] - 0s 15ms/step
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 1/1 [==============================] - 0s 18ms/step
# C:\Users\kusha\anaconda3\envs\DL\lib\site-packages\ipykernel_launcher.py:6: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 1/1 [==============================] - 0s 17ms/step
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 1/1 [==============================] - 0s 16ms/step
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 1/1 [==============================] - 0s 16ms/step
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 1/1 [==============================] - 0s 17ms/step
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
